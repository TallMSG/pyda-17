# %% [markdown]
# # Библиотека requests

# %%
import requests

# %%
# метод get
res = requests.get('https://yandex.ru')
res
# res.status_code
# Out:
# <Response [200]>

# %%
# браузер отрисовал бы страницу на основе данного текста
res.text
# Out:
# '<!DOCTYPE html><html class="i-ua_js_no i-ua_css_standart i-ua_browser_unknown i-ua_browser-engine_unknown i-ua_browser_desktop i-ua_platform_other" lang="ru"><head xmlns:og="http://ogp.me/ns#"><meta http-equiv=Content-Type content="text/html;charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>Яндекс</title><link rel="shortcut icon" href="//yastatic.net/iconostasis/_/8lFaTHLDzmsEZz-5XaQg9iTWZGE.png"><link rel="apple-touch-icon" href="//yastatic.net/iconostasis/_/5mdPq4V7ghRgzBvMkCaTzd2fjYg.png" sizes="76x76"><link rel="apple-touch-icon" href="//yastatic.net/iconostasis/_/s-hGoCQMUosTziuARBks08IUxmc.png" sizes="120x120"><link rel="apple-touch-icon" href="//yastatic.net/iconostasis/_/KnU823iWwj_vrPra7x9aQ-4yjRw.png" sizes="152x152"><link rel="apple-touch-icon" href="//yastatic.net/iconostasis/_/wT9gfGZZ80sP0VsoR6dgDyXJf2Y.png" sizes="180x180"><link rel="alternate" type="application/rss+xml" title="Новости Яндекса" href="https://yandex.ru/company/press_releases/news.rss"><link rel="alternate" type="application/rss+xml" title="Блог Яндекса" href="https://yandex.ru/blog/company/rss"><link rel="search" href="//yandex.ru/opensearch.xml" title="Яндекс" type="application/opensearchdescription+xml"><link rel="preload" href="//yastatic.net/jquery/2.1.4/jquery.min.js" as="script" crossorigin="anonymous"><link rel="preload" href="//yastatic.net/s3/home-static/_/N/f/Vq_dK534WW9iwsHxXM61_AbRA.js" as="script" crossorigin="anonymous"><meta property="fb:app_id" content="1524984910954255"><meta name="yamm" content="p"><meta name="referrer" content="origin"><meta property="og:title" content="Яндекс"><meta property="og:image" content="https://yastatic.net/s3/home/logos/share/share-logo_ru.png"><meta property="og:description" content="Найдётся всё"><meta property="og:url" content="https://yandex.ru"><meta property="og:type" content="website"><meta property="og:site_name" content="Яндекс"><meta property="og:locale" content="ru_RU"><meta property="og:locale:alternate" content="ru_RU"><meta property="og:locale:alternate" content="be_BY"><meta property="og:locale:alternate" content="kk_KZ"><meta property="og:locale:alternate" content="tt_RU"><meta property="og:locale:alternate" content="uk_UA"><script>(function(window) { var home = window.home = window.home || {}, delta = +new Date() - 1612982409 * 1000; home.now = function() { return new Date(+new Date() - delta); }; })(window);</script><script>window.home=window.home||{},home.loadManager=function(){var n={},o={};return{subscribe:function(t,e){var i=0,r=function(){++i===t.length&&setTimeout((function(){e()}),0)};"object"!=typeof t&&(t=[t]),t.forEach((function(t){o[t]?r():(n[t]||(n[t]=[]),n[t].push(r))}))},trigger:function(t){if(!o[t]&&(o[t]=!0,n[t])){for(var e=0,i=n[t].length;e<i;e++)n[t][e]();n[t]=[]}}}}();</script><script>!function(i,t){if(i.Ya=i.Ya||{},Ya.Rum)throw new Error("Rum: interface is already defined");var n=i.performance,e=n&&n.timing&&n.timing.navigationStart||Ya.startPageLoad||+new Date,s=i.requestAnimationFrame;Ya.Rum={enabled:!!n,vsStart:document.visibilityState,vsChanged:!1,_defTimes:[],_defRes:[],_deltaMarks:{},_markListeners:{},_settings:{},_vars:{},init:function(i,t){this._settings=i,this._vars=t},getTime:n&&n.now?function(){return n.now()}:Date.now?function(){return Date.now()-e}:function(){return new Date-e},time:function(i){this._deltaMarks[i]=[this.getTime()]},timeEnd:function(i,t){var n=this._deltaMarks[i];n&&0!==n.length&&n.push(this.getTime(),t)},sendTimeMark:function(i,t,n,e){void 0===t&&(t=this.getTime()),this._defTimes.push([i,t,e]),this.mark(i,t)},sendResTiming:function(i,t){this._defRes.push([i,t])},sendRaf:function(i){var t=this.getSetting("forcePaintTimeSending");if(s&&(t||!this.isVisibilityChanged())){var n=this,e="2616."+i;s((function(){!t&&n.isVisibilityChanged()||(n.getSetting("sendFirstRaf")&&n.sendTimeMark(e+".205"),s((function(){!t&&n.isVisibilityChanged()||n.sendTimeMark(e+".1928")})))}))}},isVisibilityChanged:function(){return this.vsS ...

# %%
# посмотрим куки
res.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='i', value='LbphX/iF6t9W6QQu5yZMDMdoPAG2jv38/jQaITDGOxCOQZBmIQW6TL5Q8K+ra0q0/v12G8KL7ze+raWv/g2BUqpZ4nE=', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1676054408, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='is_gdpr', value='0', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1676054408, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='is_gdpr_b', value='CMudIBCFHSgC', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1676054408, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='mda', value='0', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1623350408, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='yandex_gid', value='10725', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1615574408, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='yandexuid', value='4573619881612982408', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1928342408, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='yp', value='1615574409.ygu.1', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1928342408, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
# получаем плохой статус
bad_request = requests.get('https://yandex.ru/secret')
bad_request
# Out:
# <Response [404]>

# %%
bad_request.text
# Out:
# '<!DOCTYPE html><html class="i-ua_js_no i-ua_css_standart i-ua_browser_unknown i-ua_browser-engine_unknown i-ua_browser_desktop i-ua_platform_other" lang="ru"><head xmlns:og="http://ogp.me/ns#"><meta http-equiv=Content-Type content="text/html;charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>404</title><link rel="shortcut icon" href="//yastatic.net/iconostasis/_/8lFaTHLDzmsEZz-5XaQg9iTWZGE.png"><link rel="search" href="//yandex.ru/opensearch.xml" title="Яндекс" type="application/opensearchdescription+xml"><meta name="viewport" content="width=device-width,minimum-scale=1,maximum-scale=1,initial-scale=1,user-scalable=no"><meta property="og:title" content="Яндекс"><meta property="og:image" content="https://yastatic.net/s3/home/logos/share/share-logo_ru.png"><meta property="og:description" content="Найдётся всё"><meta property="og:url" content="https://yandex.ru"><meta property="og:type" content="website"><meta property="og:site_name" content="Яндекс"><meta property="og:locale" content="ru_RU"><script>window.home=window.home||{},home.loadManager=function(){var n={},o={};return{subscribe:function(t,e){var i=0,r=function(){++i===t.length&&setTimeout((function(){e()}),0)};"object"!=typeof t&&(t=[t]),t.forEach((function(t){o[t]?r():(n[t]||(n[t]=[]),n[t].push(r))}))},trigger:function(t){if(!o[t]&&(o[t]=!0,n[t])){for(var e=0,i=n[t].length;e<i;e++)n[t][e]();n[t]=[]}}}}();</script><link rel="stylesheet" href="//yastatic.net/s3/home-static/_/q/K/LMNqSH1f_ondDFsXiYB-zJSjM.css"><script>function Detector(){"use strict";var e=document.documentElement;return{isPlaceholderSupported:function(){return"placeholder"in document.createElement("input")},getCSS3TransformProperty:function(){for(var e=document.documentElement.style,t=["transform","MozTransform","MsTransform","msTransform","WebkitTransform","OTransform"],n="",i=0,r=t.length;i<r;++i)if(e[t[i]]!==undefined){n=t[i];break}return this.getCSS3TransformProperty=function(){return n},n},checkDataURLSupport:function(e){var t=new Image;t.onload=t.onerror=function(){e(1===this.width&&1===this.height)},t.src="..."},isActivexEnabled:function(){var e=!1;try{e=!!new window.ActiveXObject("htmlfile")}catch(t){e=!1}return e},isWin64:function(){return window.navigator&&"Win64"===window.navigator.platform},isFullScreen:function(){return window.innerWidth&&window.screen&&window.screen.width&&window.screen.height&&window.innerHeight&&window.innerWidth===screen.width&&window.innerHeight===screen.height},isIEMetroMode:function(){return this.isFullScreen()&&this.isWin64()&&!this.isActivexEnabled()},isSVGSupported:function(){if("opera"in window)return!1;var e=document.createElement("svg");return e.innerHTML="<svg/>",e.firstChild&&"http://www.w3.org/2000/svg"===e.firstChild.namespaceURI},isAnimationSupported:function(){if("opera"in window)return!1;for(var e=document.documentElement.style,t=["animationName","webkitAnimationName"],n=0,i=t.length;n<i;n++)if(e[t[n]]!==undefined)return!0},getUserFontSize:function(){var t,n,i=[],r="i-ua_user-font-size_",o=document.createElement("div");return o.style.height="1em",e.appendChild(o),t=parseInt(o.offsetHeight),e.removeChild(o),n=16===t?"normal":t<16?"small":"large",i.push(r+n),i.push(r+t+"px"),i.join(" ")},isRetina:function(){return("devicePixelRatio"in window?window.devicePixelRatio:1)>=1.25}}}function MyMap(){this.rules={},this.rulesData=[]}MyMap.prototype={add:function(e){return(e=e||null)&&!this.rules[e]&&(this.rulesData.push(e),this.rules[e]=this.rulesData.length-1),this},get:function(e){var t=this.rules[e];return t&&this.rulesData[t]||null},getAll:function(){return this.rulesData.join(" ")}};var detector=new Detector;!function(){var e,t=new MyMap;t.add("js").add("i-ua_placeholder_"+(detector.isPlaceholderSupported()?"yes":"no")).add(detector.isIEMetroMode()&&"m-ie10-metro").add(detector.isSVGSupported()?"i-ua_inlinesvg_yes m-svg":"i-ua_inlinesvg_no no-data-url").add(detector.isAnimationSupported()&&"i-ua_animation_yes").add(this.device&&"m-touch") ...

# %%
# попроуем сделать post запрос
post_req = requests.post('https://yandex.ru')
post_req
# Out:
# <Response [403]>

# %%
# cформируем поисковый запрос, обратите внимание на его формат
URL = 'https://yandex.ru/search/?text=python&lr=54'

# %%
req = requests.get(URL)
req
# Out:
# <Response [200]>

# %%
req.text
# Out:
# '<!DOCTYPE html><html class=i-ua_js_no lang=ru><meta charset=utf-8><meta http-equiv=X-UA-Compatible content="IE=edge"><title>Яндекс</title><script nonce=7430>document.documentElement.className="i-ua_js_yes i-ua_svg_yes"+((screen.deviceXDPI&&screen.logicalXDPI&&screen.deviceXDPI/screen.logicalXDPI||window.devicePixelRatio)>1?" i-ua_retina_yes":"");</script><link rel=search title="Яндекс" type="application/opensearchdescription+xml" href="/search/opensearch.xml"><meta name=referrer content=always><style nonce=7430 data-role=css data-stylesheet=header>body{margin:0}.b-page__body{margin:0;color:#000;background:#fff;height:100%;padding:0;font-family:Arial,Helvetica,sans-serif;font-size:13px;line-height:1.154}.i-ua_platform_ios.b-page__body{-webkit-tap-highlight-color:rgba(0,0,0,0);cursor:auto}html{height:100%}.b-page.b-page_js_inited.b-page_overflow_hidden,.b-page_initial-scroll_yes.b-page_js_inited.b-page_overflow_yes{overflow:hidden}.b-page_offset_top{padding-top:32px}.b-page_change_yes{will-change:padding-top;transition:padding-top .3s .1s ease-in-out}.b-page_initial-scroll_yes{overflow-y:scroll}.b-page_initial-scroll_yes.b-page_js_inited{overflow-y:auto}.a11y-fast-nav{position:absolute;top:-9999px;left:-9999px}.serp-header{position:relative;font-family:Arial,sans-serif;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.serp-header__main{display:table;box-sizing:border-box;width:100%;table-layout:fixed;box-shadow:none!important}.serp-header__under{position:relative}.serp-header__logo,.serp-header__nav,.serp-header__search2{display:table-cell;height:39px;vertical-align:top}.serp-header__nav{padding-left:20px;text-align:right;white-space:nowrap}.serp-header__logo .logo.logo_name_ys-en-87x35{background-position:0 3px}.serp-header_head-auth_yes .serp-header__search2{width:100%}.serp-header .serp-user_enter_yes,.serp-header .serp-user_type_enter{margin-top:3px;padding-left:7px;vertical-align:top}.serp-header{height:55px}.serp-header__main{padding:14px 16px 0}.serp-header_head-auth_yes .serp-header__main{min-width:500px;table-layout:auto}.serp-header__wrapper{position:fixed;width:100%;height:55px;background:#fff;-webkit-transform:translateZ(0);transform:translateZ(0)}.serp-header__search2{position:relative;z-index:1;width:638px;padding-top:1px}.serp-header__nav{position:relative;z-index:2}.serp-header .notifier{display:inline-block;margin-right:18px}.serp-header .notifier__icon{margin-top:1px}.serp-header__logo{width:100px;min-width:100px}@media (max-width:1060px){.yaplus_available_yes .link__inner{display:none}}@media (max-width:960px){.serp-header__logo{width:auto;min-width:auto}.logo[class][class]{width:18px;height:35px;margin-right:9px;background-position:0 4px}.serp-header .logo.logo_name_ys-ru-86x35{background-image:url("//yastatic.net/s3/web4static/_/v2/SSIxUPEp7tr5cbP0cCIM-2_62g8.svg")}.serp-header .logo.logo_name_ys-en-87x35{background-image:url("//yastatic.net/s3/web4static/_/v2/DTIqAt1p7IWGR0nbQsniMk5jPJg.svg")}}@media (max-width:722px){.header-favorites-button[class],.input__settings[class],.input__voice-search[class][class],.notifier[class][class],.yaplus[class]{display:none}}.serp-header__back-button-container{display:none}.serp-header{min-width:600px}.serp-header[class]{z-index:10005}.logo{display:inline-block;background-repeat:no-repeat;background-position:center;background-size:contain}@media print{.logo{-webkit-print-color-adjust:exact}}.logo_name_ys-ru-86x35{width:86px;height:35px;background-image:url("//yastatic.net/islands/_/RQWGFypkIRAzEbaERs_Sq8zKRzY.svg")}.logo_name_ys-en-87x35{width:87px;height:35px;background-image:url("//yastatic.net/islands/_/W5E8s3ZxddTVAc2-tL5VvgPy6ZY.svg")}.logo_type_link{overflow:hidden;white-space:nowrap;text-indent:100%;outline:0}.z-index-group_level_0{z-index:1000}.z-index-group_level_1{z-index:2000}.z-index-group_level_2{z-index:3000}.z-index-group_level_3{z-index:4000}.z-index-group_level_4{z-index:5000}.z-index-group_level_5{z-index:6000}.z-index ...

# %%
# в request можно передать параметры запроса и заголовки (headers) в виде словарей. 
# сегодня не будем рассматривать примеры с необхожимостью передачи заголовка, 
# но в практике вам это точно понадобится
URL = 'https://yandex.ru/search/'
params = {
    'text': 'python',
    'lr': 54
}
headers = {}
req = requests.get(URL, params)
req = requests.post(URL, params, headers)
req.text
# Out:
# '<!DOCTYPE html><html class=i-ua_js_no lang=ru><meta charset=utf-8><meta http-equiv=X-UA-Compatible content="IE=edge"><title>Яндекс</title><script nonce=5448>document.documentElement.className="i-ua_js_yes i-ua_svg_yes"+((screen.deviceXDPI&&screen.logicalXDPI&&screen.deviceXDPI/screen.logicalXDPI||window.devicePixelRatio)>1?" i-ua_retina_yes":"");</script><link rel=search title="Яндекс" type="application/opensearchdescription+xml" href="/search/opensearch.xml"><meta name=referrer content=always><style nonce=5448 data-role=css data-stylesheet=header>body{margin:0}.b-page__body{margin:0;color:#000;background:#fff;height:100%;padding:0;font-family:Arial,Helvetica,sans-serif;font-size:13px;line-height:1.154}.i-ua_platform_ios.b-page__body{-webkit-tap-highlight-color:rgba(0,0,0,0);cursor:auto}html{height:100%}.b-page.b-page_js_inited.b-page_overflow_hidden,.b-page_initial-scroll_yes.b-page_js_inited.b-page_overflow_yes{overflow:hidden}.b-page_offset_top{padding-top:32px}.b-page_change_yes{will-change:padding-top;transition:padding-top .3s .1s ease-in-out}.b-page_initial-scroll_yes{overflow-y:scroll}.b-page_initial-scroll_yes.b-page_js_inited{overflow-y:auto}.a11y-fast-nav{position:absolute;top:-9999px;left:-9999px}.serp-header{position:relative;font-family:Arial,sans-serif;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.serp-header__main{display:table;box-sizing:border-box;width:100%;table-layout:fixed;box-shadow:none!important}.serp-header__under{position:relative}.serp-header__logo,.serp-header__nav,.serp-header__search2{display:table-cell;height:39px;vertical-align:top}.serp-header__nav{padding-left:20px;text-align:right;white-space:nowrap}.serp-header__logo .logo.logo_name_ys-en-87x35{background-position:0 3px}.serp-header_head-auth_yes .serp-header__search2{width:100%}.serp-header .serp-user_enter_yes,.serp-header .serp-user_type_enter{margin-top:3px;padding-left:7px;vertical-align:top}.serp-header{height:55px}.serp-header__main{padding:14px 16px 0}.serp-header_head-auth_yes .serp-header__main{min-width:500px;table-layout:auto}.serp-header__wrapper{position:fixed;width:100%;height:55px;background:#fff;-webkit-transform:translateZ(0);transform:translateZ(0)}.serp-header__search2{position:relative;z-index:1;width:638px;padding-top:1px}.serp-header__nav{position:relative;z-index:2}.serp-header .notifier{display:inline-block;margin-right:18px}.serp-header .notifier__icon{margin-top:1px}.serp-header__logo{width:100px;min-width:100px}@media (max-width:1060px){.yaplus_available_yes .link__inner{display:none}}@media (max-width:960px){.serp-header__logo{width:auto;min-width:auto}.logo[class][class]{width:18px;height:35px;margin-right:9px;background-position:0 4px}.serp-header .logo.logo_name_ys-ru-86x35{background-image:url("//yastatic.net/s3/web4static/_/v2/SSIxUPEp7tr5cbP0cCIM-2_62g8.svg")}.serp-header .logo.logo_name_ys-en-87x35{background-image:url("//yastatic.net/s3/web4static/_/v2/DTIqAt1p7IWGR0nbQsniMk5jPJg.svg")}}@media (max-width:722px){.header-favorites-button[class],.input__settings[class],.input__voice-search[class][class],.notifier[class][class],.yaplus[class]{display:none}}.serp-header__back-button-container{display:none}.serp-header{min-width:600px}.serp-header[class]{z-index:10005}.logo{display:inline-block;background-repeat:no-repeat;background-position:center;background-size:contain}@media print{.logo{-webkit-print-color-adjust:exact}}.logo_name_ys-ru-86x35{width:86px;height:35px;background-image:url("//yastatic.net/islands/_/RQWGFypkIRAzEbaERs_Sq8zKRzY.svg")}.logo_name_ys-en-87x35{width:87px;height:35px;background-image:url("//yastatic.net/islands/_/W5E8s3ZxddTVAc2-tL5VvgPy6ZY.svg")}.logo_type_link{overflow:hidden;white-space:nowrap;text-indent:100%;outline:0}.z-index-group_level_0{z-index:1000}.z-index-group_level_1{z-index:2000}.z-index-group_level_2{z-index:3000}.z-index-group_level_3{z-index:4000}.z-index-group_level_4{z-index:5000}.z-index-group_level_5{z-index:6000}.z-index ...

# %%
# очень часто сайты могут ограничивать частые запросы к себе, 
# поэтому нужно задерживать исполнение
import time
time.sleep(0.2)

# %% [markdown]
# # Beautiful Soup

# %%
# как разбирать всю эту разметку? Поможет BeautifulSoup.
from bs4 import BeautifulSoup

# %% [markdown]
# ## Практика 1. Напишем скрипт, который будет отбирать посты из нужных хабов на habr.com

# %%
# определяем список хабов, которые нам интересны
DESIRED_HUBS = ['python', 'bigdata']

# %%
# получаем страницу с самыми свежими постами
req = requests.get('https://habr.com/ru/all/')
soup = BeautifulSoup(req.text, 'html.parser')

# %%
# извлекаем посты
posts = soup.find_all('article', class_='post')
posts
# Out:
# [<article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/MaxRokatansky/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/b9f/baf/5f9/b9fbaf5f96ae52973706a0716bd9216e.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">MaxRokatansky</span>
#  </a>
#  <span class="post__time">сегодня в 19:04</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/otus/blog/541820/">SQLite с использованием Go и Python</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/otus/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании OTUS. Онлайн-образование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании OTUS. Онлайн-образование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/sql/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'SQL'); }" rel="nofollow" title="Вы не подписаны на этот хаб">SQL</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/go/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Go'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Go</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__body-cover post__body-cover_fit-cover">
#  <img src="https://habrastorage.org/getpro/habr/upload_files/e03/17a/0d1/e0317a0d1376327780ad13bc9c052797.png" style="object-position: 0% 0%">
#  </img></div>
#  <div class="post__text post__text-html post__text_v2">
#  <p>В основном я предпочитаю использовать реляционные базы данных (SQL), поскольку они предоставляют несколько возможностей, которые весьма полезны при работе с данными. SQLite - отличный выбор, так как база данных там представляет собой единый файл, что упрощает обмен данными. Несмотря на то, что это единый файл, SQLite может обрабатывать до 281 терабайта данных. SQLite также поставляется с клиентом командной строки sqlite3, который отлично подходит для быстрого прототипирования.</p><p><em>Примечание: В других базах данных есть транзакции, языки запросов и схемы. Однако базы данных на основе SQL имеют тенденцию быть более развитыми испытанными временем, а сам SQL стандартизирован.</em></p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/otus/blog/541820/#habracut">Читать далее</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_otus,h_359,h_594,h_17748" id="infopanel_post_541820">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_negative" title="Всего голосов 1: ↑0 и ↓1">–1</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541820" data-post-type="publish_corp_ru,c_otus,h_359,h_594,h_17748" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">1</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">292</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/otus/blog/541820/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/artemhere/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/afd/cc2/08e/afdcc208ef664e756a90f8fa4d2e19f4.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">artemhere</span>
#  </a>
#  <span class="post__time">сегодня в 18:10</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/541856/">Connected! Самое главное о дизайне VPN-приложения</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/analysis_design/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Анализ и проектирование систем'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Анализ и проектирование систем</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/ui/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Интерфейсы'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Интерфейсы</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/apps_design/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Дизайн мобильных приложений'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Дизайн мобильных приложений</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/mobileanalytics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Аналитика мобильных приложений'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Аналитика мобильных приложений</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/design/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Дизайн'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Дизайн</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">Из песочницы</a></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__body-cover post__body-cover_fit-cover">
#  <img src="https://habrastorage.org/getpro/habr/upload_files/755/4c4/fc2/7554c4fc2722edfa0cddb12ca0ae6292" style="object-position: 0% 0%">
#  </img></div>
#  <div class="post__text post__text-html post__text_v2">
#  <p>Разбираемся, как сделать удобный и рабочий сервис при минимальных затратах на разработку. В статье я постарался описать все самое важное, не заостряя внимание на деталях.</p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/541856/#habracut">Читать далее</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_397,h_9188,h_19465,h_20724,h_21892" id="infopanel_post_541856">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541856" data-post-type="publish_ugc_ru,h_397,h_9188,h_19465,h_20724,h_21892" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">1</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">519</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/541856/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/EVKRUS/" title="Автор публикации">
#  <span class="default-image_mini default-image_green">
#  <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
#  </span>
#  <span class="user-info__nickname user-info__nickname_small">EVKRUS</span>
#  </a>
#  <span class="post__time">сегодня в 17:53</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/538144/">Разбор дела о краже коммерческой тайны</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/infosecurity/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Информационная безопасность'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Информационная безопасность</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/business-laws/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Законодательство в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Законодательство в IT</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v2">
#  <p>В этой статье речь пойдет о краже коммерческой тайны. Очень важно понимать, если дело дошло до суда, нужно защищаться всеми способами, которые вам доступны. Не нужно никаких сантиментов, не нужно никого жалеть или, наоборот, надеяться, что у кого-то проснется совесть и т.д.  Собирайте максимум доказательств и предоставляйте их суду. Суд не изучает эмоции, он рассматривает только формальную сторону вопроса – факты и доказательства. Чем больше у вас доказательств, чем лучше работает ваш юрист, тем выше шансы выиграть дело.</p><p>Доказать хищение информации и наказать виновника через суд – дело непростое. Потому большинство юристов рекомендуют пользоваться любой возможностью решить вопрос в досудебном порядке. Если вы все же собираетесь в суд, читайте материал ниже, возможно, именно эта статья поможет вам правильно подготовиться.</p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/538144/#habracut">Читать далее</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_50,h_20738" id="infopanel_post_538144">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 6: ↑3 и ↓3">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="538144" data-post-type="publish_ugc_ru,h_50,h_20738" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">2</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">775</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/538144/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">1</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/xtender/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/34d/1bc/0f9/34d1bc0f9d9162fedb899fe2f708959d.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">xtender</span>
#  </a>
#  <span class="post__time">сегодня в 17:36</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/541848/">Oracle: Deterministic functions, result_cache and operators</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/oracle/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Oracle'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Oracle</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/sql/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'SQL'); }" rel="nofollow" title="Вы не подписаны на этот хаб">SQL</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v2">
#  <p>После перевода статьи <a href="https://habr.com/en/post/541152/" rel="noopener noreferrer nofollow">Oracle: разница между deterministic и result_cache</a> от Steven Feuerstein, хотелось бы дополнить ее действительно важными деталями их устройства. У меня есть серия статей на эти темы, но тут я хотел бы просто все резюмировать и оставить самое важное.</p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/541848/#habracut">Read more</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_312,h_594" id="infopanel_post_541848">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541848" data-post-type="publish_ugc_ru,h_312,h_594" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">2</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">108</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/541848/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">3</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/foxcode85/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/60f/d89/01f/60fd8901f3c26e473bcbe0049fcbff08.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">foxcode85</span>
#  </a>
#  <span class="post__time">сегодня в 17:19</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/541840/">Параллельные запросы в Kotlin для автоматизации сборки данных</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/kotlin/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Kotlin'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Kotlin</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">Из песочницы</a></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__body-cover post__body-cover_fit-cover">
#  <img src="https://habrastorage.org/getpro/habr/upload_files/4e0/4b4/804/4e04b48047711a87bbbbf39f91f38a96.jpg" style="object-position: 59.102564102564% 32.045454545455%">
#  </img></div>
#  <div class="post__text post__text-html post__text_v2">
#  <p>Всем привет! В своей работе я часто использую Kotlin для автоматизации. Деятельность не связана напрямую с программированием, но Котлин здорово упрощает рабочие задачи.</p><p>Недавно нужно было собрать данные немаленького размера, дабы сделать анализ, поэтому решено было написать небольшой скрипт, который бы работал быстро и сохранял данные в Excel. С последним пунктом проблем не возникло - почитал про Apache POI, взял пару примеров из официальной документации, доработав под себя. Чего не скажешь про запросы в Сеть.</p><p>Источник отдавал пачками json и надо было как-то быстро эти "пачки" собирать, преобразовывая в текст и записывая в файл таблицу. </p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/541840/#habracut">Читать далее</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_359,h_19441" id="infopanel_post_541840">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 3: ↑3 и ↓0">+3</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541840" data-post-type="publish_ugc_ru,h_359,h_19441" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">3</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">372</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/541840/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">8</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/nin-jin/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/20a/0ad/d8c/20a0add8ce3ddddec0e521f86e694f40.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">nin-jin</span>
#  </a>
#  <span class="post__time">сегодня в 17:11</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/541800/">Инверсия контроля на голом TypeScript без боли</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/complete_code/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Совершенный код'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Совершенный код</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/refactoring/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Проектирование и рефакторинг'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Проектирование и рефакторинг</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/web_testing/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Тестирование веб-сервисов'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Тестирование веб-сервисов</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/typescript/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'TypeScript'); }" rel="nofollow" title="Вы не подписаны на этот хаб">TypeScript</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__body-cover post__body-cover_fit-cover">
#  <img src="https://habrastorage.org/getpro/habr/upload_files/db1/bd0/b81/db1bd0b813956ea692fe48a69f1f43b8.png" style="object-position: 40.384615384615% 0.45454545454545%">
#  </img></div>
#  <div class="post__text post__text-html post__text_v2">
#  <p>Здравствуйте, меня зовут Дмитрий Карловский и (сколько себя помню) я борюсь со своим окружением. Ведь оно такое костное, дубовое, и никогда не понимает, что я от него хочу. Но в какой-то момент я понял, что хватит это терпеть и надо что-то менять. Поэтому теперь не окружение диктует мне, что я могу и не могу делать, а я диктую окружению каким ему быть.</p><p>Как вы уже поняли, далее речь пойдёт про инверсию контроля через "контекст окружения". Многим этот подход уже знаком по "переменным окружения" - они задаются при запуске программы и обычно наследуются для всех программ, которые та запускает. Мы же применим эту концепцию для организации нашего кода на TypeScript.</p><p>Итак, что мы хотим получить:</p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/541800/#habracut">Что-что?</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_359,h_524,h_7504,h_19279,h_21370" id="infopanel_post_541800">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 5: ↑3 и ↓2">+1</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541800" data-post-type="publish_ugc_ru,h_359,h_524,h_7504,h_19279,h_21370" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">8</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">594</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/541800/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/MaxRokatansky/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/b9f/baf/5f9/b9fbaf5f96ae52973706a0716bd9216e.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">MaxRokatansky</span>
#  </a>
#  <span class="post__time">сегодня в 17:09</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/otus/blog/541812/">12 примеров улучшения кода с помощью @dataclass</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/otus/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании OTUS. Онлайн-образование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании OTUS. Онлайн-образование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/machine_learning/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Машинное обучение'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Машинное обучение</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__body-cover post__body-cover_fit-cover">
#  <img src="https://habrastorage.org/getpro/habr/upload_files/c2d/dde/aaf/c2dddeaafa30ef2e1c5842ec243263f9.png" style="object-position: 0% 0%">
#  </img></div>
#  <div class="post__text post__text-html post__text_v2">
#  <p>Мы добавляем алгоритмы кластеризации с помощью пакетов scikit-learn, Keras и других в пакет Photonai. На 12 примерах мы покажем, как <em>@dataclass</em> улучшает код на Python. Для этого мы используем код из пакета Photonai для Machine Learning.</p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/otus/blog/541812/#habracut">Читать далее</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_otus,h_340,h_359,h_19439" id="infopanel_post_541812">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 3: ↑3 и ↓0">+3</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541812" data-post-type="publish_corp_ru,c_otus,h_340,h_359,h_19439" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">6</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">476</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/otus/blog/541812/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/AloneCoder/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/741/45e/bea/74145ebeab7f222cce402aed2683f9d7.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">AloneCoder</span>
#  </a>
#  <span class="post__time">сегодня в 16:44</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/mailru/blog/541624/">Культ лучших практик</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/mailru/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Mail.ru Group'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Mail.ru Group</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/complete_code/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Совершенный код'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Совершенный код</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/terminator/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Терминология IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Терминология IT</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/dev_management/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Управление разработкой'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Управление разработкой</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <div style="text-align:center;"><img src="https://habrastorage.org/webt/t-/rj/rk/t-rjrke7lqnq6n4mezu-cutxdvq.jpeg"/></div><br/>
#  Лучшие практики, несмотря на термин, не всегда хороши. В программировании многие из них не оправдывают своего названия. Они распространяются не благодаря своим заслугам или доказательствам эффективности, а из-за эффекта авторитета и использования обществом. По мере их распространения теряются нюансы. А с потерей нюансов становится легче заниматься их евангелизмом. В сочетании с нехваткой опыта это может привести к возникновению культа лучших практик. Представьте команду, которая одержима их использованием — скажем, разработкой через тестирование (test-driven development) или написанием пользовательских сценариев, — до такой степени, что это уже вредит. В эту ловушку попадали многие, в том числе и я.<br/>
#  <br/>
#  Почему лучшие практики могут быть вредны? Почему мы любим им следовать? Когда и как они мешают? Чтобы ответить на эти вопросы, нужно понять, откуда берутся эти практики и как они распространяются в программировании.<br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/mailru/blog/541624/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_mailru,h_359,h_524,h_19019,h_19583" id="infopanel_post_541624">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 6: ↑6 и ↓0">+6</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541624" data-post-type="publish_corp_ru,c_mailru,h_359,h_524,h_19019,h_19583" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">10</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,6k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/mailru/blog/541624/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">3</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/AlexxNB/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/9da/ab8/746/9daab8746ec465c7dcda3c0a952cc538.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">AlexxNB</span>
#  </a>
#  <span class="post__time">сегодня в 16:19</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/541834/">Переиспользуемый компонент Svelte: чтобы никому не было больно</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/webdev/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Разработка веб-сайтов'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Разработка веб-сайтов</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/javascript/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'JavaScript'); }" rel="nofollow" title="Вы не подписаны на этот хаб">JavaScript</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/sveltejs/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'SvelteJS'); }" rel="nofollow" title="Вы не подписаны на этот хаб">SvelteJS</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <p><img alt="Переиспользуемый компонент Svelte: чтобы никому не было больно" src="https://habrastorage.org/webt/rg/la/yk/rglaykolo16aiaflox9f_i2brb8.png"/></p><br/>
#  <p>Компонентные фреймворки независимо от названия никогда не покинут область только нишевого использования, если сообщество не будет создавать для них общедоступные компоненты, которые можно легко встроить в свой проект. </p><br/>
#  <p>За последние года полтора для фреймворка Svelte уже создано множество различных компонентов, которые можно найти на <a href="https://www.npmjs.com/search?q=svelte" rel="nofollow noopener noreferrer">NPM</a>, <a href="https://github.com/search?q=svelte" rel="nofollow noopener noreferrer">GitHub</a> или <a href="https://sveltesociety.dev/components/" rel="nofollow noopener noreferrer">официальном списке</a>. К сожалению, не все из них правильно "приготовлены" и порой их использование раздует размер бандла приложения сильнее, чем должно быть. А бывает, что такие пакеты просто невозможно использовать, потому что его автор не силён в подготовке пакетов и упустил какие-то важные моменты. </p><br/>
#  <p>В этой статье я расскажу как сделать и опубликовать npm-пакет со Svelte-компонентом так, чтобы им смогли воспользоваться все желающие, не получив при этом головной боли от неожиданных проблем.</p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/541834/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_91,h_357,h_22278" id="infopanel_post_541834">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 2: ↑2 и ↓0">+2</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541834" data-post-type="publish_ugc_ru,h_91,h_357,h_22278" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">8</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">444</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/541834/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">1</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
# ...
#  <span class="user-info__nickname user-info__nickname_small">honyaki</span>
#  </a>
#  <span class="post__time">сегодня в 13:59</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/skillfactory/blog/540300/">Как учить рекурсию разработчикам программного обеспечения</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/skillfactory/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании SkillFactory'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании SkillFactory</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/javascript/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'JavaScript'); }" rel="nofollow" title="Вы не подписаны на этот хаб">JavaScript</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <h3>Пришло время переосмыслить обучение рекурсии с помощью реальных кейсов вместо элегантных математических уравнений</h3><br/>
#  <a href="https://habr.com/ru/company/skillfactory/blog/540300/"><div style="text-align:center;"><img src="https://habrastorage.org/webt/xn/ks/_u/xnks_ux9bsmlszxh1tjc1wei84c.png"/></div></a><br/>
#  <br/>
#  Для программистов, особенно программистов-самоучек, первое знакомство с миром «рекурсии» в основном связано с математикой. При упоминании рекурсии программисты сразу вспоминают некоторые из наших любимых слов на F – нет, не те самые слова на F, а:<br/>
#  <br/>
#  <strong>Фибоначчи</strong><br/>
#  <br/>
#  <pre><code class="javascript">function fibonacci(position) {
#   if (position &lt; 3) return 1;
#   return fibonacci(position - 1) + fibonacci(position - 2);
#  }
#  </code></pre><br/>
#  <strong>Факториал</strong><br/>
#  <br/>
#  <pre><code class="javascript">function factorial(num) {
#   if (num === 1) return num;
#   return num * factorial(num - 1);
#  }
#  </code></pre><br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/skillfactory/blog/540300/#habracut">Приятного чтения!</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_skillfactory,h_357,h_359,h_20696" id="infopanel_post_540300">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 13: ↑10 и ↓3">+7</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="540300" data-post-type="publish_corp_ru,c_skillfactory,h_357,h_359,h_20696" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">22</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,5k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/skillfactory/blog/540300/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">5</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/gomon_yuriy/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/6e0/f37/8ac/6e0f378acbf9fa01a1adb1c7e71e2fdd.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">gomon_yuriy</span>
#  </a>
#  <span class="post__time">сегодня в 13:57</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/541806/">BA дайджест, январь 2021: как отклонять feature request и оценивать стоимость ошибки в БП</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/analysis_design/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Анализ и проектирование систем'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Анализ и проектирование систем</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/productpm/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Управление продуктом'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Управление продуктом</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">Из песочницы</a></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v2">
#  <p>Всем привет! Меня зовут Юра, я BA Tech Lead в NIX, а это – первый выпуск дайджеста для бизнес-аналитиков. В нем вы найдете, на мой взгляд, ценные и достойные внимания материалы за прошлый месяц. Enjoy!</p><p><em>В скобках возле заголовков – уровень сложности статьи (Normal * → Hard </em><strong><em> → </em></strong><em>Expert ***) и примерное время на изучение материала.</em></p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/541806/#habracut">Читать далее</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_397,h_20726" id="infopanel_post_541806">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 3: ↑3 и ↓0">+3</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541806" data-post-type="publish_ugc_ru,h_397,h_20726" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">2</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">157</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/541806/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/marshinov/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/f33/8f7/4c7/f338f74c736571017d86fe79fcaa1965.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">marshinov</span>
#  </a>
#  <span class="post__time">сегодня в 13:48</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/jugru/blog/541362/">Модели памяти C++ и CLR</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/jugru/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании JUG Ru Group'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании JUG Ru Group</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/net/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', '.NET'); }" rel="nofollow" title="Вы не подписаны на этот хаб">.NET</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/cpp/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'C++'); }" rel="nofollow" title="Вы не подписаны на этот хаб">C++</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/csharp/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'C#'); }" rel="nofollow" title="Вы не подписаны на этот хаб">C#</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/parallel_programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Параллельное программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Параллельное программирование</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <p>Это расшифровка-перевод <a href="https://youtu.be/6wZVpg2SyJQ" rel="nofollow noopener noreferrer">доклада</a> Саши Гольдштейна, признанного лучшим на конференции <a href="https://habr.com/ru/company/jugru/blog/314224/">DotNext 2016 Piter</a>. С годами этот доклад стал лишь актуальнее прежнего: появление Mac на ARM-процессорах — еще один пример, почему разработчикам сегодня нужно думать не только о x86-архитектуре.</p><br/>
#  <p><img src="https://habrastorage.org/files/426/16b/55b/42616b55beca4be89bf3b5a2faefe303.jpg"/></p><br/>
#  <p>Речь пойдет о проблемах, с которыми вы можете столкнуться при написании многопоточного кода, если вы думаете, что достаточно умны, чтоб спроектировать свои собственные механизмы синхронизации.</p><br/>
#  <p>То, что подходит процессорам Intel на архитектурах x86 и x86-64, может не подойти другой архитектуре. Как только вы перенесете свой код на другой процессор, например, на ARM для iPhone и Android, есть вероятность, что он перестанет работать как надо. Проблемы могут быть как очевидными (воспроизводиться с первого-второго раза), так и не очень (возникать только раз в миллион итераций). Вполне вероятно, что такие баги могут добраться до продакшна. Сегодня .NET и, конечно, C++ можно использовать не только на Windows и Intel, но и на других платформах, так что доклад будет полезен многим разработчикам.</p><br/>
#  <blockquote>Дисклеймер: данная статья предназначена для продвинутых читателей. Смотрите на свой страх и риск. За частое упоминание барьеров памяти и изменения порядка исполнения инструкций она получила возрастное ограничение 18+.</blockquote>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/jugru/blog/541362/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_jugru,h_546,h_559,h_17718,h_17822" id="infopanel_post_541362">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 20: ↑19 и ↓1">+18</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="541362" data-post-type="publish_corp_ru,c_jugru,h_546,h_559,h_17718,h_17822" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">40</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,6k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/jugru/blog/541362/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/60214110/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>]

# %%
for post in posts:
    post_id = post.parent.attrs.get('id')
   # если идентификатор не найден, это что-то странное, пропускаем
    if not post_id:
        continue
    post_id = int(post_id.split('_')[-1])
    print('post', post_id)
    hubs = post.find_all('a', class_='hub-link')
# Out:
# post 541820
# post 541856
# post 538144
# post 541848
# post 541840
# post 541800
# post 541812
# post 541624
# post 541834
# post 541832
# post 541750
# post 539962
# post 541804
# post 541816
# post 541810
# post 541672
# post 541650
# post 540300
# post 541806
# post 541362

# %%
# добавляем извлечение хабов из постов, чтобы отбирать только нужные
for post in posts:
    post_id = post.parent.attrs.get('id')
   # если идентификатор не найден, это что-то странное, пропускаем
    if not post_id:
        continue
    post_id = int(post_id.split('_')[-1])
    hubs = post.find_all('a', class_='hub-link')
    for hub in hubs:
            hub_lower = hub.text.lower()
           # ищем вхождение хотя бы одного желаемого хаба
            if any([hub_lower in desired for desired in DESIRED_HUBS]):
               # пост нам интересен - делаем с ним все что захотим:
               # можно отправит в телеграм уведомление, можно на почту и т.п.
                title_element = post.find('a', class_='post__title_link')
                print(title_element.text, title_element.attrs.get('href'))
               # так как пост уже нам подошел - дальше нет смысла проверять хабы
                break
# Out:
# 12 примеров улучшения кода с помощью @dataclass https://habr.com/ru/company/otus/blog/541812/
# Анализируем время ответа собеседника https://habr.com/ru/company/ruvds/blog/541750/
# Как получилось, что 0,1 + 0,2 = 0,30000000000000004? https://habr.com/ru/post/541816/

# %% [markdown]
# ## Практика 2. Напишем скрипт, который будет собирать новости с сайта Коммерсанта

# %%
URL = 'https://www.kommersant.ru/search/results'
params = {
    'search_query': 'python'
}

# %%
res = requests.get(URL, params)

# %%
res.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html class="no-js" lang="ru"  >\r\n<head>\r\n<title>Коммерсантъ: последние новости России и мира</title>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1" />\r\n<meta charset="utf-8"/>\r\n\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <script> if (document.cookie.indexOf(\'IsNonMobileViewport\') >= 0){document.write(\'<meta name="viewport" content="width=1200">\')}</script>\r\n\r\n<meta name="format-detection" content="telephone=no" />\r\n<meta name="title" content="Коммерсантъ: последние новости России и мира" />\r\n\r\n<meta name="description" content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" />\r\n\r\n<meta name="keywords" content="Новости,Политика,Экономика,Бизнес,Финансы,Дело,Биржа,Рынок,Акции,Прогнозы,Критика,Интервью,Рейтинги,Документы,Деньги,Власть,Автопилот,Тематические страницы,Первые лица,Деловые новости,Мировая практика,Культура,Спорт,Weekend,Астрологический прогноз,Погода мира,Курсы валют ЦБ РФ" />\r\n\r\n\r\n\r\n\r\n<link rel="apple-touch-icon" sizes="57x57" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-57x57.png">\r\n<link rel="apple-touch-icon" sizes="60x60" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-60x60.png">\r\n<link rel="apple-touch-icon" sizes="72x72" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-72x72.png">\r\n<link rel="apple-touch-icon" sizes="76x76" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-76x76.png">\r\n<link rel="apple-touch-icon" sizes="114x114" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-114x114.png">\r\n<link rel="apple-touch-icon" sizes="120x120" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-120x120.png">\r\n<link rel="apple-touch-icon" sizes="144x144" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-144x144.png">\r\n<link rel="apple-touch-icon" sizes="152x152" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-152x152.png">\r\n<link rel="apple-touch-icon" sizes="180x180" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-180x180.png">\r\n<link rel="icon" type="image/png" href="https://im.kommersant.ru/ContentFlex/images/favicons/favicon-32x32.png" sizes="32x32">\r\n<link rel="icon" type="image/png" href="https://im.kommersant.ru/ContentFlex/images/favicons/android-chrome-192x192.png" sizes="192x192">\r\n<link rel="icon" type="image/png" href="https://im.kommersant.ru/ContentFlex/images/favicons/favicon-16x16.png" sizes="16x16">\r\n<link rel="manifest" href="/manifest.json">\r\n<link rel="mask-icon" href="https://im.kommersant.ru/ContentFlex/images/favicons/safari-pinned-tab.svg" color="#5bbad5">\r\n<meta name="msapplication-TileColor" content="#2d89ef">\r\n<meta name="msapplication-TileImage" content="https://im.kommersant.ru/ContentFlex/images/favicons/mstile-144x144.png">\r\n<meta name="theme-color" content="#ffffff">\r\n\r\n<link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/css/kommersant.css?2012171311361152" charset="utf-8" />\r\n<link rel="stylesheet" href="/ContentFlex/modules/dist/main.css?2010151416382564"/>\r\n\r\n\r\n\r\n\t<link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/css/search.css?2004101325128136" charset="utf-8" />\r\n\t<link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/css/nano.css?1805180023023693" charset="utf-8" />\r\n\t<link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/css/datepicker.css?2006291815442276" charset="utf-8" />\r\n\r\n\r\n<script>\r\n\twindow.puids = {\r\n\t\t\'puid1\': \'0\',\r\n\t\t\'puid2\': \'\',\r\n\t\t\'puid3\': \'\',\r\n\t\t\'puid4\': \'i0\',\r\n\t\t\'puid5\': \'999\'\r\n\t};\r\n</script>\r\n\r\n<!--[if lt IE 10]>\r\n<script src="https://im.kommersant.ru/ContentFlex/js/html5.js?1602191901594361" ...

# %%
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="ru">
# <head>
# <title>Коммерсантъ: последние новости России и мира</title>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script> if (document.cookie.indexOf('IsNonMobileViewport') >= 0){document.write('<meta name="viewport" content="width=1200">')}</script>
# <meta content="telephone=no" name="format-detection">
# <meta content="Коммерсантъ: последние новости России и мира" name="title"/>
# <meta content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" name="description"/>
# <meta content="Новости,Политика,Экономика,Бизнес,Финансы,Дело,Биржа,Рынок,Акции,Прогнозы,Критика,Интервью,Рейтинги,Документы,Деньги,Власть,Автопилот,Тематические страницы,Первые лица,Деловые новости,Мировая практика,Культура,Спорт,Weekend,Астрологический прогноз,Погода мира,Курсы валют ЦБ РФ" name="keywords"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="https://im.kommersant.ru/ContentFlex/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#2d89ef" name="msapplication-TileColor"/>
# <meta content="https://im.kommersant.ru/ContentFlex/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <link charset="utf-8" href="https://im.kommersant.ru/ContentFlex/css/kommersant.css?2012171311361152" rel="stylesheet">
# <link href="/ContentFlex/modules/dist/main.css?2010151416382564" rel="stylesheet">
# <link charset="utf-8" href="https://im.kommersant.ru/ContentFlex/css/search.css?2004101325128136" rel="stylesheet">
# <link charset="utf-8" href="https://im.kommersant.ru/ContentFlex/css/nano.css?1805180023023693" rel="stylesheet">
# <link charset="utf-8" href="https://im.kommersant.ru/ContentFlex/css/datepicker.css?2006291815442276" rel="stylesheet">
# <script>
# 	window.puids = {
# 		'puid1': '0',
# 		'puid2': '',
# 		'puid3': '',
# 		'puid4': 'i0',
# 		'puid5': '999'
# 	};
# </script>
# <!--[if lt IE 10]>
# <script src="https://im.kommersant.ru/ContentFlex/js/html5.js?1602191901594361"></script>
# <![endif]-->
# <script src="https://im.kommersant.ru/ContentFlex/js/jquery.js?1909251636130903"></script>
# <script src="https://im.kommersant.ru/ContentFlex/js/jquery.slider.js?2001161735525013"></script>
# <script src="https://im.kommersant.ru/ContentFlex/js/thirdparty.js?1903131721122656"></script>
# <script src="https://im.kommersant.ru/ContentFlex/js/kommersant.js?2102101843279737"></script>
# <script>
# 	kommersant.antiCache.cssComments = 'https://im.kommersant.ru/contentflex/css/comments.css?1907031808048203';
# 	kommersant.antiCache.cssGallery = 'https://im.kommersant.ru/contentflex/css/gallery.css?2012101336567584';
# 	kommersant.antiCache.ajaxCommentsTemplates = 'https://im.kommersant.ru/contentflex/ajax/comments/templates.html?1907081648178126';
# 	kommersant.antiCache.ajaxTemplates = 'https://im.kommersant.ru/contentflex/ajax/templates.html?2011251524199429';
# 	kommersant.antiCache.jsComments = 'https://im.kommersant.ru/contentflex/js/jquery.comments.js?2101261919186947';
# 	kommersant.antiCache.jsMark = 'https://im.kommersant.ru/contentflex/js/jquery.mark.min.js?1709081838214160';
# 	kommersant.antiCache.jsJqueryValidate = 'https://im.kommersant.ru/contentflex/js/jquery.validate.min.js?1709141923191971';
# 	kommersant.antiCache.jsMaillist = 'https://im.kommersant.ru/contentflex/js/maillist.js?1904101922353593';
# 	kommersant.antiCache.jsFmCommon = 'https://im.kommersant.ru/contentflex/js/fm_common3.js?1811132002129980';
# 	kommersant.antiCache.jsNanoScroller = 'https://im.kommersant.ru/contentflex/js/jquery.nanoscroller.min.js?1607262006591093';
# 	kommersant.antiCache.jsScrollMagic = 'https://im.kommersant.ru/contentflex/js/scrollmagic/ScrollMagic.min.js?1602191902421794';
# 	kommersant.antiCache.jsHighmapsCisDisputed = 'https://im.kommersant.ru/contentflex/js/highmaps/cis-disputed.js?1902041433508578';
# 	kommersant.antiCache.jsCharts = 'https://im.kommersant.ru/contentflex/js/charts.js?2101262054090896';
# 	kommersant.antiCache.jsWidgets = 'https://im.kommersant.ru/contentflex/js/widgets.js?2101261924547750';
# 	kommersant.antiCache.jsHighmapsWorldDisputed = 'https://im.kommersant.ru/contentflex/js/highmaps/world-disputed.js?1903011850417031';
# 	kommersant.antiCache.viconsComments = 'https://im.kommersant.ru/contentflex/ajax/vicons/comments.html?1907031809599085';
# 	kommersant.vicons.add('https://im.kommersant.ru/contentflex/ajax/vicons/common.html?2008241546221862', {cache: true});
# </script>
# <link crossorigin="" href="https://ads.betweendigital.com" rel="preconnect"/>
# <script async="" src="https://yastatic.net/pcode/adfox/header-bidding.js"></script>
# <script src="https://im.kommersant.ru/banners/hb2020/hb.js?2101121629102401"></script>
# <script crossorigin="anonymous" src="https://yastatic.net/pcode/adfox/loader.js"></script>
# <script>
# (function() {
# var hm = document.createElement('script'); hm.type ='text/javascript'; hm.async = true;
# hm.src = ('++u-heatmap-it+log-js').replace(/[+]/g,'/').replace(/-/g,'.');
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(hm, s);
# })();
# </script>
# <script type="text/javascript">
# kommersant.user.subscriptionTypes = [{"Id":1,"Name":"Подписка на срочные новости","Title":"Срочные новости в течение дня в рассылке «Коммерсантъ»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":["news.yandex.ru","news.yandex.kz","news.yandex.by","news.yandex.ua","news-clck.yandex.ru"],"Publishing":null,"Region":null},"Priority":1,"LogoHtml":"","ClassSubscriptionPopupContent":""},{"Id":2,"Name":"Подписка на Weekend","Title":"Подпишитесь на&nbsp;рассылку<br> «Свежий номер Коммерсантъ Weekend»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":14,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"weekend"},{"Id":3,"Name":"Подписка на Деньги","Title":"Подпишитесь на&nbsp;рассылку<br> материалов «Коммерсантъ Деньги»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":3,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"money"},{"Id":4,"Name":"Подписка на Огонёк","Title":"Подпишитесь на&nbsp;рассылку<br> «Свежий номер Огонёк»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":84,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"ogonek"},{"Id":5,"Name":"Подписка на Власть","Title":"Подпишитесь на&nbsp;рассылку<br> материалов «Коммерсантъ Власть»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":2,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"vlast"},{"Id":6,"Name":"Подписка на газету","Title":"Подпишитесь на&nbsp;рассылку","SubTitle":"Свежий номер газеты<br><strong>Коммерсантъ</strong>","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":1,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"newspaper"},{"Id":7,"Name":"Подписка на дайджест новостей региона Пермь","Title":"Подпишитесь на&nbsp;дайджест<br> новостей в рассылке «Коммерсантъ Пермь»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":null,"Region":59},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"region"},{"Id":8,"Name":"Подписка на дайджест новостей региона Самара","Title":"Подпишитесь на&nbsp;дайджест<br> новостей в рассылке «Коммерсантъ Самара»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":null,"Region":63},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"region"},{"Id":9,"Name":"Подписка на дайджест новостей региона Волгоград","Title":"Подпишитесь на&nbsp;дайджест<br> новостей в рассылке «Коммерсантъ Волгоград»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":null,"Region":34},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupCon ...
# </script>
# <script>window.last_time_update = 1612989431;</script>
# <script charset="utf-8" src="https://im.kommersant.ru/ContentFlex/js/jquery.nanoscroller.min.js?1607262006591093"></script>
# <script charset="utf-8" src="https://im.kommersant.ru/ContentFlex/js/jquery.datepicker.min.js?1706281831581406"></script>
# </link></link></link></link></link></meta></head>
# <body class="">
# <div id="counters-top" style="position: absolute; visibility: hidden">
# <script>
# (function () {
# 	window.kommersantAnalytics = {
# 		adblock: '',
# 		rubrics: '',
# 		publishing: '',
# 		themes: '',
# 		themegroups: '',
# 		authors: '',
# 		audio: 'No',
# 		liveinternet: ''
# 	};
# 	var advad = new Image();
# 	advad.onload = function () {
# 		window.kommersantAnalytics.adblock = 'No';
# 	};
# 	advad.onerror = function () {
# 		window.kommersantAnalytics.adblock = 'Yes';
# 	};
# 	advad.src = 'https://im.kommersant.ru/ContentFlex/images/adv.gif';
# })();
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K37VX3" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
# 	(function (w, d, s, l, i) {
# 		w[l] = w[l] || []; w[l].push({ 'gtm.start':
# new Date().getTime(), event: 'gtm.js'
# 		}); var f = d.getElementsByTagName(s)[0],
# j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-K37VX3');
# </script>
# <!-- End Google Tag Manager -->
# <!-- Kommersant -->
# <script>
# function counterKommersant() {
# //new Image().src = '//www.kommersant.ru/headerfooter/counterA?p=0&ref=' + escape(document.referrer) + '&rnd=' + Math.floor(Math.random() * 1000000000);
# }
# function counterKommersantRead() {
#
# }
# counterKommersant();
# counterKommersantRead();
# </script>
# <noscript>
# </noscript>
# <!-- /Kommersant -->
# <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "84394", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
# if (d.getElementById(id)) return;
# var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
# ts.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//top-fwz1.mail.ru/js/code.js";
# var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
# if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="" src="//top-fwz1.mail.ru/counter?id=84394;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# <!--LiveInternet counter-->
# <script>
# function counterLiveInternet() {
# 	new Image().src = "//counter.yadro.ru/hit" + (window.kommersantAnalytics.liveinternet ? ";" + window.kommersantAnalytics.liveinternet : "") + "?r" + escape(document.referrer) + ((typeof (screen) == "undefined") ? "" : ";s" + screen.width + "*" + screen.height + "*" + (screen.colorDepth ? screen.colorDepth : screen.pixelDepth)) + ";u" + escape(document.URL) + ";h" + escape(document.title.substring(0, 80)) + ";" + Math.random();
# }
# counterLiveInternet();
# </script>
# <noscript>
# <img alt="" height="1" src="//counter.yadro.ru/hit" width="1"/>
# </noscript>
# <!--/LiveInternet-->
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
# 	var yaParams = {
#
# };
# </script>
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
# ym(153166, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash: true,
# 	params: yaParams
# });
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/153166" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <img id="advad" src="https://im.kommersant.ru/ContentFlex/images/adv.gif" style="display: none"/>
# <script>
# (function (i, s, o, g, r, a, m) {
# i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# (i[r].q = i[r].q || []).push(arguments)
# }, i[r].l = 1 * new Date(); a = s.createElement(o),
# m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
# ga('create', 'UA-875277-5', 'kommersant.ru');
#
# ga('set', 'dimension6', 'No');
# if (window.kommersantAnalytics.adblock) {
# 	ga('set', 'dimension3', window.kommersantAnalytics.adblock || null);
# }
# ga('send', 'pageview');
# </script>
# <!-- tns-counter.ru -->
# <script>
# function counterTns() {
# new Image().src = '//www.tns-counter.ru/V13a***R>' + document.referrer.replace(/\*/g, '%2a') + '*kommersant_ru/ru/CP1251/tmsec=komm_online/' + Math.floor(Math.random() * 900000000 + 100000000);
# }
# counterTns();
# </script>
# <noscript>
# <img alt="" height="1" src="//www.tns-counter.ru/V13a****kommersant_ru/ru/CP1251/tmsec=komm_online/" width="1"/>
# </noscript>
# <!--/tns-counter.ru -->
# <!-- ttsmi2 -->
# <script>
# var ttsmi2_data = {siteid: 40723, count: "site"};
# (function() {
# var sc = document.createElement("script");
# sc.type = "text/javascript";
# sc.async = true;
# sc.src = "//target.smi2.net/client/target.js";
# var s = document.getElementsByTagName("script")[0];
# s.parentNode.insertBefore(sc, s);
# }());
# </script>
# <!--/ttsmi2 -->
# </div>
# <script>
# function countersUpdate() {
# 	counterKommersant();
# 	counterKommersantRead();
#
# 	try {
# 		_tmr.push({id: '84394', type: 'pageView', url: document.URL, start: (new Date()).getTime()});
# 	} catch (ignore) {}
#
# 	counterLiveInternet();
#
# 	(function () {
# 		var yaParams = {};
# 		window.kommersantAnalytics.rubrics && (yaParams.rubric = window.kommersantAnalytics.rubrics);
# 		window.kommersantAnalytics.publishing && (yaParams.publication = window.kommersantAnalytics.publishing);
# 		window.kommersantAnalytics.themes && (yaParams.theme = window.kommersantAnalytics.themes);
# 		window.kommersantAnalytics.themegroups && (yaParams.maintheme = window.kommersantAnalytics.themegroups);
# 		try {
# 			ym(153166, 'params', yaParams);
# 			ym(153166, 'hit', window.location.pathname + window.location.search + window.location.hash, {
# 				params: yaParams
# 			});
# 		} catch (ignore) {}
# 	})();
#
# 	(function () {
# 		try {
# 			ga('set', 'page', window.location.pathname + window.location.search + window.location.hash);
# 			ga('set', 'dimension1', window.kommersantAnalytics.rubrics || null);
# 			ga('set', 'dimension2', window.kommersantAnalytics.publishing || null);
# 			ga('set', 'dimension4', window.kommersantAnalytics.themes || null);
# 			ga('set', 'dimension5', window.kommersantAnalytics.themegroups || null);
# 			ga('set', 'dimension8', window.kommersantAnalytics.authors || null);
# 			ga('set', 'dimension6', window.kommersantAnalytics.audio || null);
# 			ga('set', 'dimension3', window.kommersantAnalytics.adblock || null);
# 			ga('send', 'pageview');
# 		} catch (ignore) {}
# 	})();
#
# 	counterTns();
#
# 	try {
# 		smi2Tracker.track(ttsmi2_data);
# 	} catch (ignore) {}
#
# 	try {
# 		counterIo();
# 	} catch (ignore) { }
# }
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / 0Десктоп / BackGround test-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: BackGround-->
# <div id="adfox_153864371043563488"></div>
# <script>
#
# window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_153864371043563488',
#         params: Object.assign({
#             p1: 'cbuhy',
#             p2: 'gbom',
#           }, window.puids || {}),
#          onRender: function () {$('.adfox-banner-background').after('<style>.adv3-2_140pxx1200px {display: none;}@media only screen and (min-width: 1200px) {body {padding-top: 240px;}.main_nav {max-width: 1180px;width: 100%;margin-left: auto;margin-right: auto;}.bg_cover {position: absolute;top: 240px;right: 0;left: 0;bottom: 0;background-color: #fff;width: 1180px;margin: 0 auto;}}</style><div class="bg_cover"></div>')}
#
#        }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#             }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / Web / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Fullscreen-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489746795378030"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489746795378030',
#         params: Object.assign({
#             p1: 'bwuyh',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekubo'
#         }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#    );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / Fullscreen-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: Fullscreen_redesign_test-->
# <div id="adfox_160803209609717001"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_160803209609717001',
#         params: Object.assign({
#             p1: 'blnry',
#             p2: 'eurl'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / Tablet / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Tablet_FullScreen Tablet-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489757566528014"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489757566528014',
#         params: Object.assign({
#             p1: 'bwvch',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekuxl',
#         }, window.puids || {})
#  }, ['tablet'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Планшет / FullScreen Tablet-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: Fullscreen_redesign_test-->
# <div id="adfox_1486107887739357"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1486107887739357',
#         params: Object.assign({
#             p1: 'buggw',
#             p2: 'eurl'
#         }, window.puids || {})
#     }, ['tablet'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / mobile / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Mobile_Full Screen Mobile-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489754877765270"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1489754877765270',
#         params: Object.assign({
#             p1: 'bwvcg',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekusj'
#         }, window.puids || {})
#     }, ['phone'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Мобильный / Full Screen Mobile-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: Fullscreen_redesign_test-->
# <div id="adfox_1486107930501960"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1486107930501960',
#         params: Object.assign({
#             p1: 'buggv',
#             p2: 'eurl'
#         }, window.puids || {})
#     }, ['phone'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# <div class="adv3-1_910pxx110px hide1 hide2">
# </div>
# <header class="main_header">
# <nav class="navmenu hide1 hide2">
# <div class="main_nav">
# <div class="layout main_header__inner">
# <div class="main_header__content">
# <div class="main_header__auth_nest">
# </div>
# </div>
# <div class="main_header__aside">
# <ul class="main_nav__list">
# <li class="main_nav__item">
# <a href="/daily?from=header_gazeta">Газета</a>
# </li>
# <li class="main_nav__item">
# <a href="/apps?from=header_prilozheniya">Приложения</a>
# </li>
# <li class="main_nav__item">
# <a href="/ogoniok?from=header_ogoniok">Огонёк</a>
# </li>
# <li class="main_nav__item">
# <a href="/weekend?from=header_weekend">Weekend</a>
# </li>
# <li class="main_nav__item">
# <a class="navmenu-toggle" data-navmenu-id="top-regions" href="/regions?from=header_regions">Регионы</a>
# </li>
# <li class="main_nav__item">
# <a href="/autopilot?from=header_autopilot">Автопилот</a>
# </li>
# <li class="main_nav__item">
# <a href="/nauka?from=header_nauka">Наука</a>
# </li>
# <li class="main_nav__item">
# <a href="http://www.kommersant.uk" target="_blank">UK</a>
# </li>
# <li class="main_nav__item">
# <a class="main_nav_menu__item-name" href="/fm?from=header_fm">
# <img alt="fm radio" class="main_nav_menu__item_logo" src="https://im.kommersant.ru/ContentFlex/images/logos/ico_fm_l.svg"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="main_nav_menu navmenu-item" id="navmenu-top-regions">
# <div class="layout">
# <ul class="main_nav_menu__list">
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/78">Санкт-Петербург</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/36">Воронеж</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/66">Екатеринбург</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/18">Ижевск</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/16">Казань</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/23">Краснодар</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/24">Красноярск</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/52">Нижний Новгород</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/54">Новосибирск</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/59">Пермь</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/61">Ростов-на-Дону</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/63">Самара</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/64">Саратов</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/2">Уфа</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/74">Челябинск</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/76">Ярославль</a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="main_header__data_bar hide1 hide2">
# <div class="layout main_header__inner">
# <div class="main_header__content">
# <div class="main_header__auth_nest">
# <div class="b-auth_panel resize js-auth" data-resize-places=".main_header__auth_nest">
# <ul class="b-auth_panel-menu b-auth_panel__login">
# <li class="b-auth_panel-menu__item">
# <a class="b-auth_panel__link user-login" href="#">ВОЙТИ</a>
# </li>
# <li class="b-auth_panel-menu__item">
# <a class="user-register" href="#">Регистрация</a>
# </li>
# </ul>
# <ul class="b-auth_panel-menu b-auth_panel__exit">
# <li class="b-auth_panel-menu__item">
# <a href="/lk/profile?from=header_profil">ПРОФИЛЬ</a>
# </li>
# <li class="b-auth_panel-menu__item">
# <a class="user-logout" href="#">ВЫХОД</a>
# </li>
# </ul>
# <ul class="b-auth_panel-menu b-auth_panel__notification">
# <li class="b-auth_panel-menu__item">
# <a href="/LK/Subscriptions" title="Новые материалы по вашим подпискам">
# <span class="vicon vicon--notification">
# <svg class="vicon__body"><use xlink:href="#vicon-notification" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </a>
# <a href="/LK/Subscriptions">
# <span class="b-auth_panel-menu__notifications_count js-auth-notifications hide"></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_header__data">
# <span>10 февраля, среда</span>
# </div>
# </div>
# <div class="main_header__aside">
# <div class="main_header__special_rubric_nest hide3">
# </div>
# <ul class="main_nav__list hide1 hide2">
# <li class="main_nav__item main_nav__item--alt">
# <a href="https://www.kartoteka.ru/" target="_blank">Картотека</a>
# </li>
# <li class="main_nav__item main_nav__item--alt">
# <a href="https://bankruptcy.kommersant.ru" target="_blank">Банкротства</a>
# </li>
# <li class="main_nav__item main_nav__item--alt">
# <a href="/conference?from=header_konferencii">Конференции</a>
# </li>
# <li class="main_nav__item main_nav__item--alt">
# <a href="/subscription?from=header_podpiska">Подписка</a>
# </li>
# <li class="main_nav__item main_nav__item--alt">
# <a href="/photo?from=header_photo">Фотоагентство</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="main_header__logo_bar hide1 hide2">
# <div class="layout main_header__inner">
# <div class="main_header__content">
# <div class="main_header__logo">
# <a class="kbd_button" href="/?from=logo" tabindex="0">
# <div class="kbd_button__body" tabindex="-1">
# <svg aria-label="Kommersant.ru" class="main_header__main_logo"><use xlink:href="#vicon-main_logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </div>
# </a>
# </div>
# </div>
# <div class="main_header__aside">
# <div class="fm_announce__nest">
# </div>
# </div>
# </div>
# </div>
# <nav class="layout main_header__special hide1 hide2">
# <div class="main_header__inner">
# <div class="main_header__content">
# <ul class="main_nav__list">
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/47">Страна</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/5">Мир</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/3">Экономика</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/4">Бизнес</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/finance">Финансы</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/realty">Недвижимость</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/8">Культура</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/9">Спорт</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/hitech">Hi-Tech</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/auto">Авто</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/style">Стиль</a>
# </li>
# <li class="main_nav__item main_nav__item--search place-search">
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="adv3-1_910pxx110px hide1 hide2" style="margin-bottom: 10px">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / Web / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_100%x240 Перетяжка-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489746521107767"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1489746521107767',
#         params: Object.assign({
#             p1: 'bwuyh',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekueg'
#         }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / BILB I (970_250) Перетяжка-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: BILB I (100%x240_top)-->
# <div id="adfox_160803211171647429"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_160803211171647429',
#         params: Object.assign({
#             p1: 'blnrl',
#             p2: 'eurc',
#             pk: 'пожар торговом центре Кемерово Кемеровский зимняя вишня',
#             pke: '1'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# <div class="mobile_header hide3">
# <!-- верхняя часть шапки -->
# <div class="mobile_header__menu">
# <button class="kbd_button mobile_header__button mobile_header__burger popup_menu__toggle" tabindex="0" title="Меню">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon--burger">
# <svg class="vicon__body">
# <use xlink:href="#vicon-burger" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </div>
# </button>
# <div class="mobile_header__middle">
# <a class="kbd_button mobile_header__logo" href="/?from=mobile_logo" tabindex="0">
# <div class="kbd_button__body" tabindex="-1">
# <svg class="mobile_header__logo_image">
# <use xlink:href="#vicon-main_logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </a>
# </div>
# <div class="place-search mobile_header__button mobile_header__search">
# <div class="search_window resize" data-resize-places=".place-search" id="navsearch">
# <form action="/search/results" id="navsearch-form" method="get">
# <input name="places" type="hidden" value=""/>
# <input name="categories" type="hidden" value=""/>
# <input name="datestart" type="hidden" value="10.02.2020"/>
# <input name="dateend" type="hidden" value="10.02.2021"/>
# <input name="sort_type" type="hidden" value="1"/>
# <input name="regions" type="hidden" value=""/>
# <input name="results_count" type="hidden" value=""/>
# <input name="page" type="hidden" value="1"/>
# <div class="search__input_wrapper">
# <input class="search__input" id="navsearch-query" name="search_query" placeholder="Поиск по сайту" type="search"/>
# </div>
# <button class="kbd_button search__button mobile_header__button" id="navsearch-submit" tabindex="0" title="Поиск" type="submit">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon-search_empty">
# <svg class="vicon__body">
# <use xlink:href="#vicon-search_empty" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </div>
# </button>
# </form>
# </div>
# </div>
# </div>
# <div class="mobile_header__lk">
# <div class="mobile_header__button mobile_header__enter js-auth is_active">
# <button class="kbd_button mobile_header__button mobile_header__door user-login" tabindex="0" title="Войти" type="button">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon--enter">
# <svg class="vicon__body">
# <use xlink:href="#vicon-enter" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </div>
# </button>
# <a class="kbd_button mobile_header__button mobile_header__user" href="/lk/profile?from=mobile_profil" tabindex="0" title="Профиль">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon--user">
# <svg class="vicon__body">
# <use xlink:href="#vicon-user" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# <span class="mobile_header__user_text">Войти в профиль</span>
# <span aria-hidden="true" class="mobile_header__enter_notification js-auth-notifications hide"></span>
# </div>
# </a>
# </div>
# <div class="mobile_header__info">
# <time class="mobile_header__info_text">10 февраля, среда</time>
# </div>
# <div class="fm_announce__nest">
# <button class="kbd_button fm_announce resize" data-resize-places=".fm_announce__nest" tabindex="0" title="Слушать радио">
# <div class="kbd_button__body" tabindex="-1">
# <span class="fm_announce__text">Слушать радио</span>
# <div class="mobile_header__button hide3">
# <span class="vicon vicon--fm_mobile_play">
# <svg class="vicon__body"><use xlink:href="#fm_mobile_play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# <span class="vicon vicon--fm_mobile_pause">
# <svg class="vicon__body"><use xlink:href="#fm_mobile_pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </div>
# <span class="fm_announce__icon hide1 hide2"></span>
# </div>
# </button>
# </div>
# </div>
# </div>
# <div class="main_header__footer_line"></div>
# <div class="adv1-header_100p hide3">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / mobile / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Mobile_1000х600 сверху-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489755438758"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489755438758',
#         params: Object.assign({
#             p1: 'bwvcg',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekusk'
#         }, window.puids || {})
#        }, ['phone','tablet'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Мобильный / 1000х600 сверху-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 1000х600 сверху-->
# <div id="adfox_1488194504651863"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1488194504651863',
#         params: Object.assign({
#             p1: 'bukwz',
#              p2: 'fibq',
#             pk: 'пожар торговом центре Кемерово Кемеровский зимняя вишня',
#             pke: '1'
#         }, window.puids || {})
#     }, ['phone','tablet'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# </header>
# <div class="layout">
# <div class="grid grid--main">
# <div class="grid_cell grid_cell_small grid_cell_nogap hide1 hide2">
# <!-- Коротко (новости) -->
# <div class="place-newsline">
# <section class="b-newsline resize" data-resize-places=".place-newsline">
# <h3 class="title title-indent hide1 hide2"><a href="/news">Коротко</a></h3>
# <h3 class="title_light hide3"><a href="/news">Новости</a></h3>
# <ul class="b-newsline__list">
# <li class="b-newsline__item b-newsline__item--news-of-the-day">
# <article>
# <a href="/doc/4683583?from=hotnews" title="Новость часа">
# <span class="vicon vicon--hot_news">
# <svg class="vicon__body"><use xlink:href="#vicon-hot_news" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#
# <h3 class="article_subheader"><a href="/doc/4683595">NYT: в Джорджии начато уголовное расследование попыток Трампа отменить итоги выборов</a></h3>
# </article>
# </li>
# </ul>
# <div class="b-newsline__menu">
# <button class="b-newsline__menu_item b-newsline__menu_item__more ui_button ui_button--solid" type="button">
# 			ещё
# 			<span class="vicon vicon--gull_down">
# <svg class="vicon__body"><use xlink:href="#vicon-small_up_arrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </button>
# <a class="b-newsline__menu_item ui_button ui_button--solid" href="/archive/news?from=news">все новости</a>
# </div>
# </section>
# </div>
# <div class="hide1 hide2 place-voting">
# <section class="b-voting resize poll lazyloading" data-resize-places=".place-voting">
# <input type="hidden" value="/poll/last/1744">
# </input></section>
# </div>
# <div class="b-tgb_chain">
# <div class="b-tgb_chain__uho">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / ТГБ вертикальный 1-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: ТГБ вертикальный-->
# <div id="adfox_160803214564445466"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_160803214564445466',
#         params: Object.assign({
#             p1: 'btfzf',
#             p2: 'ffyl'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# <div class="b-tgb_chain__uho">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / ТГБ вертикальный 2-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: ТГБ вертикальный-->
# <div id="adfox_160803198623871979"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_160803198623871979',
#         params: Object.assign({
#             p1: 'btgny',
#             p2: 'ffyl'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# <div class="b-tgb_chain__uho">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / ТГБ вертикальный 3-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: ТГБ вертикальный-->
# <div id="adfox_160803179360872040"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_160803179360872040',
#         params: Object.assign({
#             p1: 'btgnz',
#             p2: 'ffyl'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# </div>
# </div>
# <div class="grid_cell grid_cell_large">
# <h3 class="title title-half">Поиск</h3>
# <div class="search js-search">
# <div class="search_rules_content js-search-rules">
# <button aria-labelledby="search_rules__header" class="kbd_button js-search-rules-close search_rules_close" role="dialog" tabindex="0" type="button">
# <span class="vicon kbd_button__body" tabindex="-1">
# <svg class="vicon__body"><use xlink:href="#vicon-collapse" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </button>
# <div class="nano">
# <div class="nano-content">
# <div class="search_rules__body">
# <h4 class="search_header" id="search_rules__header">Правила поиска</h4>
# <h5 class="search_subheader">В качестве поисковых терминов можно использовать:</h5>
# <ul class="search_list">
# <li class="search_list_item">отдельное слово;</li>
# <li class="search_list_item">несколько слов, разделенных пробелами (поиск документов, включающих все слова).</li>
# </ul>
# <h5 class="search_subheader">Поиск производится:</h5>
# <ul class="search_list">
# <li class="search_list_item">без учета строчных и прописных букв;</li>
# <li class="search_list_item">игнорируя знаки пунктуации.</li>
# </ul>
# <h5 class="search_subheader">Дополнительные условия:</h5>
# <ul class="search_list">
# <li class="search_list_item">в запрос могут быть включены операторы-связки (AND, OR, NOT) и оператор близости (NEAR);</li>
# <li class="search_list_item">слова запроса могут иметь символ обобщения (*), но только в конце слова;</li>
# <li class="search_list_item">слова при поиске интерпретируются с учетом словоформ;</li>
# <li class="search_list_item">для поиска по точной форме запроса этот запрос нужно указать в кавычках.</li>
# </ul>
# <h5 class="search_subheader">Замечания:</h5>
# <ul class="search_list">
# <li class="search_list_item">при использовании специальных символов (&amp;, |, ^, #, @, $, (, ), *) запрос следует взять в кавычки;</li>
# <li class="search_list_item">для поиска слов, заключенных в кавычки, весь запрос следует также заключить в кавычки.</li>
# </ul>
# <h5 class="search_subheader">Пример запроса и результаты поиска:</h5>
# <div class="search_rules_sample"><b>Запрос:</b> "банк "Империал""<br/>
# <b>Результат:</b> Статьи, включающие фразу «банк "Империал"»</div>
# <div class="search_rules_sample"><b>Запрос:</b> Курс and доллара<br/>
# <b>Результат:</b> Статьи, имеющие оба слова «курс», «доллара»</div>
# <div class="search_rules_sample"><b>Запрос:</b> Курс or "доллар*" or "высок"<br/>
# <b>Результат:</b> Статьи, включающие одно из слов — «курс», «доллар», «доллара», «долларов», «долларовая», «высокого», «высокому» и т.д.</div>
# </div>
# </div>
# <div class="nano-pane">
# <div class="nano-slider">
# </div>
# </div>
# </div>
# </div>
# <div class="search_holder search_holder--expanded_search more">
# <form action="/search/results" id="frmSearch" method="get" onsubmit="DoSearch()">
# <input id="places" name="places" type="hidden"/>
# <input id="categories" name="categories" type="hidden"/>
# <input id="isbankrupt" name="isbankrupt" type="hidden" value=""/>
# <input id="datestart" name="datestart" type="hidden"/>
# <input id="dateend" name="dateend" type="hidden"/>
# <input id="sort_type" name="sort_type" type="hidden"/>
# <input id="sort_dir" name="sort_dir" type="hidden"/>
# <input id="regions" name="regions" type="hidden"/>
# <input id="results_count" name="results_count" type="hidden"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="search_rules">
# <button class="kbd_button js-search-rules-button ui_link" tabindex="0" type="button">
# <span class="kbd_button__body search_rules_link" tabindex="-1">
# 					Правила поиска
# 				</span>
# </button>
# </div>
# <input class="search_input" name="search_query" placeholder="Поиск" type="text" value="python"/>
# <button class="kbd_button ui_button ui_button--solid search__search_button" tabindex="0" type="submit">
# <span class="kbd_button__body" tabindex="-1">
# 				Искать
# 			</span>
# </button>
# ...
# <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t218_150307.jpg" src="..."/>
# </picture>
# <noscript>
# <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t218_150307.jpg"/>
# </noscript>
# </a>
# </div>
# </div>
# <div class="text">
# <div class="search_results_stat">
# <span class="vicon vicon--article vicon--small">
# <svg class="vicon__body">
# <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <a href="/apps/126466" target="_blank">
# <span class="search_results_number">010</span>
# <span class="search_results_source">Приложение к газете "Коммерсантъ" №29 от 27.10.2020</span>
# </a>
# </div>
# <h2 class="article_name">
# <a href="/doc/4529711?query=python" target="_blank">В один клик</a>
# </h2>
# <h1 class="article_subheader">
# <a href="/doc/4529711?query=python" target="_blank">
# 									Huawei Honor Cup
# 								</a>
# </h1>
# <div class="article_intro">
# <a href="/doc/4529711?query=python" target="_blank">
# 									 ...  знания языка программирования <mark>Python</mark>, некоторые разделы высшей ...
# 								</a>
# </div>
# </div>
# </div>
# <ul class="search_pager">
# <li class="search_pager__previous_page"><span class="vicon vicon--small"><svg class="vicon__body"><use xlink:href="#vicon-gull_down" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span></li>
# <li class="search_pager__page search_pager__current_page">1</li>
# <li class="search_pager__page">
# <a href="/search/results?search_query=python&amp;page=2">2</a>
# </li>
# <li class="search_pager__page"><a href="/search/results?search_query=python&amp;page=3">3</a></li>
# <li class="search_pager__next_page active"><a href="/search/results?search_query=python&amp;page=2"><span class="vicon vicon--small"><svg class="vicon__body"><use xlink:href="#vicon-gull_down" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="adv3-14_910pxx110px hide1 hide2">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / Web / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: <tracking_100%х240 footer>-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489746313272902"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489746313272902',
#         params: Object.assign({
#             p1: 'bwuyh',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekisb'
#     }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#    );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Сквозное размещение / 100%х240 footer-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 100%x240_redesign_test_footer-->
# <div id="adfox_1486973896119987"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1486973896119987',
#         params: Object.assign({
#             p1: 'bwfpj',
#             p2: 'fmox',
#             pct: 'c',
#             pp: 'g'
#         }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# </div>
# <div class="adv3-2_140pxx1200px hide1 hide2">
# </div>
# <div class="grid hide3">
# <div class="grid_cell">
# <div class="place-voting"></div>
# <div class="place-company_news"></div>
# <div class="adv1-250x50 adv2-250x50 hide3" style="background-color: #ececee; margin-left: -15px; margin-right: -15px;">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / mobile / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Mobile_250/50 footer-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489754354727209"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489754354727209',
#         params: Object.assign({
#             p1: 'bwvcg',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekusg'
#         }, window.puids || {})
#      }, ['phone','tablet'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Мобильный / footer-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 100xAuto_mob-->
# <div id="adfox_150781180893298319"></div>
# <script>
#      window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_150781180893298319',
#         params: Object.assign({
#             p1: 'bwgav',
#             p2: 'evil',
#            }, window.puids || {})
#        }, ['phone','tablet'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# </div>
# </div>
# </div>
# <div class="layout">
# <footer class="main_footer" id="footer">
# <div class="main_footer_newspaper">
# <ul class="main_footer_control">
# <li class="main_footer_control__item">
# <a href="/LK/Feedback">Обратная связь</a>
# </li>
# <li class="main_footer_control__item" id="push-subscription-trigger"></li>
# <li class="main_footer_control__item fullversion hide1 hide2 hide">
# <a class="fullversion-link-off" href="#">Мобильная версия</a>
# </li>
# <li class="main_footer_control__item fullversion hide3">
# <a class="fullversion-link-on" href="#">Полная версия сайта</a>
# </li>
# </ul>
# <nav class="main_footer_nav_box">
# <ul class="main_footer_nav">
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/archive">Архив</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/authors">Авторы</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/themes">Темы</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/doc/3688126">Справочники</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/specials">Мультимедиа</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/interactive/tests">Тесты</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/lk/notification">Email-рассылки</a>
# </li>
# <li class="main_footer_nav__item main_footer_nav__item--br">
# <a class="main_footer_nav__link_info" href="/about">О «Коммерсанте»</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/redaction">Редакция</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/contacts">Контакты</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/digital">iOs&amp;Android</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/vacancies">Вакансии</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/copyright">Правовая информация</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_adv" href="/ad">Реклама</a>
# </li>
# </ul>
# <a class="main_footer_partner" href="https://regions.eisr.ru/" target="_blank">Партнер «Ъ» — Навигатор по российским региональным практикам ЭИСИ</a>
# </nav>
# <div class="main_footer_hand_history">
# <a href="/doc/3882478">
# <picture class="js-lazyimage">
# <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/CorpImages/Custom/new_footer/hand_4x.png" src="..."/>
# </picture>
# <noscript>
# <img alt="" class="fallback_image" src="https://im.kommersant.ru/CorpImages/Custom/new_footer/hand_4x.png"/>
# </noscript>
# </a>
# </div>
# </div>
# <div class="main_footer_commerce">
# <div class="main_footer_commerce__item adv_warn">
# <div class="adv_marker adv_warn__body">
# 				Материалы с такой меткой, партнерские проекты и новости компаний опубликованы на коммерческой основе
# 			</div>
# </div>
# <ul class="main_footer_commerce__item main_footer_icons network">
# <li class="main_footer_icons__item">
# <a href="https://www.facebook.com/kommersant.ru" target="_blank">
# <span class="vicon vicon--fb vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-fb_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://vk.com/kommersant_ru" target="_blank">
# <span class="vicon vicon--vk vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-vk_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://www.instagram.com/kommersant_online/" target="_blank">
# <span class="vicon vicon--ig vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-ig_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://twitter.com/#!/kommersant" target="_blank">
# <span class="vicon vicon--tw vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-tw_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://ok.ru/group/53942273310836" target="_blank">
# <span class="vicon vicon--ok vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-ok_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://t.me/kommersant" target="_blank">
# <span class="vicon vicon--tg vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-tg_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://invite.viber.com/?g2=AQASKm3nkHYfLUfAeChUPQpUmuFiN6WagC%2B%2FFdwldgMHhadaBSbY6LiIYBwfMnfV" target="_blank">
# <span class="vicon vicon--vb vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-vb_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://flipboard.com/@Kommersant" target="_blank">
# <span class="vicon vicon--flipboard vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-flipboard" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="http://subscribe.ru/author/24276108/list" target="_blank">
# <span class="vicon vicon--subscribe_service vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-subscribe-service" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item main_footer_icons__item_years">16+</li>
# </ul>
# <ul class="main_footer_commerce__item main_footer_counters hide1 hide2">
# <li class="main_footer_counters__item">
# <!-- Rating@Mail.ru logo -->
# <a href="http://top.mail.ru/jump?from=84394" target="_blank">
# <img alt="Рейтинг@Mail.ru" height="31" src="//top-fwz1.mail.ru/counter?id=84394;t=487;l=1" style="border: 0;" width="88"/>
# </a>
# <!-- //Rating@Mail.ru logo -->
# </li>
# <li class="main_footer_counters__item">
# <!--LiveInternet logo-->
# <a href="http://www.liveinternet.ru/click" target="_blank">
# <img alt="" height="31" src="//counter.yadro.ru/logo?14.1" style="border: 0;" title="LiveInternet: показано число просмотров за 24 часа, посетителей за 24 часа и за сегодня" width="88"/>
# </a>
# <!--/LiveInternet-->
# </li>
# </ul>
# </div>
# <div class="main_footer_copyright">© 1991–2021 АО «Коммерсантъ»<span class="main_footer_copyright__add hide1 hide2">. All rights reserved</span></div>
# </footer>
# </div>
# <div class="popup_menu">
# <div class="popup_menu__inner">
# <button class="kbd_button popup_menu__close" tabindex="0">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon--small vicon--close">
# <svg class="vicon__body"><use xlink:href="#vicon-close" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </div>
# </button>
# <ul class="popup_menu__list popup_menu__list--main">
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/47?from=menu_strana">Страна</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/5?from=menu_mir">Мир</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/3?from=menu_ekonomika">Экономика</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/4?from=menu_biznes">Бизнес</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/finance?from=menu_finansi">Финансы</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/realty?from=menu_nedvizimost">Недвижимость</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/8?from=menu_kultura">Культура</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/9?from=menu_sport">Спорт</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/hitech?from=menu_hitech">Hi-tech</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/auto?from=menu_auto">Авто</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/style?from=menu_style">Стиль</a>
# </li>
# </ul>
# <ul class="popup_menu__list popup_menu__list--issues">
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/daily?from=menu_gazeta">Газета</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/apps?from=menu_prilozheniya">Приложения</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/Ogoniok?from=menu_ogoniok">Огонёк</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/weekend?from=menu_weekend">Weekend</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/regions?from=menu_regions">Регионы</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/autopilot?from=menu_autopilot">Автопилот</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/nauka?from=menu_nauka">Наука</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="http://www.kommersant.uk/?from=menu_uk" target="_blank">UK</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue_other">
# <a href="/fm?from=menu_fm">FM93.6</a>
# </li>
# </ul>
# <ul class="popup_menu__list">
# <li class="popup_menu__item">
# <a href="https://www.kartoteka.ru/?from=menu_kartoteka" target="_blank">Картотека</a>
# </li>
# <li class="popup_menu__item">
# <a href="https://bankruptcy.kommersant.ru/?from=menu_bankrotstva" target="_blank">Банкротства</a>
# </li>
# <li class="popup_menu__item">
# <a href="/Conf?from=menu_konferencii">Конференции</a>
# </li>
# <li class="popup_menu__item">
# <a href="/subscription?from=menu_podpiska">Подписка</a>
# </li>
# <li class="popup_menu__item">
# <a href="/photo?from=menu_photo">Фотоагентство</a>
# </li>
# <li class="popup_menu__item">
# <a href="/academy?from=menu_academy">Академия</a>
# </li>
# </ul>
# </div>
# </div>
# <script src="https://im.kommersant.ru/JScripts/NewWindow.js?1910141750220468"></script>
# <script src="https://im.kommersant.ru/Scripts/poll_new.js?1910141746402031"></script>
# <script async="" charset="utf-8" data-uid="159f1b125b1d2605ef3759146fd44686" id="my-widget-script" src="https://likemore-go.imgsmail.ru/widget.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.9.1/firebase-app.js" type="text/javascript"></script>
# <script src="https://www.gstatic.com/firebasejs/7.9.1/firebase-messaging.js" type="text/javascript"></script>
# <script src="/ContentFlex/modules/dist/bundle.js?2010151416382095"></script>
# </body>
# </html>

# %%
# добираемся до блоков с новостями
news_blocks = soup.find_all('div', class_='search_results_item')
news_blocks
# Out:
# [<div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/online/156" target="_blank">
#  <span class="search_results_number">001</span>
#  <span class="search_results_source">Ъ-Черноземье-Online от 10.02.2021</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4683264?query=python" target="_blank">Синергия цифровизации: Сбер и ВГУ обновляют дорожную карту сотрудничества</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4683264?query=python" target="_blank">
#  									 ...  обучения на языке <mark>Python</mark> и многих других ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/doc/4615331" target="_blank">
#  <span class="search_results_number">002</span>
#  <span class="search_results_source">Партнерские проекты от 25.12.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4615331?query=python" target="_blank">Руки, которые стоят миллион</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4615331?query=python" target="_blank">
#  									 ... ) Дизайн и верстка: <mark>Python</mark> Creative Group .auditorium ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/doc/4615354" target="_blank">
#  <span class="search_results_number">003</span>
#  <span class="search_results_source">Партнерские проекты от 23.12.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4615354?query=python" target="_blank">Руки, которые стоят миллион</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4615354?query=python" target="_blank">
#  									 ... ) Дизайн и верстка: <mark>Python</mark> Creative Group
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item search_results_item--media">
#  <div class="search_results_media">
#  <div class="photo">
#  <a href="/doc/4616964?query=python" target="_blank">
#  <picture class="js-lazyimage">
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t241_125414.webp 1200w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t240_125414.webp 1035w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t239_125414.webp 990w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t250_125414.webp 870w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t238_125414.webp 690w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t237_125414.webp 660w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t236_125414.webp 600w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t235_125414.webp 580w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t234_125414.webp 550w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t233_125414.webp 480w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t232_125414.webp 370w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t231_125414.webp 360w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t230_125414.webp 300w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t229_125414.webp 250w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t228_125414.webp 240w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t227_125414.webp 180w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t226_125414.webp 160w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_t225_125414.webp 143w, https://im.kommersant.ru/Issues.photo/REGIONS/VRN_Online/2020/12/17/KVR_001006_00579_1_
img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/REGIONS/PITER_Tema/2020/2251/KSP_015144_00683_1_t218_182929.jpg"/>
#  </noscript>
#  </a>
#  </div>
#  </div>
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/apps/6004738" target="_blank">
#  <span class="search_results_number">007</span>
#  <span class="search_results_source">Приложение к газете "Коммерсант С-Петербург" №225 от 08.12.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4602882?query=python" target="_blank">Робототехника нуждается в людях</a>
#  </h2>
#  <h1 class="article_subheader">
#  <a href="/doc/4602882?query=python" target="_blank">
#  									Кадры
#  								</a>
#  </h1>
#  <div class="article_intro">
#  <a href="/doc/4602882?query=python" target="_blank">
#  									 ...  (C++, C#, Java, <mark>Python</mark>), опыт работы с ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/online/289" target="_blank">
#  <span class="search_results_number">008</span>
#  <span class="search_results_source">Ъ-Южный-Урал-Online от 07.12.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4603550?query=python" target="_blank">СберКласс представлен на международной конференции AI Journey Junior</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4603550?query=python" target="_blank">
#  									 ...  тренажером языка программирования <mark>Python</mark>, который в тестовом ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/news" target="_blank">
#  <span class="search_results_number">009</span>
#  <span class="search_results_source">Лента новостей (Москва) от 01.12.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4594535?query=python" target="_blank">ИИ позволит отслеживать выбросы CO2, связанные с работой компьютеров</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4594535?query=python" target="_blank">
#  									 ... , написанным на языке <mark>Python</mark>. Программа также предлагает ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item search_results_item--media">
#  <div class="search_results_media">
#  <div class="photo">
#  <a href="/doc/4529711?query=python" target="_blank">
#  <picture class="js-lazyimage">
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t241_150307.webp 1200w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t240_150307.webp 1035w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t239_150307.webp 990w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t250_150307.webp 870w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t238_150307.webp 690w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t237_150307.webp 660w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t236_150307.webp 600w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t235_150307.webp 580w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t234_150307.webp 550w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t233_150307.webp 480w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t232_150307.webp 370w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t231_150307.webp 360w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t230_150307.webp 300w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t229_150307.webp 250w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t228_150307.webp 240w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t227_150307.webp 180w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t226_150307.webp 160w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t225_150307.webp 143w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t224_150307.webp 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..." type="image/webp"/>
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t241_150307.jpg 1200w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t240_150307.jpg 1035w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t239_150307.jpg 990w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t250_150307.jpg 870w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t238_150307.jpg 690w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t237_150307.jpg 660w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t236_150307.jpg 600w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t235_150307.jpg 580w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t234_150307.jpg 550w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t233_150307.jpg 480w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t232_150307.jpg 370w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t231_150307.jpg 360w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t230_150307.jpg 300w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t229_150307.jpg 250w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t228_150307.jpg 240w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t227_150307.jpg 180w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t226_150307.jpg 160w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t225_150307.jpg 143w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t224_150307.jpg 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..."/>
#  <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t218_150307.jpg" src="..."/>
#  </picture>
#  <noscript>
#  <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/TEMA2/2020/029/KMO_124958_04031_1_t218_150307.jpg"/>
#  </noscript>
#  </a>
#  </div>
#  </div>
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/apps/126466" target="_blank">
#  <span class="search_results_number">010</span>
#  <span class="search_results_source">Приложение к газете "Коммерсантъ" №29 от 27.10.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4529711?query=python" target="_blank">В один клик</a>
#  </h2>
#  <h1 class="article_subheader">
#  <a href="/doc/4529711?query=python" target="_blank">
#  									Huawei Honor Cup
#  								</a>
#  </h1>
#  <div class="article_intro">
#  <a href="/doc/4529711?query=python" target="_blank">
#  									 ...  знания языка программирования <mark>Python</mark>, некоторые разделы высшей ...
#  								</a>
#  </div>
#  </div>
#  </div>]

# %%
# добираемся до текста со ссылкой
articles_intro = list(map(lambda x: x.find('div', class_='article_intro'), news_blocks))
articles_intro
# Out:
# [<div class="article_intro">
#  <a href="/doc/4683264?query=python" target="_blank">
#  									 ...  обучения на языке <mark>Python</mark> и многих других ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4615331?query=python" target="_blank">
#  									 ... ) Дизайн и верстка: <mark>Python</mark> Creative Group .auditorium ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4615354?query=python" target="_blank">
#  									 ... ) Дизайн и верстка: <mark>Python</mark> Creative Group
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4616964?query=python" target="_blank">
#  									 ...  разработка», «Программирование на <mark>Python</mark>», «VR-AR-разработка ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4614960?query=python" target="_blank">
#  									 ... ) Дизайн и верстка: <mark>Python</mark> Creative Group
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4613237?query=python" target="_blank">
#  									 ... ) Дизайн и верстка: <mark>Python</mark> Creative Group
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4602882?query=python" target="_blank">
#  									 ...  (C++, C#, Java, <mark>Python</mark>), опыт работы с ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4603550?query=python" target="_blank">
#  									 ...  тренажером языка программирования <mark>Python</mark>, который в тестовом ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4594535?query=python" target="_blank">
#  									 ... , написанным на языке <mark>Python</mark>. Программа также предлагает ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4529711?query=python" target="_blank">
#  									 ...  знания языка программирования <mark>Python</mark>, некоторые разделы высшей ...
#  								</a>
#  </div>]

# %%
# добираемся до ссылок
a_list = list(map(lambda x: x.find('a').get('href'), articles_intro))
a_list
# Out:
# ['/doc/4683264?query=python',
#  '/doc/4615331?query=python',
#  '/doc/4615354?query=python',
#  '/doc/4616964?query=python',
#  '/doc/4614960?query=python',
#  '/doc/4613237?query=python',
#  '/doc/4602882?query=python',
#  '/doc/4603550?query=python',
#  '/doc/4594535?query=python',
#  '/doc/4529711?query=python']

# %%
# формируем полноценные ссылки
all_refs = list(map(lambda x: 'https://www.kommersant.ru/' + x, a_list))
all_refs
# Out:
# ['https://www.kommersant.ru//doc/4683264?query=python',
#  'https://www.kommersant.ru//doc/4615331?query=python',
#  'https://www.kommersant.ru//doc/4615354?query=python',
#  'https://www.kommersant.ru//doc/4616964?query=python',
#  'https://www.kommersant.ru//doc/4614960?query=python',
#  'https://www.kommersant.ru//doc/4613237?query=python',
#  'https://www.kommersant.ru//doc/4602882?query=python',
#  'https://www.kommersant.ru//doc/4603550?query=python',
#  'https://www.kommersant.ru//doc/4594535?query=python',
#  'https://www.kommersant.ru//doc/4529711?query=python']

# %%
# объединим все в одну функцию
def get_all_links(url, query):
    all_refs = []
    params = {
        'search_query': query,
    }
    res = requests.get(URL, params)
    time.sleep(0.3)
    soup = BeautifulSoup(res.text, 'html.parser')
    news_blocks = soup.find_all('div', class_='search_results_item')
    articles_intro = list(map(lambda x: x.find('div', class_='article_intro'), news_blocks))
    a_list = list(map(lambda x: x.find('a').get('href'), articles_intro))
    all_refs = list(map(lambda x: 'https://www.kommersant.ru/' + x, a_list))

    return all_refs

all_links = get_all_links(URL, 'python')
all_links
# Out:
# ['https://www.kommersant.ru//doc/4683264?query=python',
#  'https://www.kommersant.ru//doc/4615331?query=python',
#  'https://www.kommersant.ru//doc/4615354?query=python',
#  'https://www.kommersant.ru//doc/4616964?query=python',
#  'https://www.kommersant.ru//doc/4614960?query=python',
#  'https://www.kommersant.ru//doc/4613237?query=python',
#  'https://www.kommersant.ru//doc/4602882?query=python',
#  'https://www.kommersant.ru//doc/4603550?query=python',
#  'https://www.kommersant.ru//doc/4594535?query=python',
#  'https://www.kommersant.ru//doc/4529711?query=python']

# %%
# но мы же собрали только одну страницу? Хотим ВСЕ новости
def get_all_links(url, query, pages):
    all_refs = []
    params = {
        'search_query': query
    }
    for i in range(pages):
        params['page'] = i + 1
        res = requests.get(URL, params)
        time.sleep(0.3)
        soup = BeautifulSoup(res.text, 'html.parser')
        news_blocks = soup.find_all('div', class_='search_results_item')
        articles_intro = list(map(lambda x: x.find('div', class_='article_intro'), news_blocks))
        a_list = list(map(lambda x: x.find('a').get('href'), articles_intro))
        all_refs += list(map(lambda x: 'https://www.kommersant.ru/' + x, a_list))
    return all_refs

all_links = get_all_links(URL, 'python', 3)
all_links
# Out:
# ['https://www.kommersant.ru//doc/4683264?query=python',
#  'https://www.kommersant.ru//doc/4615331?query=python',
#  'https://www.kommersant.ru//doc/4615354?query=python',
#  'https://www.kommersant.ru//doc/4616964?query=python',
#  'https://www.kommersant.ru//doc/4614960?query=python',
#  'https://www.kommersant.ru//doc/4613237?query=python',
#  'https://www.kommersant.ru//doc/4602882?query=python',
#  'https://www.kommersant.ru//doc/4603550?query=python',
#  'https://www.kommersant.ru//doc/4594535?query=python',
#  'https://www.kommersant.ru//doc/4529711?query=python',
#  'https://www.kommersant.ru//doc/4492730?query=python',
#  'https://www.kommersant.ru//doc/4450879?query=python',
#  'https://www.kommersant.ru//doc/4450177?query=python',
#  'https://www.kommersant.ru//doc/4434580?query=python',
#  'https://www.kommersant.ru//doc/4407208?query=python',
#  'https://www.kommersant.ru//doc/4399817?query=python',
#  'https://www.kommersant.ru//doc/4377181?query=python',
#  'https://www.kommersant.ru//doc/4349643?query=python',
#  'https://www.kommersant.ru//doc/4317759?query=python',
#  'https://www.kommersant.ru//doc/4282410?query=python',
#  'https://www.kommersant.ru//doc/4275981?query=python']

# %%
import pandas as pd

# %%
# собираем даты, заголовки и тексты новостей
# получаем ошибочку. Значит не у всех получаемых страниц одинаковая разметка
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    time.sleep(0.3)
    date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
    print(date)
    title = soup.find('h1', class_='article_name').text
    print(title)
    text = soup.find('div', class_='article_text_wrapper').text
    print(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-a04b17bdcdb0> in <module>
#       4     soup = BeautifulSoup(requests.get(link).text, 'html.parser')
#       5     time.sleep(0.3)
# ----> 6     date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
#       7     print(date)
#       8     title = soup.find('h1', class_='article_name').text
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
# получаем ошибочку. Значит не у всех получаемых страниц одинаковая разметка
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    if soup.find('div', class_='b-article__publish_date'):
        date = pd.to_datetime(soup.find('div', class_='b-article__publish_date').find('time').get('datetime'), dayfirst=True).date()
    elif soup.find('time', class_='title__cake'):
        date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
    print(date)
    if soup.find('h2', class_='article_name'): 
        title = soup.find('h2', class_='article_name').text
    else: 
        title = soup.find('h1', class_='article_name').text    
    print(title)
    text = soup.find('div', class_='article_text_wrapper').text
    print(text)
# Out:
# 2021-02-10
# Синергия цифровизации: Сбер и ВГУ обновляют дорожную карту сотрудничества
#
#
#
#
#
#
# Фото: Сбербанк
#
# Почти год назад в Воронежском государственном университете открылась лаборатория искусственного интеллекта Сбербанка. Этот большой проект стал очередным этапом многолетнего сотрудничества одного из крупнейших вузов и одной из крупнейших финансовых компаний страны. А также он стал отправной точкой к реализации еще более амбициозных совместных инициатив.
# Лаборатория искусственного интеллекта Сбербанка органично дополнила уже существующую в университете IT-инфраструктуру. Она оснащена мощным компьютерным оборудованием и позволяет решать полный спектр задач в области информационных систем искусственного интеллекта, информационной безопасности, создания новых технологий обработки информации и машинного обучения.
# В стенах лаборатории студентам предлагают освоить самые перспективные направления развития искусственного интеллекта: от анализа больших данных (Big data) и современных нейросетевых технологий до построения систем машинного обучения на языке Python и многих других возможностей.
# На недавней встрече-знакомстве председателя Центрально-Черноземного банка Наталии Цайтлер с командой Воронежского госуниверситета во главе с ректором Дмитрием Ендовицким партнеры обсудили перспективы дальнейшего взаимодействия.
#
#
#
#
#
# Фото: Сбербанк
#
# –  Одно из главных направлений сотрудничества – формирование культуры технологических новаций, – отметила Наталия Цайтлер. – Речь идет об опыте экосистемы Сбера, которая предлагает инновационные сервисы для широкого спектра индустрий, в том числе в сфере образования. Так, в нашей международной программе для seed-стартапов Sber500 в партнёрстве с 500 Startups к программам для сотрудников (SberUp) и школьников (SberZ) добавился акселератор SberStudent для студентов, аспирантов, научных сотрудников институтов и университетов. Участники смогут развить свою бизнес-идею и запустить свой первый коммерческий проект. Сбербанк полностью оплатит обучение. Помимо основной программы, лучшие команды, выбранные Сбером, получат дополнительное кураторство, работая совместно со Стэнфордским Центром Профессионального Развития. Глобальная цель всех этих акселераторов — вырастить созвездие новых сильных технологических компаний, которые могли бы стать фундаментом новой экономики нашей страны. Заявки на участие в SberStudent принимаются до 25 февраля, и у каждого талантливого студента ВГУ есть реальная возможность  создать свой первый стартап при поддержке Сбера.
# Ректор Воронежского госуниверситета в свою очередь отметил, что предыдущая дорожная карта сотрудничества с Центрально-Черноземным банком была полностью реализована. В ближайшее время стороны договорились разработать документ, который отразит перечень новых планов.
# – Сбербанк – ключевой стратегический партнер Воронежского госуниверситета, – подчеркнул ректор ВГУ Дмитрий Ендовицкий. – Нам очень интересна общая тема развития технологий искусственного интеллекта, расширение возможностей созданной лаборатории, а также использование нашего методологического опыта в IT-области для обмена знаниями с представителями Сбера. Все это вместе открывает большое поле для взаимодействия и уверен, что мы достигнем больших результатов. На встрече мы говорили также о региональном научно-образовательном центре «Цифровые инновации в экономике», созданном по распоряжению губернатора Воронежской области. Сбербанк может стать здесь серьезным локомотивом за счет своего опыта формирования многих трендов внутри страны – это будет очень перспективно и полезно для региона».
# На фоне новых «маршрутов» взаимодействия продолжат развиваться и направления, уже ставшие традиционными для ВГУ и Сбербанка. В частности, это подготовка профильных кадров для одного из крупнейших работодателей региона.
# ПАО Сбербанк. 16+
#
# 2020-12-25
# Руки, которые стоят миллион
#
#
#
#
#
#
#
# Знаменитый русский композитор, пианист и дирижер Сергей Рахманинов не любил, когда его фотографируют репортеры, в особенности — папарацци. Однажды он был на гастролях в небольшом американском городе, и местный фотокорреспондент просто-таки преследовал его. Когда Рахманинов обедал, журналист достал камеру и попытался сделать снимок, но музыкант закрыл лицо руками. Снимок вышел на первой полосе газеты с гениальной подписью: «Руки, которые стоят миллион».В нашем проекте — те, чьи руки стоят миллион.
# История четвертая: художник
#
#
#
#
#
#
# «Мой инструмент — руки»Ирина Петракова, художник
# — У тебя 20 ноября должна была открыться персональная выставка «Проявляется исчезновением» в ММОМА на Петровке, но в последний момент все перенеслось из-за пандемии.
# — Вообще выставка должна была открыться еще весной, но, когда случился первый локдаун, стало понятно, что будет перенос. Летом появились новые даты в ноябре, и вот, буквально за неделю, когда уже шел монтаж выставки и везде были анонсы, объявили о закрытии музеев, и выставку снова пришлось перенести. Сама выставка — рефлексия по поводу того, что сейчас происходит, как мы организовываем себя в пространстве, это и про мои переживания, и про мои методы работы как художника. Часть выставки предполагается перформативной — я буду (а я очень надеюсь, что выставка все же случится) расписывать одну из стен.
# Забавно, что после того, как я написала в социальных сетях, что выставка переносится, многие пошутили, что название — «Проявляется исчезновением» — сработало.
# — Раз речь зашла о методах работы. Насколько я знаю, ты не работаешь с кистями и карандашами.
# — Не использую, мой инструмент — руки. Люблю уголь. Отсюда и перформативная часть выставки — я буду рисовать на стенах, исключая какой-то дополнительный медиум вроде бумаги. Это обживание пространства телом. В чем-то это схоже с техниками абстрактного экспрессионизма.
# — Вообще художник и руки — тема интересная. Ты сама работаешь руками, но сейчас много художников, которые создают концепции и приглашают других для их реализации.
# — Конечно, художник не только работает руками, иначе он был бы ремесленником, но для меня работа руками важна — это прямая взаимосвязь. Твой ум и твои руки. Я всегда стараюсь во всем участвовать. Даже если мне понадобится пригласить сварщика для проекта, я потом все равно доработаю поверхности. При этом, когда я училась в ИПСИ, мне было чуть ли не стыдно, что я умею что-то делать руками. Но моя практика показала, что это суперпреимущество.
# У меня классическое художественное образование, новосибирский Худграф (ныне Институт искусств): меня пять лет учили живописи, рисунку. Мне потом приходилось забывать, как канонически правильно писать, так появилась моя техника пятна. Это та реальность, которую я пытаюсь замылить, или наоборот — проявление чего-то реалистичного из этого пятна.
# Во время локдауна искусству придумывания было сложно. Ты можешь сколько угодно придумывать, но ты не можешь произвести. И занять свое время не можешь. И даже если не говорить об искусстве, многие за эту весну поменяли кардинально свои занятия. И новые часто связаны с ручным трудом. Возможно, это связано с тем, что столько всего перешло в виртуальный мир, что все, что мы можем ухватить руками, стало более ценным.
# — Кроме несостоявшейся выставки в ММОМА что еще в твоих планах изменилось из-за пандемии?
# — Что-то отменилось, но другие вещи произошли благодаря пандемии. Например, австрийская резиденция в Москве на «Фабрике». Они не могли привезти австрийских художников из-за того, что были закрыты границы, и пригласили российских художников придумать какой-то проект про Австрию. И я с двумя другими, совершенно замечательными, художниками придумали вымышленного персонажа — австрийскую художницу, которая впервые оказывается в Москве во время локдауна и создает тут какое-то искусство про Россию. Это мы рефлексируем по поводу России и российского современного искусства как бы глазами модной австрийской авангардной художницы.
#
#
#
#
#
#
# — А вообще как локдаун для тебя прошел?
# — Часть его я провела в Москве, часть — в Петербурге. Уехала туда на две недели и осталась на два месяца. Там я как раз работала над ноябрьской выставкой. Кстати, что касается выставки — из-за пандемии изменились не только ее даты, не только то, как я над ней работала, но и ее тема. До пандемии она была другой — про смерть и жизнь после смерти, но мир изменился, и ты не мог делать как прежде. Ну и этически, мне кажется, сейчас неуместно было бы делать выставку на тему, связанную со смертью.
# — У Audemars Piguet есть такой проект — Art Comission. Каждый год они приглашают куратора, который выбирает художника и тот создает проект, премьера которого происходит на Art Basel. Насколько, по-твоему, спонсоры и патроны вообще важны для искусства?
# — Очень важны. Это очень счастливый момент, когда происходит соединение хороших и идей и возможностей их реализации. Если у художника будет проект, в котором должны быть, например, золотые вилы, понятно, что сам он будет ждать много лет, чтобы заработать на его реализацию. И здорово, если кто-то момент создания приближает.
# Как здорово и когда художники занимаются самоорганизацией, создают свои объединения.
# — Говоря о новой этике в современном искусстве. О том, что тот же нью-йоркский МоМА недавно прошел через крупную реконструкцию, цель которой — представить больше художников-афроамериканцев, коренных жителей Америки, женщин… Что ты про это думаешь?
# — Это вообще очень интересный вопрос. Я, например, не считаю себя феминисткой, я не люблю феминитивы. Я художник, а не художница. Я за то, чтобы все имели право высказываться, но против того, чтобы кто-либо навязывал свою точку зрения. И я против того, чтобы в попытке всех уравнять, терялось искусство.
# Ирина Петракова — художник, соорганизатор Центра «Красный» (Москва, 2015–2018). Среди последних персональных выставок: «Come and Hide» (Iragui Gallery, Москва, 2018), «Объясните это темным» (Центр «Красный», Москва, 2016). Активно занимается художественной и образовательной практикой с детьми и подростками. Работы находятся в коллекциях фонда Ruarts, ЦСИ «ЗАРЯ», Iragui Gallery и в частных коллекциях.
# Проект Audemars Piguet
# Автор: Анна МинаковаПродюсер: Александр ЩуренковФотограф: Александр ПлатоновЧасы на герое: CODE 11.59 by Audemars Piguet Автоматические (реф. 15210OR.OO.A616CR.01) Дизайн и верстка: Python Creative Group
# 2020-12-23
# Руки, которые стоят миллион
#
#
#
#
#
#
#
# Знаменитый русский композитор, пианист и дирижер Сергей Рахманинов не любил, когда его фотографируют репортеры, в особенности — папарацци. Однажды он был на гастролях в небольшом американском городе, и местный фотокорреспондент просто-таки преследовал его. Когда Рахманинов обедал, журналист достал камеру и попытался сделать снимок, но музыкант закрыл лицо руками. Снимок вышел на первой полосе газеты с гениальной подписью: «Руки, которые стоят миллион».В нашем проекте — те, чьи руки стоят миллион.
# История третья: огранщик
#
#
#
#
#
#
# «Мы смотрим на камень руками»Дмитрий Саморуков, мастер художественной огранки
# — Давайте начнем с предмета у вас в руках, который вы так нежно держите. Что это за изобретение?
# — В 2000 году я открыл производство по огранке цветных камней и уже тогда начал разрабатывать оборудование, которое будет удобно мне. Мне помогло мое техническое образование — я окончил МГТУ Станкин.
# Центр цифрового образования детей расположился на первом и втором этажах информационно-выставочного центра ПАО «Пигмент». Не классы, а кубы с современной техникой, удобно обустроенным пространством так и располагают к инновационным открытиям и созданию прорывных технологий.
# По федеральному проекту «Цифровая образовательная среда» национального проекта «Образование» в 2020 году на его создание выделено около 24,3 млн руб. Размер субсидии из федерального бюджета — почти 13 млн руб. Из бюджета Тамбовской области добавили 8,7 млн руб. Средства индустриального партнера — 2,6 млн руб.
# Космической скорости развития пожелал новой образовательной площадке губернатор Александр Никитин. И это пожелание, без сомнения, особенно актуально. Обучение в «IT-кубе. Тамбов» идет по шести направлениям: «Мобильная разработка», «Программирование на Python», «VR-AR-разработка», «Кибергигиена и большие данные», «Системное администрирование» и «Программирование роботов». Программы обучения реализуются совместно с ведущими IT-компаниями России и мира, такими как «Яндекс.Лицей», «IT-школа Samsung», «Крибрум», LegoEducation. Помимо этого, на площадке оборудованы зона коворкинга и шахматная гостиная.
# «На одной площадке нам удалось сконцентрировать возможности системы образования, дополнительного образования, университетского сообщества и реальной сферы экономики в виде лидера отраслевого развития — завода “Пигмент”. Я считаю это большой удачей и новыми горизонтами развития для всех предприятий Тамбовской области в сфере внедрения информационных технологий», — подчеркивает губернатор Александр Никитин.
# Проект представляет собой современную образовательную экосистему, объединяющую лидеров IT-рынка, опытных наставников, прошедших обучение у партнеров — участников проекта, а самое главное — школьников, которых особенно привлекает сфера современных технологий.
# Планируется, что ежегодно в центре смогут проходить обучение 400 детей и подростков в возрасте от 7 до 17 лет. В мероприятиях, проводимых «IT-кубом. Тамбов» совместно с партнерами, будет задействовано более 1,5 тыс. детей со всех городов и районов области. Обучение в центре цифрового образования бесплатное.
# По итогам конкурсного отбора федерального проекта «Цифровая образовательная среда» нацпроекта «Образование» Министерство просвещения РФ поддержало создание к 2022 году трех центров цифрового образования «IT-куб» в Тамбовской области.
# На высоких скоростях
# Без интернета сегодня сложно учителю провести полноценный урок: он помогает выставить оценки, выдать домашнее задание, продемонстрировать справочные материалы. По федеральному проекту «Цифровая образовательная среда» школы области оснащают высокоскоростным интернетом. До конца 2021 года 100% школ региона получат интернет на скорости 50 Мегабит/с на селе и 100 Мегабит/с в городах.
# Работы по подключению школ области и организаций среднего профессионального образования к высокоскоростному интернету начались в 2019 году. Тогда было подключено 143 учреждения. В 2020 году по государственному контракту к высокоскоростному интернету подключены две городские школы, а также 139 школ и один филиал организации профессионального образования, расположенные в сельской местности .
# Важен не только интернет, но и современная техника, которая расширит возможности обучения. В 2020 году в 101 образовательную организацию области поступило новейшее компьютерное и презентационное оборудование для эффективной реализации образовательных программ, внедрения современных цифровых технологий в образовательный процесс.
# Всего же в период с 2019 по 2022 год по проекту «Цифровая образовательная среда» компьютерные классы, презентационное оборудование, ноутбуки поступят в 219 образовательных организаций области. Благодаря этому все они смогут пользоваться онлайн-сервисами и федеральными образовательными платформами.
# Новые мастерские
# — Сначала все рождается в голове. Брускетта с крабом и гуакамоле вообще появилась благодаря случаю. Были грибы, я думал, куда бы их добавить, а брускетта с крабом и гуакамоле уже была в меню. Я решил попробовать добавить их туда, а потом понял, что не хватает пармезана. Так родилось одно из наших очень популярных блюд. Весь процесс создания рецепта — две-три минуты! Вообще хорошие рецепты часто рождаются быстро или приходят во время работы. Просто что-то добавляешь, меняешь и понимаешь — вот этот вкус. Я люблю необычные сочетания. У нас есть десерт — панна-кота. Многие используют такое сочетание соленого со сладким в десертах, как соленая карамель. А мы решили использовать сочетание соли с карамелизированным бананом.
# — Я слышала от разных знакомых много суждений вроде «ресторан проверяется десертом» или «ресторан проверяется качеством самого популярного блюда». А на твой взгляд, чем?
# — Качеством продуктов. И соответствием блюда его цене. Нередко бывает, когда дорогое блюдо не выглядит на эту сумму и не имеет нужного вкуса. Подача вообще очень важна. Может быть вкусное блюдо, испорченное подачей. И это всегда вина шеф-повара.
#
#
#
#
#
# На фото: А. Медяник, на запястье Артема: часы CODE 11.59 by Audemars Piguet
#
# — Среди звездных шеф-поваров кто лично тебе нравится?
# — Я одно время смотрел очень много роликов Гордона Рамзи и готовил то, что он готовит. Просто для себя, чтобы проверить, насколько это вкусно. Простая, быстрая, вкусная еда. На самом деле, я смотрел ролики многих поваров, но именно метод Рамзи мне ближе. А кроме того, он хороший рассказчик. Он умеет говорить о еде так, что сразу пробуждает аппетит.
# — Ресторан совсем новый, но я знаю, что вы планируете постоянно что-то менять и обновлять.
# — Сейчас мы ввели завтраки, потом вводим сезонное меню — зимой, например, у нас подходящие сезону десерты из хурмы, равиоли из тыквы.
# — Есть довольно много фильмов про кухню, про шеф-поваров. Насколько вообще происходящее в них соответствует действительности? Есть какие-то, близкие к реальности?
#
# 2020-12-15
# Руки, которые стоят миллион
#
#
#
#
#
#
#
# Знаменитый русский композитор, пианист и дирижер Сергей Рахманинов не любил, когда его фотографируют репортеры, в особенности — папарацци. Однажды он был на гастролях в небольшом американском городе, и местный фотокорреспондент просто-таки преследовал его. Когда Рахманинов обедал, журналист достал камеру и попытался сделать снимок, но музыкант закрыл лицо руками. Снимок вышел на первой полосе газеты с гениальной подписью: «Руки, которые стоят миллион».В нашем проекте — те, чьи руки стоят миллион.
# История первая: музыкант
#
#
#
#
#
# На фото: А. Болдачев, на запястье Александра: часы CODE 11.59 by Audemars Piguet
#
# «Арфы создавали часовщики»Александр Болдачев, арфист
# — Ты в этот раз приехал в Москву на всероссийскую «Ночь искусств», которая прошла в очень необычном формате — без зрителей, с онлайн-трансляцией. Расскажи о ней.
# — У арфы сейчас ренессанс, и я много вкладываю в ее развитие. В Москве я не был с февраля, в последний визит дирижировал в Центре Павла Слободкина. Потом должен был вернуться, но начался локдаун. Многие мероприятия отменялись, а «Ночь искусств» поменяла формат. Все участники были в концертном зале Казанского вокзала, а зрители могли смотреть трансляцию онлайн и в записи. Но поменялось не только это: изначально планировалось, что «Ночь» будет концертом с моей программой и, возможно, парой артистов, но когда объявили онлайн-формат, то стало очевидно, что нужно сделать картинку красивой, многогранной. Поэтому я пригласил группу «Помпея», Вадима Эйленкрига с его бэндом, скрипку и саксофон (Елену Ревич и Веронику Кожухарову), балет Большого театра. Еще были костюмы студии Андрея Бартенева, художники Саша Фролова со своими скульптурами и Вова Перкин, который написал 10-метровое полотно во время выступления — на нем появлялись персонажи его мира, они изображали зрителей.
# Вообще я очень рад, что посвященный арфе проект стал центральным на «Ночи искусств».
# — Арфа выглядит очень технически сложным инструментом.
# — Педальной арфе в этом году 300 лет. То есть триста лет с момента изобретения педального механизма, который переключает высоту звука, а вообще арфе тысяч десять лет, потому что она происходит от охотничьего лука. Родина арфы — весь мир. В Европе распространилась кельтская арфа, на которой играли миннезингеры, менестрели, труверы, трубадуры. Педальную арфу изобрел немец Хохбрукер. У нее очень сложный механизм: в первых версиях было 800–900 деталей, сейчас их больше 2000. Механизм работает так: нога нажимает педаль, педаль прикреплена к металлическому шнуру, который идет сквозь колонну. Каждое нажатие педали запускает множество механических движений, поэтому все должно быть выверено до доли миллиметра. Ошибка в долю миллиметра в настройке — и будет звучать фальшиво. Такая четкость присуща именно часовщикам, поэтому издавна часовщики участвовали в создании арф.
# — Больше всего как производители часов знамениты швейцарцы, а кто знаменит своими арфами?
# — Центры были в Германии, Австрии, потом появился центр во Франции, потом — большая фабрика в Чикаго, которой уже 150 лет. От нее отщепился итальянец Виктор Сальви и сделал свою компанию. Сейчас она итальянская, но начиналась ее история как раз в Швейцарии, где было первое производство Salvi. Лично я играю именно на этой арфе.
# Вообще производство арф похоже на лабораторию — наладкой механики, дерева занимается большая команда.
# — Насколько я знаю, один комплект струн для арфы стоит порядка 2000 евро, а сколько стоит весь инструмент?
# — В отличие от скрипки арфы пока еще не старятся красиво. То есть если я захочу купить столетнюю или двухсотлетнюю арфу, это не будет дорого. Она будет не в лучшем рабочем состоянии, потому что напряжение на деку около двух тонн, при этом для хорошего звучания дерево должно быть тонким, и со временем из-за этого дерево деформируется. В цене новые арфы. Студенческую можно купить за сумму от 10 тысяч евро, а самые дорогие будут стоить 120–150 тысяч евро. Выше по цене уже не найдешь.
# — Только если бриллиантами инкрустировать…
# — В истории такое было. Когда менестрели играли в Ирландии, герб которой, к слову, именно арфа, был такой закон: за долги можно у человека забрать все, кроме инструмента. Поэтому менестрели ходили с арфами, которые были невероятно богато украшены. Все, что они имели, они встраивали в арфу.
# — Арфа, кроме того что сложная и дорогая, еще и огромная. Она с тобой путешествует по миру или как это происходит?
# — Вообще арфа как рояль — в каждом месте должна быть своя. Но часто случается так, особенно в не самых центральных городах, что арфа есть, но она не самого лучшего качества. Тут мне часто помогает Salvi — они предоставляют арфу, если она у них есть в этом городе, в остальных случаях нахожу сам. Нередко помогают местные коллеги. Вожу я арфу только в пределах города. Свои арфы у меня есть в Москве и Цюрихе, где я живу.
#
#
#
#
#
# На фото: А. Болдачев,
# на запястье Александра: часы CODE 11.59 by Audemars Piguet
#
# — Кроме классической арфы есть еще электронная, расскажи о ней.
# — Электроакустическая арфа появилась в середине XX века, когда все инструменты делали электроакустическими. Даже в Советском Союзе были попытки создания такой арфы.
# С другой стороны, нужных отрасли специалистов не хватает. «Самый большой дефицит кадров наблюдается у промышленных предприятий. Поскольку чаще всего сами предприятия как конечные заказчики роботехнических решений не очень понимают, как использовать роботов,— говорит Алиса Конюховская, исполнительный директор Национального агентства участников рынка робототехники (НАУРР).— Также есть роботехнические компании в области промышленной робототехники, интеграторы, которые в основном сами себе готовят кадры, потому что сейчас в университетах нет именно такого направления подготовки. Помимо этого, в сфере сервисной робототехники нужны кадры. Повышение занятости в этом сегменте прогнозируется в среднем на 20% ежегодно».
# Екатерина Скляренко, руководитель отдела маркетинга hh.ru по Северо-Западу, оценивает нынешний уровень конкуренции среди соискателей как невысокий: на одну вакансию, размещенную на портале hh.ru, приходится около четырех резюме, что чуть ниже нормативного показателя в пять-шесть резюме. Почти треть соискателей — это специалисты c опытом работы более шести лет (35%), 27% не имеют опыта, 23% имеют опыт от трех до шести лет. Более половины (55%) кандидатов из Москвы, 10% — из Петербурга, 6% — из Татарстана, 5% — из Свердловской области.
# «Нехватка специалистов связана с тем, что рынок только начинает расти и развиваться в РФ,— говорит госпожа Копылова.— У нас в стране достаточно талантливых людей в математике и программировании, а это главные профкомпетенции для входа в данную профессию. Но слишком мало компаний и ограниченное число проектов, где можно набраться опыта». Отчасти это подтверждают данные hh.ru. «Количество вакансий для программистов и инженеров-робототехников в России по кварталам исчисляется десятками»,— отмечает госпожа Скляренко.
# При этом динамика их появления довольно высокая. Так, за неполный четвертый квартал 2020 года было опубликовано на 23% больше предложений о работе, чем в третьем квартале, и на 42% больше, чем годом ранее. Большая часть вакансий опубликована в Москве, на втором месте с небольшим отрывом — Петербург.
# Востребованы сегодня в первую очередь разработчики, проектировщики и инженеры. «От них зависит успех проектов по механизации производств. Большую часть задач решают именно они»,— поясняет госпожа Елисеева. Большинство компаний ищет специалистов с опытом работы от двух лет. Ключевые навыки и компетенции, которые ценятся в кандидатах: развитое мышление, знание прикладной математики, программирования, быстрая обучаемость.
# Екатерина Скляренко добавляет, что в разных вакансиях чаще всего среди требований работодатели указывают высшее образование, понимание основ современной робототехники, навык написания рабочих программ для роботов Fanuc, Kuka, Universal Robots, опыт реализации проектов по автоматизации с применением робототехники, знание схемотехники, электроавтоматики и электротехники, работа с САПР- и CAM-системами, комплексные знания устройств и принципов работы электронных и механических систем и узлов обрабатывающих центров с ЧПУ, знание языков программирования (C++, C#, Java, Python), опыт работы с дронами, опыт программирования микроконтроллеров.
# По данным hh.ru, средняя предлагаемая заработная плата для специалистов отрасли находится в диапазоне от 60 до 100 тыс. рублей. «Как правило, речь идет о фиксированном окладе,— уточняет госпожа Елисеева.— Премии, если они предусмотрены, могут быть квартальными или ежегодными и обычно рассчитываются отдельно. Компании, которые готовы обучать специалистов с нуля, предлагают таким кандидатам значительно меньший доход, чем опытным специалистам».
# По оценке Ольги Копыловой, доход профессионалов может доходить до 300 тыс. рублей в месяц. Алиса Конюховская отмечает, что в робототехнике заработная плата в среднем выше, чем в других сферах, поскольку заняты в ней в основном высококвалифицированные IT-специалисты.
# Несмотря на то, что рынок только начинает расти и компании могут ощущать дефицит редких специалистов, как правило, большинство вакансий закрывается в течение месяца, говорит Юлия Елисеева. По ее словам, отчасти это происходит за счет переобучения возрастных кандидатов. «Если возрастной кандидат, инженер, хочет пройти переобучение, у него есть перспективы и возможности развиваться и в робототехнике»,— говорит эксперт. Впрочем, на практике взрослых специалистов, желающих перейти в эту сферу, немного. По словам эксперта, сейчас робототехнику представляют молодые специалисты.
# Кстати, так называемая образовательная робототехника, помогающая детям осваивать основы компьютерной грамотности, азы математики и работу с различными механизмами, на сегодня самый главный потребитель кадров, считает госпожа Скляренко. «На рынке труда сегодня много предложений для тренеров, методистов, кураторов образовательных программ по робототехнике в учебных заведениях или на курсах для детей. То есть, помимо спроса на готовых специалистов, рынок активно растит новые кадры»,— поясняет она.
# Эксперты прогнозируют рост потребности в специалистах в ближайшие годы. По оценке НАУРР, только в промышленном секторе робототехники общая потребность в квалифицированных специалистах уже сегодня составляет более 24 тыс. специалистов. К 2025 году она возрастет до 40 тыс., к 2030 году — до 66 тыс. человек.
# Анжелика Тихонова
#
# 2020-12-07
# СберКласс представлен на международной конференции AI Journey Junior
#
# На международной конференции AI Journey Junior для школьников, интересующихся искусственным интеллектом, представлена школьная цифровая платформа СберКласс.
# На мастер-классе «Лайфхаки по ИИ для начинающих» детям рассказали о машинном обучении, профессии Data Scientist, объяснили на примере беспилотного автомобиля, какие этапы включает создание алгоритмов искусственного интеллекта. Участники мастер-класса смогли познакомиться с интерфейсом СберКласса, учебными модулями, посвящёнными технологии ИИ, и тренажером языка программирования Python, который в тестовом режиме внедрён в платформу.
# Марина Ракова, вице-президент, директор дивизиона «Цифровые платформы образования» Сбербанка:
# ...
# Курс по правильному питанию также есть у «Силы Воли». За 10 тыс. руб. и 91 день там обещают рассказать о голодании, диетах, спорных продуктах (алкоголе, мучном и пр.). Базовый онлайн-курс рисования в школе рисования Вероники Калачевой с доступом на три месяца стоит 7,5 тыс. руб., на год — 8,5 тыс. руб. Он включает четыре направления: пейзажи, натюрморты, рисование животных, птиц и рыб, а также флористику. Онлайн-курс английского «Месяц за месяц» с индивидуальными занятиями два-три раза в неделю в Lingoda стоит €329 (25,83 тыс. руб. по курсу ЦБ на 12 июня) в месяц.
# По словам Максима Спиридонова, цены онлайн-курсов зависят от набора параметров: стоимости услуг экспертов курса, затрат на команду образовательного продукта — методистов, продюсеров, координаторов, маркетинга, уровня рентабельности продукта и длительности обучения. Также при определении стоимости курса всегда анализируются конкурентные предложения, добавляет он.
# Дмитрий Крутов указывает, что онлайн-образование — это не только предварительно записанные видеоуроки. В первую очередь это сложный IT-продукт — система управления обучением (LMS), это высокие постоянные издержки, которые несильно зависят от колебаний спроса, указывает он. По словам Елизаветы Кондрашовой, стоимость любого образовательного курса «Акселератора ФРИИ» складывается из гонорара преподавателя, наставников, методической разработки, команды сопровождения и накладных расходов в виде аренды площадки и кофе-брейков: «Очевидно, что при такой схеме онлайн-формат не будет стоить значительно меньше очного».
# Время сесть за парту
# Именно летний период может быть хорошим моментом для начала занятий. Как отмечает Роман Кумар Виас, летом практически все игроки раздают скидки, так как это традиционно мертвый сезон в образовании. Максим Спиридонов отмечает, что большинство образовательных компаний уже предоставляют скидки на обучение для пользователей и, скорее всего, предложения будут актуальны еще на весь летний период. Из-за того что после периода повышенного спроса произойдет отток трафика и скидки станут своеобразным триггером и инструментом повышения конверсии аудитории, рассуждает он.
# Но, добавляет господин Спиридонов, компании, у которых такие длительные скидки не были просчитаны заранее, скорее всего, будут плавно повышать стоимость продуктов. Skillbox во время карантина открыл бесплатный доступ к восьми курсам, говорит Дмитрий Крутов. По его словам, изменений ценовой политики сервис не планирует, наоборот, реализует проекты, которые делают онлайн-образование доступнее.
#
#
#
#
# Самые высокооплачиваемые профессии в России
#       Вакансия Зарплата в месяц (тыс. руб.)     Ведущий iOS-разработчик От 300   Разработчик интеграционных решений 230   Директор по управлению персоналом в IT-компании От 200   Руководитель направления стратегического маркетинга От 180   Senior GO Development 180–220   Внутренний аудитор 170–200   Часовой мастер 150   Ведущий дизайнер-консультант в фирме премиальной мебели 150–300   IT-рекрутер 150–200   Программист 1С 150     открыть таблицу в новом окне
# На ноябрь 2019 года.
# Источник: HeadHunter.
# 2020-05-20
# «МТС»  сообщает об увеличении набора специалистов для развития цифровых продуктов компании
#
# На Кубани большинство вакансий открыто в сфере ИТ, но также высока потребность в сотрудниках, способных продавать инновационные решения компании
#
#
#
#
#
#
# Всего в Группе МТС открыто более 600 вакансий по ИТ-направлениям. Востребованы разработчики разного стека технологий (Java, .net, JS, Python и других), DevOps-инженеры, аналитики, специалисты по машинному обучению, QA-инженеры.
# В 2019 году МТС приняла в ИТ-команду 1204 специалиста, в 2020 — более 400. МТС перевела рекрутинг в онлайн и готова продолжать найм ИТ-экспертов, несмотря на дистанционный формат работы большинства сотрудников компании. Интервью проводятся в видеоформате, запущена система удаленной адаптации, предоставления доступов и оформления. Новые сотрудники, чей функционал допускает работу вне офиса, могут сразу приступить к рабочим обязанностям из дома.
#
# 2020-04-09
# В Ростове стартовал прием заявок в бесплатные школы цифровых навыков.
#
# Занятия начнутся 20 апреля и в период эпидемии короновируса будут проходить дистанционно
# Благотворительный фонд «Система», оператор социальных инвестиций АФК «Система», объявляет об открытии бесплатных школ цифровых навыков «Лифт в будущее. Школа» в Ростовской области. В школах дети будут получать дополнительное образование в области сквозных технологий, программирования и микроэлектроники. Стартуют занятия 20 апреля в формате дистанционного обучения. Проект реализуется при поддержке телекоммуникационной компании «МТС» и АО Агрохолдинга «СТЕПЬ».
# Школа цифровых навыков –первая ступень всероссийского образовательного проекта «Лифт в будущее.3.0», задача которого создать в регионах полноценную экосистему для подготовки высококвалифицированных инженеров в области микроэлектроники (со школы и до вступления в профессию). Программа включает в себя: создание сети современных школ на базе региональных образовательных учреждений («Лифт в будущее. Школа»), формирование региональных образовательных кластеров на базе ведущих технических вузов («Лифт в будущее. Академия») и грантовую поддержку молодых ученых («Лифт в будущее. Наука»).
# Продолжительность курса составит три учебных года. Программа развивает алгоритмическое мышление и творческие способности, формирует умения в области программирования и микроэлектроники. В течение курса дети освоят самый актуальный на данный момент язык программирования — Python и получат базовые навыки в сфере микроэлектроники. Обучение будет проходить в малых группах (до 12 человек) по уникальной практико-ориентированной методике под руководством опытных наставников. Дети будут изучать не только теорию, но и использовать полученные знания в решении реальных задач, а также тренироваться работать в командах и управлять проектами — осваивать soft-skills.
# Ученики, успешно завершившие обучение в школе цифровых навыков, смогут перейти на следующую ступень — поступить в «Лифт в будущее. Академия» и воспользоваться преимуществом при поступлении в ведущие вузы-партнеры.
# Председатель правления — генеральный директор АО «БЭСК» Дмитрий Шароватов отметил: «Отечественная энергетика сегодня следует курсом на цифровизацию отрасли. Отрадно, что по практическому внедрению многих цифровых технологий АО «БЭСК» является лидером российского электросетевого комплекса и нам очень нужны специалисты высокой квалификации. Уверен, что данный проект Благотворительного фонда «Система» откроет новые возможности как для профориентации талантливых детей в Республике Башкортостан, так и для пополнения промышленных компаний высококвалифицированными кадрами».
# «Лифт в будущее. Школа» будет работать по двум адресам в Уфе: в Школе № 31 с углубленным изучением отдельных предметов на ул. Рихарда Зорге, д. 50 и в Инженерном лицее-интернате на ул. Нежинской, д. 13. Подать заявку на обучение можно на сайте проекта «Лифт в будущее. Школа»: http://bf.sistema.ru/school/
# Справка
# «Лифт в будущее» – флагманская программа корпоративного фонда АФК «Система», который поддерживает инженерное образование в России с 2011 года. В течение первых пяти лет программа открывала школьникам и студентам по всей стране доступ к дополнительному образованию, в том числе на базе выездных инженерно-конструкторских школ, которые прошли в 11 регионах России. Участниками программ проектного обучения стали свыше 20 тыс. человек. Благодаря программе учебные заведения и преподаватели получали необходимые ресурсы и компетенции в сфере проектной инновационной деятельности.
# В 2018 году БФ «Система» запустил уникальную программу дополнительного образования по микроэлектронике для студентов технических вузов в формате learning-by-doing, соединив вузовскую теорию с практикой технологической индустрии. Цель программы – содействие в получении лучшего образования в области передовых IT-профессий и развитии потенциала для создания собственных проектов.
# К программе дополнительного образования по микроэлектронике присоединились 9 ведущих технических вузов страны (МИЭТ, МАИ, ТГУ, ДВФУ, УрФУ и др.) и крупнейшее микроэлектронное предприятие России – ПАО «Микрон», входящее в ГК «Элемент». По итогу годовой программы были подготовлены новые специалисты в сфере интернета вещей: они получили не только инженерные навыки, но и научились самостоятельно управлять продуктом. На базе разработок двух команд в июне 2019 года был создан первый российский центр коллективного проектирования электроники на Дальнем Востоке.

# %%
# запишем данные в датафрейм
kom_news = pd.DataFrame()
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    time.sleep(0.3)
    if soup.find('div', class_='b-article__publish_date'):
        date = pd.to_datetime(soup.find('div', class_='b-article__publish_date').find('time').get('datetime'), dayfirst=True).date()
    elif soup.find('time', class_='title__cake'):
        date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
    if soup.find('h2', class_='article_name'): 
        title = soup.find('h2', class_='article_name').text
    else: 
        title = soup.find('h1', class_='article_name').text    
    text = soup.find('div', class_='article_text_wrapper').text
    row = {'date': date, 'title': title, 'text': text}
    kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
kom_news
# Out:
#          date                                              title  \
# 0  2021-02-10  Синергия цифровизации: Сбер и ВГУ обновляют до...
# 0  2020-12-25                        Руки, которые стоят миллион
# 0  2020-12-23                        Руки, которые стоят миллион
# 0  2020-12-21                Новые грани тамбовского образования
# 0  2020-12-18                        Руки, которые стоят миллион
# 0  2020-12-15                        Руки, которые стоят миллион
# 0  2020-12-08                    Робототехника нуждается в людях
# 0  2020-12-07  СберКласс представлен на международной конфере...
# 0  2020-12-01  ИИ позволит отслеживать выбросы CO2, связанные...
# 0  2020-10-27                                        В один клик
# 0  2020-09-17           SuSMoST — мощный молекулярный инструмент
# 0  2020-08-17                               Отстали на поколение
# 0  2020-08-11  Питерские и казанские программисты стали побед...
# 0  2020-07-29  В Тутаеве появится центр цифрового образования...
# 0  2020-07-07  Инновации на рынке Fintech и кибербезопасности...
# 0  2020-07-02  В Тутаеве откроют центр цифрового образования ...
# 0  2020-06-30                                  Инвестиции в себя
# 0  2020-05-20  «МТС»  сообщает об увеличении набора специалис...
# 0  2020-04-09  В Ростове стартовал прием заявок в бесплатные ...
# 0  2020-03-06  АО «БЭСК» приняло участие в открытии бесплатны...
# 0  2020-03-03  В Башкирии стартует набор в бесплатные школы ц...
#
#                                                 text
# 0  \n\n\n\n\n\nФото: Сбербанк\n\nПочти год назад ...
# 0  \n\n\n\n\n\n\nЗнаменитый русский композитор, п...
# 0  \n\n\n\n\n\n\nЗнаменитый русский композитор, п...
# 0  \n2020 год стал особенным для системы образова...
# 0  \n\n\n\n\n\n\nЗнаменитый русский композитор, п...
# 0  \n\n\n\n\n\n\nЗнаменитый русский композитор, п...
# 0  \nРоссийский рынок робототехники растет на 10%...
# 0  \nНа международной конференции AI Journey Juni...
# 0  \nСегодня, 1 декабря, канадский исследовательс...
# 0  \nЕвразийские соревнования в IT-сфере Huawei H...
# 0  \nРоссийские ученые разработали программу, кот...
# 0  \nВалерий Макаров, научный руководитель Центра...
# 0  \n8 августа шесть проектов в сфере финтех и ки...
# 0  \nВ городе Тутаеве Ярославской области осенью ...
# 0  \n1-8 августа пройдет второй хакатон из серии ...
# 0  \nОсенью 2020 года в Тутаеве откроют второй в ...
# 0  \nКарантинные меры в связи с пандемией COVID-1...
# 0  \nНа Кубани большинство вакансий открыто в сфе...
# 0  \nЗанятия начнутся 20 апреля и в период эпидем...
# 0  \n\n\n\n\n\nСемиклассники РИЛИ на открытом уро...
# 0  \nВ Уфе стартует набор детей в бесплатные школ...

# %%
# обернем в функцию 
def get_kom_news(links):
    kom_news = pd.DataFrame()
    for link in all_links:
        soup = BeautifulSoup(requests.get(link).text, 'html.parser')
        if soup.find('div', class_='b-article__publish_date'):
            date = pd.to_datetime(soup.find('div', class_='b-article__publish_date').find('time').get('datetime'), dayfirst=True).date()
        elif soup.find('time', class_='title__cake'):
            date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
        if soup.find('h2', class_='article_name'): 
            title = soup.find('h2', class_='article_name').text
        else: 
            title = soup.find('h1', class_='article_name').text    
        text = soup.find('div', class_='article_text_wrapper').text
        row = {'date': date, 'title': title, 'text': text}
        kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
    return kom_news

# %%
kom_news = get_kom_news(all_links)
kom_news

# %% [markdown]
# # API

# %% [markdown]
# ## Практика 3. Получим данные о песнях исполнителя при помощи  [API ITunes](https://developer.apple.com/library/archive/documentation/AudioVideo/Conceptual/iTuneSearchAPI/index.html)

# %%
# https://developer.apple.com/library/archive/documentation/AudioVideo/Conceptual/iTuneSearchAPI/UnderstandingSearchResults.html#//apple_ref/doc/uid/TP40017632-CH8-SW1
URL = 'https://itunes.apple.com/search?term=jack+johnson'

# %%
res = requests.get(URL)

# %%
res.text
# Out:
# '\n\n\n{\n "resultCount":50,\n "results": [\n{"wrapperType":"track", "kind":"music-video", "artistId":909253, "collectionId":1445738051, "trackId":1445738215, "artistName":"Jack Johnson", "collectionName":"To the Sea", "trackName":"You And Your Heart", "collectionCensoredName":"To the Sea", "trackCensoredName":"You And Your Heart (Closed-Captioned)", "artistViewUrl":"https://music.apple.com/us/artist/jack-johnson/909253?uo=4", "collectionViewUrl":"https://music.apple.com/us/music-video/you-and-your-heart-closed-captioned/1445738215?uo=4", "trackViewUrl":"https://music.apple.com/us/music-video/you-and-your-heart-closed-captioned/1445738215?uo=4", \n"previewUrl":"https://video-ssl.itunes.apple.com/itunes-assets/Video115/v4/f0/92/0c/f0920ce2-8bb7-5e62-b44c-36ce701fe7b1/mzvf_6922739671336234286.640x352.h264lc.U.p.m4v", "artworkUrl30":"https://is1-ssl.mzstatic.com/image/thumb/Video/v4/ae/be/c8/aebec8f3-2baa-7708-1cb9-af064c5423a4/source/30x30bb.jpg", "artworkUrl60":"https://is1-ssl.mzstatic.com/image/thumb/Video/v4/ae/be/c8/aebec8f3-2baa-7708-1cb9-af064c5423a4/source/60x60bb.jpg", "artworkUrl100":"https://is1-ssl.mzstatic.com/image/thumb/Video/v4/ae/be/c8/aebec8f3-2baa-7708-1cb9-af064c5423a4/source/100x100bb.jpg", "collectionPrice":11.99, "trackPrice":-1.00, "releaseDate":"2010-06-01T07:00:00Z", "collectionExplicitness":"notExplicit", "trackExplicitness":"notExplicit", "discCount":1, "discNumber":1, "trackCount":15, "trackNumber":14, "trackTimeMillis":197288, "country":"USA", "currency":"USD", "primaryGenreName":"Rock"}, \n{"wrapperType":"track", "kind":"music-video", "artistId":909253, "collectionId":1445828301, "trackId":1445828313, "artistName":"Jack Johnson", "collectionName":"Sleep Through the Static: Remixed", "trackName":"Sleep Through The Static / I Love You And Buddha Too", "collectionCensoredName":"Sleep Through the Static: Remixed", "trackCensoredName":"Sleep Through The Static / I Love You And Buddha Too (Live From The Solar Powered Plastic Plant)", "artistViewUrl":"https://music.apple.com/us/artist/jack-johnson/909253?uo=4", "collectionViewUrl":"https://music.apple.com/us/music-video/sleep-through-static-i-love-you-buddha-too-live-from/1445828313?uo=4", "trackViewUrl":"https://music.apple.com/us/music-video/sleep-through-static-i-love-you-buddha-too-live-from/1445828313?uo=4", \n"previewUrl":"https://video-ssl.itunes.apple.com/itunes-assets/Video118/v4/4a/40/a0/4a40a0b1-9403-64f9-1b86-da6edfb9c5d7/mzvf_7192500523742699525.640x352.h
h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/e0/57/fb/e057fb31-73b9-f79a-11ab-83757b653efb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/e0/57/fb/e057fb31-73b9-f79a-11ab-83757b653efb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/e0/57/fb/e057fb31-73b9-f79a-11ab-83757b653efb/source/100x100bb.jpg',
#    'collectionPrice': 6.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2008-09-23T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 10,
#    'trackNumber': 8,
#    'trackTimeMillis': 220262,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Alternative'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 909253,
#    'collectionId': 1445828301,
#    'trackId': 1445828314,
#    'artistName': 'Jack Johnson',
#    'collectionName': 'Sleep Through the Static: Remixed',
#    'trackName': 'Enemy',
#    'collectionCensoredName': 'Sleep Through the Static: Remixed',
#    'trackCensoredName': 'Enemy (Live from the Solar Powered Plastic Plant)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/jack-johnson/909253?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/music-video/enemy-live-from-the-solar-powered-plastic-plant/1445828314?uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/music-video/enemy-live-from-the-solar-powered-plastic-plant/1445828314?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video118/v4/10/b3/a1/10b3a179-cfde-de0e-38fd-366f124ea4c5/mzvf_6334388115797063087.640x352.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/46/0e/5b/460e5b72-4396-4f0a-0ee8-5fb265addaa6/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/46/0e/5b/460e5b72-4396-4f0a-0ee8-5fb265addaa6/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/46/0e/5b/460e5b72-4396-4f0a-0ee8-5fb265addaa6/source/100x100bb.jpg',
#    'collectionPrice': 6.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2008-09-23T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 10,
#    'trackNumber': 9,
#    'trackTimeMillis': 211923,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Alternative'},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1504747175,
#    'trackId': 1063466898,
#    'artistName': 'J.J. Abrams',
#    'collectionName': 'Star Wars: The Skywalker Saga (9-Movie Collection)',
#    'trackName': 'Star Wars: The Force Awakens',
#    'collectionCensoredName': 'Star Wars: The Skywalker Saga (9-Movie Collection)',
#    'trackCensoredName': 'Star Wars: The Force Awakens',
#    'collectionArtistId': 410641764,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/buena-vista-home-entertainment-inc/410641764?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/star-wars-the-force-awakens/id1063466898?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/star-wars-the-force-awakens/id1063466898?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video82/v4/a3/ef/25/a3ef253a-208e-3cbc-cbf0-bc444dae2f8d/mzvf_6313901593442783545.640x354.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video123/v4/1f/2b/ae/1f2bae7f-62a1-1055-8471-401291b6dcdd/pr_source.lsr/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video123/v4/1f/2b/ae/1f2bae7f-62a1-1055-8471-401291b6dcdd/pr_source.lsr/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video123/v4/1f/2b/ae/1f2bae7f-62a1-1055-8471-401291b6dcdd/pr_source.lsr/100x100bb.jpg',
#    'collectionPrice': 19.99,
#    'trackPrice': 19.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 19.99,
#    'trackHdPrice': 19.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '2015-12-18T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 9,
#    'trackNumber': 3,
#    'trackTimeMillis': 8302127,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Action & Adventure',
#    'contentAdvisoryRating': 'PG-13',
#    'shortDescription': 'Lucasfilm and visionary director J.J. Abrams join forces to take you back again to a galaxy far, far',
#    'longDescription': "Visionary director J.J. Abrams brings to life the motion picture event of a generation. As Kylo Ren and the sinister First Order rise from the ashes of the Empire, Luke Skywalker is missing when the galaxy needs him most. It's up to Rey, a desert scavenger, and Finn, a defecting stormtrooper, to join forces with Han Solo and Chewbacca in a desperate search for the one hope of restoring peace to the galaxy.",
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 909253,
#    'collectionId': 1445828301,
#    'trackId': 1445828315,
#    'artistName': 'Jack Johnson',
#    'collectionName': 'Sleep Through the Static: Remixed',
#    'trackName': 'Adrift',
#    'collectionCensoredName': 'Sleep Through the Static: Remixed',
#    'trackCensoredName': 'Adrift (Live from the Solar Powered Plastic Plant)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/jack-johnson/909253?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/music-video/adrift-live-from-the-solar-powered-plastic-plant/1445828315?uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/music-video/adrift-live-from-the-solar-powered-plastic-plant/1445828315?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video128/v4/fd/0b/3a/fd0b3a65-e9a0-48a3-8f7a-57de04118330/mzvf_8207109141616879086.640x352.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/6f/0e/40/6f0e40b8-285c-ab2b-633e-0d6477a4dfb7/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/6f/0e/40/6f0e40b8-285c-ab2b-633e-0d6477a4dfb7/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/6f/0e/40/6f0e40b8-285c-ab2b-633e-0d6477a4dfb7/source/100x100bb.jpg',
#    'collectionPrice': 6.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2008-09-23T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 10,
#    'trackNumber': 10,
#    'trackTimeMillis': 180805,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Alternative'},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1502169871,
#    'trackId': 1315255745,
#    'artistName': 'Jake Kasdan',
#    'collectionName': 'Jumanji: Welcome to the Jungle + Jumanji: The Next Level',
#    'trackName': 'Jumanji: Welcome to the Jungle',
#    'collectionCensoredName': 'Jumanji: 2 Film Bundle',
#    'trackCensoredName': 'Jumanji: Welcome to the Jungle',
#    'collectionArtistId': 345346702,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/sony-pictures-entertainment/345346702?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/jumanji-welcome-to-the-jungle/id1315255745?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/jumanji-welcome-to-the-jungle/id1315255745?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video118/v4/42/b9/a0/42b9a0b1-60e4-86c0-36b3-915522d45765/mzvf_172183937853883111.640x354.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video125/v4/2a/0c/0e/2a0c0ef1-6026-4659-f5f0-8f1f9a0b5e8a/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video125/v4/2a/0c/0e/2a0c0ef1-6026-4659-f5f0-8f1f9a0b5e8a/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video125/v4/2a/0c/0e/2a0c0ef1-6026-4659-f5f0-8f1f9a0b5e8a/source/100x100bb.jpg',
#    'collectionPrice': 14.99,
#    'trackPrice': 14.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 14.99,
#    'trackHdPrice': 14.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '2017-12-20T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 2,
#    'trackNumber': 1,
#    'trackTimeMillis': 7154612,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Action & Adventure',
#    'contentAdvisoryRating': 'PG-13',
#    'shortDescription': 'Four teenagers in detention discover an old video console with a game they’ve never heard of. When',
#    'longDescription': 'Four teenagers in detention discover an old video console with a game they’ve never heard of. When they decide to play, they are immediately sucked into the jungle world of Jumanji in the bodies of their avatars (Dwayne Johnson, Jack Black, Kevin Hart, and Karen Gillan). They’ll have to complete the adventure of their lives filled with fun, thrills and danger or be stuck in the game forever!',
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1502173677,
#    'trackId': 1488964698,
#    'artistName': 'Jake Kasdan',
#    'collectionName': 'Jumanji Bienvenue Dans La Jungle + Jumanji Next Level',
#    'trackName': 'Jumanji: The Next Level',
#    'collectionCensoredName': 'Jumanji Bienvenue Dans La Jungle + Jumanji Next Level',
#    'trackCensoredName': 'Jumanji: The Next Level',
#    'collectionArtistId': 345346702,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/sony-pictures-entertainment/345346702?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/jumanji-the-next-level/id1488964698?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/jumanji-the-next-level/id1488964698?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video113/v4/10/c1/51/10c15162-a881-fdf5-149f-850147f526d0/mzvf_10451023053396014921.640x352.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video114/v4/1d/50/26/1d502647-3349-738d-af07-f8714b9ffa8a/pr_source.lsr/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video114/v4/1d/50/26/1d502647-3349-738d-af07-f8714b9ffa8a/pr_source.lsr/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video114/v4/1d/50/26/1d502647-3349-738d-af07-f8714b9ffa8a/pr_source.lsr/100x100bb.jpg',
#    'collectionPrice': 14.99,
#    'trackPrice': 14.99,
#    'collectionHdPrice': 14.99,
#    'trackHdPrice': 14.99,
#    'releaseDate': '2019-12-13T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 2,
#    'trackNumber': 2,
#    'trackTimeMillis': 7399223,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Action & Adventure',
#    'contentAdvisoryRating': 'PG-13',
#    'shortDescription': 'As the gang returns to Jumanji, they will have to brave parts unknown and unexplored in order to',
#    'longDescription': 'In Jumanji: The Next Level, the gang is back (Dwayne Johnson, Jack Black, Kevin Hart and Karen Gillan) but the game has changed. As they return to Jumanji to rescue one of their own, they discover that nothing is as they expect. The players will have to brave parts unknown and unexplored, from the arid deserts to the snowy mountains, in order to escape the world’s most dangerous game.',
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1538638348,
#    'trackId': 522395870,
#    'artistName': 'Stanley Kubrick',
#    'collectionName': 'Stanley Kubrick 3-Film-Collection',
#    'trackName': 'The Shining',
#    'collectionCensoredName': 'Stanley Kubrick 3-Film-Collection',
#    'trackCensoredName': 'The Shining',
#    'collectionArtistId': 199257486,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/warner-bros-entertainment-inc/199257486?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/the-shining/id522395870?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/the-shining/id522395870?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video113/v4/b5/ba/9b/b5ba9b22-a729-6922-a5d7-5048995c714e/mzvf_16016633912569956430.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video114/v4/48/93/34/4893342e-7138-179b-e84b-3623a6cb2ba1/pr_source.lsr/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video114/v4/48/93/34/4893342e-7138-179b-e84b-3623a6cb2ba1/pr_source.lsr/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video114/v4/48/93/34/4893342e-7138-179b-e84b-3623a6cb2ba1/pr_source.lsr/100x100bb.jpg',
#    'collectionPrice': 14.99,
#    'trackPrice': 14.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 14.99,
#    'trackHdPrice': 14.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '1980-05-23T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 3,
#    'trackNumber': 3,
#    'trackTimeMillis': 8626628,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Horror',
#    'contentAdvisoryRating': 'R',
#    'shortDescription': "Academy Award winner Jack Nicholson and Shelley Duvall star in director Stanley Kubrick's disturbing",
#    'longDescription': "Academy Award winner Jack Nicholson and Shelley Duvall star in director Stanley Kubrick's disturbing adaptation of Stephen King's blockbuster horror novel. When writer Jack Torrance (Nicholson)--who has a history of alcoholism and child abuse--takes a job as winter caretaker for a hotel high in the Rocky Mountains, he, his wife (Duvall) and their psychic young son will be isolated until spring. But once the first blizzard closes the road out, the accumulated power of evil deeds committed at the hotel begins to drive Jack mad. Now there may be no escape for his wife and son in this haunting madness, memory and family violence.",
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'trackId': 1515512877,
#    'artistName': 'Rod Lurie',
#    'trackName': 'The Outpost',
#    'trackCensoredName': 'The Outpost',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/the-outpost/id1515512877?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video114/v4/69/ca/73/69ca73d7-3609-2b13-473f-bb6fe26fa828/mzvf_10824856657231643563.640x460.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video113/v4/35/c4/ca/35c4ca11-e7a4-6154-45b5-a9f3a53a1d08/pr_source.lsr/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video113/v4/35/c4/ca/35c4ca11-e7a4-6154-45b5-a9f3a53a1d08/pr_source.lsr/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video113/v4/35/c4/ca/35c4ca11-e7a4-6154-45b5-a9f3a53a1d08/pr_source.lsr/100x100bb.jpg',
#    'collectionPrice': 14.99,
#    'trackPrice': 14.99,
#    'trackRentalPrice': 4.99,
#    'collectionHdPrice': 14.99,
#    'trackHdPrice': 14.99,
#    'trackHdRentalPrice': 4.99,
#    'releaseDate': '2020-07-03T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 7393632,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Action & Adventure',
#    'contentAdvisoryRating': 'R',
#    'shortDescription': 'Based on true events. A team of U.S. soldiers stationed at the deadliest outpost in Afghanistan are',
#    'longDescription': 'Based on true events, in this military thriller, a small unit of U.S. soldiers, alone at the remote Combat Outpost Keating, located deep in the valley of three mountains in Afghanistan, battles to defend against an overwhelming force of Taliban fighters in a coordinated attack. The Battle of Kamdesh, as it was known, was the bloodiest American engagement of the Afghan War in 2009 and Bravo Troop 3-61 CAV became one of the most decorated units of the 19-year conflict.',
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1483657612,
#    'trackId': 1266109512,
#    'artistName': 'Steven Soderbergh',
#    'collectionName': 'Smart Comedies',
#    'trackName': 'Logan Lucky',
#    'collectionCensoredName': 'Smart Comedies',
#    'trackCensoredName': 'Logan Lucky',
#    'collectionArtistId': 345353262,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/universal-studios-home-entertainment/345353262?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/logan-lucky/id1266109512?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/logan-lucky/id1266109512?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video118/v4/80/8c/a2/808ca215-7268-e6b0-9480-b1def415154e/mzvf_8707233484467779285.640x354.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video128/v4/d6/13/0b/d6130b43-c816-d561-cfdc-9eaf6ae6d1c5/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video128/v4/d6/13/0b/d6130b43-c816-d561-cfdc-9eaf6ae6d1c5/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video128/v4/d6/13/0b/d6130b43-c816-d561-cfdc-9eaf6ae6d1c5/source/100x100bb.jpg',
#    'collectionPrice': 29.99,
#    'trackPrice': 14.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 34.99,
#    'trackHdPrice': 14.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '2017-08-18T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 5,
#    'trackNumber': 5,
#    'trackTimeMillis': 7143840,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Action & Adventure',
#    'contentAdvisoryRating': 'PG-13',
#    'shortDescription': 'Trying to reverse a family curse, brothers Jimmy (Channing Tatum) and Clyde Logan (Adam Driver) set',
#    'longDescription': "Hoping to reverse a 'curse' that's hung over his family for generations, Jimmy Logan (Channing Tatum) hatches a plan to rob the Charlotte Motor Speedway during the Coca-Cola 600, NASCAR's biggest race of the year. He convinces his bartender brother Clyde (Adam Driver) and hairdresser sister Mellie (Riley Keough) to help him pull everything off--but first they have to break the bomb maker Joe Bang (Daniel Craig) out of jail in broad daylight. Academy Award® winner Hilary Swank plays a no-nonsense FBI agent determined to bring the Logans to justice and keep them from racing away with the loot in this high-speed caper from Academy Award®-winning director Steven Soderbergh.",
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'trackId': 1450546361,
#    'artistName': 'Stephen Merchant',
#    'trackName': 'Fighting With My Family',
#    'trackCensoredName': 'Fighting With My Family',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/fighting-with-my-family/id1450546361?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video124/v4/34/2a/01/342a01b8-994d-cde8-215a-5a2b32da5448/mzvf_6573278904134096288.640x352.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video113/v4/34/d6/29/34d62948-4b6b-f101-eb0d-7cbcd319a145/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video113/v4/34/d6/29/34d62948-4b6b-f101-eb0d-7cbcd319a145/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video113/v4/34/d6/29/34d62948-4b6b-f101-eb0d-7cbcd319a145/source/100x100bb.jpg',
#    'collectionPrice': 14.99,
#    'trackPrice': 14.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 14.99,
#    'trackHdPrice': 14.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '2019-02-22T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 6483775,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Comedy',
#    'contentAdvisoryRating': 'PG-13',
#    'longDescription': 'Reformed gangster and wrestler Ricky and his wife Julia make a living performing with their children Saraya and Zak. When brother and sister get the chance to audition for WWE, it seems the family dream is coming true but they are about to learn that becoming a WWE Superstar demands more than they ever imagined possible.',
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'artistId': 909253,
#    'trackId': 1487135503,
#    'artistName': 'Jack Johnson',
#    'trackName': 'All At Once: On the Road Tour Documentary',
#    'trackCensoredName': 'All At Once: On the Road Tour Documentary',
#    'artistViewUrl': 'https://music.apple.com/us/artist/jack-johnson/909253?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/all-at-once-on-the-road-tour-documentary/id1487135503?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video111/v4/a8/e5/19/a8e5199c-df7e-7ff1-6c87-0bc4db95a201/mzvf_2579342668513896153.640x476.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/94/0f/0c/940f0cfb-3368-1e16-f94f-f89c27ae8496/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/94/0f/0c/940f0cfb-3368-1e16-f94f-f89c27ae8496/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/94/0f/0c/940f0cfb-3368-1e16-f94f-f89c27ae8496/source/100x100bb.jpg',
#    'collectionPrice': 7.99,
#    'trackPrice': 7.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 9.99,
#    'trackHdPrice': 9.99,
#    'trackHdRentalPrice': 4.99,
#    'releaseDate': '2016-04-08T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 2472388,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Concert Films',
#    'contentAdvisoryRating': 'NR',
#    'shortDescription': 'This film takes an intimate look at Jack Johnson’s music and tour greening initiatives. When Jack',
#    'longDescription': 'This film takes an intimate look at Jack Johnson’s music and tour greening initiatives. When Jack goes on the road, he doesn’t just show up and play music. The tour partners with local non-profits, local food vendors and strives to leave a lasting positive impact. The entire tour is an extension of the environmentally conscious and socially engaged life he leads along with his wife, Kim. After years on the road, playing venues around the globe, the Johnson’s have established an inspiring way of touring with a focus on creating as little impact on the earth as possible. Along the way, the tour gives a platform to dozens of local non-profits working to educate and inspire others to make choices that benefit our communities and the greater global environment. While following Jack’s 2014 west coast tour, this film highlights the Johnson‘s Kokua Hawaii Foundation, the All At Once campaign, and several non-profit partners and businesses focusing on plastic free initiatives and sustainable local food systems. Additionally, the film highlights the unique way in which tour is run. From traveling on biodiesel-powered buses, to sourcing organic and locally grown meals to carefully disposing of waste created along the way. The goal of the tour and this documentary is to inspire people to get involved, make the right choices, and enjoy the music along the way.'},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1455689014,
#    'trackId': 872652035,
#    'artistName': 'Wally Pfister',
#    'collectionName': 'Transcendence / Her',
#    'trackName': 'Transcendence (2014)',
#    'collectionCensoredName': 'Transcendence / Her',
#    'trackCensoredName': 'Transcendence (2014)',
#    'collectionArtistId': 199257486,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/warner-bros-entertainment-inc/199257486?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/transcendence-2014/id872652035?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/transcendence-2014/id872652035?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video122/v4/ed/c4/42/edc44224-6626-47ba-055c-04132a9e647a/mzvf_1713063716496264176.640x354.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/ab/ab/8a/abab8a04-4585-02be-b663-89124a404f51/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/ab/ab/8a/abab8a04-4585-02be-b663-89124a404f51/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/ab/ab/8a/abab8a04-4585-02be-b663-89124a404f51/source/100x100bb.jpg',
#    'collectionPrice': 19.98,
#    'trackPrice': 6.99,
#    'trackRentalPrice': 2.99,
#    'collectionHdPrice': 19.98,
#    'trackHdPrice': 6.99,
#    'trackHdRentalPrice': 2.99,
#    'releaseDate': '2014-04-18T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 2,
#    'trackNumber': 1,
#    'trackTimeMillis': 7154655,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Sci-Fi & Fantasy',
#    'contentAdvisoryRating': 'PG-13',
#    'shortDescription': 'Dr. Will Caster is the foremost researcher in the field of Artificial Intelligence, working to',
#    'longDescription': "Dr. Will Caster is the foremost researcher in the field of Artificial Intelligence, working to create a sentient machine that combines the collective intelligence of everything ever known with the full range of human emotions. His highly controversial experiments have made him famous, but they have also made him the prime target of anti-technology extremists who will do whatever it takes to stop him. However, in their attempt to destroy Will, they inadvertently become the catalyst for him to succeed-to be a participant in his own transcendence. For his wife Evelyn (Rebecca Hall) and best friend Max Waters (Paul Bettany), both fellow researchers, the question is not if they can... but if they should. Their worst fears are realized as Will's thirst for knowledge evolves into a seemingly omnipresent quest for power, to what end is unknown. The only thing that is becoming terrifyingly clear is there may be no way to stop him.",
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1525654165,
#    'trackId': 1212655586,
#    'artistName': 'Unknown',
#    'collectionName': 'Los Pitufos - colección 5 Películas',
#    'trackName': 'Smurfs: The Lost Village',
#    'collectionCensoredName': 'Los Pitufos - colección 5 Películas',
#    'trackCensoredName': 'Smurfs: The Lost Village',
#    'collectionArtistId': 345346702,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/sony-pictures-entertainment/345346702?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/smurfs-the-lost-village/id1212655586?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/smurfs-the-lost-village/id1212655586?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video111/v4/d4/b7/e4/d4b7e424-57c2-1673-e3a3-727b7bd338a8/mzvf_894817716214925515.640x456.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video114/v4/f0/ad/ff/f0adff1b-a4bf-0e2b-718c-bbf921b031f2/pr_source.lsr/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video114/v4/f0/ad/ff/f0adff1b-a4bf-0e2b-718c-bbf921b031f2/pr_source.lsr/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video114/v4/f0/ad/ff/f0adff1b-a4bf-0e2b-718c-bbf921b031f2/pr_source.lsr/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 12.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 14.99,
#    'trackHdPrice': 14.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '2017-04-07T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 5,
#    'trackNumber': 5,
#    'trackTimeMillis': 5405357,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Kids & Family',
#    'contentAdvisoryRating': 'PG',
#    'shortDescription': 'In this fully animated, all-new take on the Smurfs, a mysterious map sets Smurfette and her best',
#    'longDescription': 'In this fully animated, all-new take on the Smurfs, a mysterious map sets Smurfette and her best friends Brainy, Clumsy and Hefty on an exciting and thrilling race through the Forbidden Forest filled with magical creatures to find a mysterious lost village before the evil wizard Gargamel does. Embarking on a roller coaster journey full of action and danger, the Smurfs are on a course that leads to the discovery of the biggest secret in Smurf history!',
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'trackId': 915871210,
#    'artistName': 'Dave Green',
#    'trackName': 'Earth to Echo',
#    'trackCensoredName': 'Earth to Echo',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/earth-to-echo/id915871210?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video111/v4/c9/6d/93/c96d9356-6d91-be49-7b76-fdd9a3ab5939/mzvf_4326775294140110462.640x458.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video5/v4/93/87/42/93874249-e1cf-bd15-75c9-dbdf7fa29f56/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video5/v4/93/87/42/93874249-e1cf-bd15-75c9-dbdf7fa29f56/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video5/v4/93/87/42/93874249-e1cf-bd15-75c9-dbdf7fa29f56/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 12.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 12.99,
#    'trackHdPrice': 12.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '2014-07-02T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 5474613,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Action & Adventure',
#    'contentAdvisoryRating': 'PG',
#    'shortDescription': 'Tuck, Munch and Alex are a trio of inseparable friends whose lives are about to change. Their',
#    'longDescription': 'Tuck, Munch and Alex are a trio of inseparable friends whose lives are about to change. Their neighborhood is being destroyed by a highway construction project that is forcing their families to move away. But just two days before they must part ways, the boys begin receiving a strange series of signals on their phones. Convinced something bigger is going on, they team up with another school friend, Emma, and set out to look for the source of their phone signals. What they discover is something beyond their wildest imaginations: a small alien who has become stranded on Earth. In need of their help, the four friends come together to protect the alien and help him find his way home. This journey, full of wonder and adventure, is their story, and their secret.',
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1451260465,
#    'trackId': 303821283,
#    'artistName': 'Barry Levinson',
#    'collectionName': 'Award Winners: Best Actor',
#    'trackName': 'Rain Man',
#    'collectionCensoredName': 'Award Winners: Best Actor',
#    'trackCensoredName': 'Rain Man',
#    'collectionArtistId': 84755883,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/mgm/84755883?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/rain-man/id303821283?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/rain-man/id303821283?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video128/v4/8f/0c/3d/8f0c3ddb-8b5d-ca51-709d-a4c5445f3a86/mzvf_3658363766175086127.640x458.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video41/v4/c7/fd/64/c7fd64ec-3e4c-4008-7674-5ba90cf0cf26/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video41/v4/c7/fd/64/c7fd64ec-3e4c-4008-7674-5ba90cf0cf26/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video41/v4/c7/fd/64/c7fd64ec-3e4c-4008-7674-5ba90cf0cf26/source/100x100bb.jpg',
#    'collectionPrice': 34.99,
#    'trackPrice': 14.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 34.99,
#    'trackHdPrice': 14.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '1988-12-16T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 4,
#    'trackNumber': 3,
#    'trackTimeMillis': 8035693,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Drama',
#    'contentAdvisoryRating': 'R',
#    'longDescription': "When Charlie Babbitt goes home to the Midwest for his estranged father's funeral, he learns not only that he's been cut out of his inheritance, but that he has a grown brother...Raymond...who has been sheltered almost all of his life in an East Coast institution for the developmentally disabled. Raymond is an autistic savant...a person who is severely limited in most mental areas but extremely gifted in others. After traveling to the institution, Charlie kidnaps Raymond but then finds that Raymond will only fly Qantas. So the two begin a long cross-country odyssey in their father's 1949 Buick Roadmaster convertible...a trip that will lead them to understanding and love, and for Charlie a kind of redemption."},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'trackId': 1288858258,
#    'artistName': 'S. Craig Zahler',
#    'trackName': 'Brawl In Cell Block 99',
#    'trackCensoredName': 'Brawl In Cell Block 99',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/brawl-in-cell-block-99/id1288858258?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video128/v4/ff/b1/ce/ffb1cef0-f242-e67e-8728-2bb499721369/mzvf_6152102678793919243.640x460.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/47/29/e0/4729e05e-31e2-7575-3090-3561f5c5be61/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/47/29/e0/4729e05e-31e2-7575-3090-3561f5c5be61/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/47/29/e0/4729e05e-31e2-7575-3090-3561f5c5be61/source/100x100bb.jpg',
#    'collectionPrice': 13.99,
#    'trackPrice': 13.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 14.99,
#    'trackHdPrice': 14.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '2017-10-06T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 7952415,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Action & Adventure',
#    'contentAdvisoryRating': 'Unrated',
#    'shortDescription': 'When Bradley (Vince Vaughn) finds himself in a gunfight between the police and his own ruthless',
#    'longDescription': 'When Bradley (Vince Vaughn) finds himself in a gunfight between the police and his own ruthless allies, he is thrown in prison, where his enemies force him to commit acts of violence that turn the place into a savage battleground.',
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1512618438,
#    'trackId': 271860957,
#    'artistName': 'James L. Brooks',
#    'collectionName': 'Must-Watch Award-Winning 5-Film Collection',
#    'trackName': 'As Good As It Gets',
#    'collectionCensoredName': 'Must-Watch Award-Winning 5-Film Collection',
#    'trackCensoredName': 'As Good As It Gets',
#    'collectionArtistId': 345346702,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/sony-pictures-entertainment/345346702?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/as-good-as-it-gets/id271860957?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/as-good-as-it-gets/id271860957?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video128/v4/fe/5c/e1/fe5ce190-5e3b-4d95-636a-1e241ddb6383/mzvf_2464839205232181025.640x376.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/9d/4d/63/9d4d631b-c2e1-ddd5-5457-7b7c03330a31/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/9d/4d/63/9d4d631b-c2e1-ddd5-5457-7b7c03330a31/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/9d/4d/63/9d4d631b-c2e1-ddd5-5457-7b7c03330a31/source/100x100bb.jpg',
#    'collectionPrice': 39.99,
#    'trackPrice': 12.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 39.99,
#    'trackHdPrice': 12.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '1997-12-23T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 5,
#    'trackNumber': 5,
#    'trackTimeMillis': 8318975,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Comedy',
#    'contentAdvisoryRating': 'PG-13',
#    'longDescription': "Jack Nicholson, Helen Hunt, Greg Kinnear and Cuba Gooding, Jr., star in James L. Brooks' hit comedy, As Good As It Gets. Nicholson gives a show-stopping performance as Melvin Udall, an obsessive-compulsive novelist with Manhattan's meanest mouth. But when his neighbor Simon is hospitalized, Melvin is forced to babysit Simon's dog. And that unexpected act of kindness, along with waitress Carol Connelly, helps put Melvin back in the human race."},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'collectionId': 1539041181,
#    'trackId': 1454342398,
#    'artistName': 'S. Craig Zahler',
#    'collectionName': 'Action + Comedy Collection',
#    'trackName': 'Dragged Across Concrete',
#    'collectionCensoredName': 'Action + Comedy Collection',
#    'trackCensoredName': 'Dragged Across Concrete',
#    'collectionArtistId': 345356312,
#    'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/lions-gate-films-inc/345356312?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/movie/dragged-across-concrete/id1454342398?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/dragged-across-concrete/id1454342398?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video114/v4/f0/b7/97/f0b7971b-c002-1158-dede-30baae4d55f3/mzvf_5256704124952860706.640x352.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video113/v4/a2/4a/37/a24a3752-c1e4-6faa-efe8-96cf29cbd21c/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video113/v4/a2/4a/37/a24a3752-c1e4-6faa-efe8-96cf29cbd21c/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video113/v4/a2/4a/37/a24a3752-c1e4-6faa-efe8-96cf29cbd21c/source/100x100bb.jpg',
#    'collectionPrice': 19.99,
#    'trackPrice': 9.99,
#    'trackRentalPrice': 3.99,
#    'collectionHdPrice': 19.99,
#    'trackHdPrice': 10.99,
#    'trackHdRentalPrice': 3.99,
#    'releaseDate': '2019-03-22T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 5,
#    'trackNumber': 2,
#    'trackTimeMillis': 9510175,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Action & Adventure',
#    'contentAdvisoryRating': 'R',
#    'shortDescription': 'Two police detectives (Mel Gibson, Vince Vaughn) find themselves suspended when a video of their',
#    'longDescription': 'Two police detectives (Mel Gibson, Vince Vaughn) find themselves suspended when a video of their strong-arm tactics is leaked to the media. With little money and no options, the embittered policemen descend into the criminal underworld and find more than they wanted waiting in the shadows.',
#    'hasITunesExtras': True},
#   {'wrapperType': 'track',
#    'kind': 'feature-movie',
#    'artistId': 909253,
#    'trackId': 1467927519,
#    'artistName': 'Jack Johnson',
#    'trackName': 'En Concert',
#    'trackCensoredName': 'En Concert',
#    'artistViewUrl': 'https://music.apple.com/us/artist/jack-johnson/909253?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/movie/en-concert/id1467927519?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music71/v4/3a/a0/2d/3aa02d4c-0cb4-286e-1aa6-b720da614080/rm_image.jpg/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'collectionExplicitness': 'notExplicit',
#    'trackCount': 1,
#    'copyright': '© 2016 WE CANT BE BEAT LLC',
#    'country': 'USA',
#    'currency': 'USD',
#    'releaseDate': '2016-08-24T07:00:00Z',
#    'primaryGenreName': 'History',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview113/v4/8c/1f/bf/8c1fbf45-e5f8-b0fd-2829-699fb3a86555/mzaf_336937109248618947.std.aac.p.m4a',
#    'description': "The Ottoman Empire was a strong world power for over 600 years beginning in the late 13th century. How did it rise from one man who was given charge of a small parcel of land to an empire that spanned three continents? Why did it begin to lose battle after battle, eventually reaching a point where it was beaten back by its enemies? Which sultans presented the empire with the tools for success and which destroyed the unity? What contributed to its demise? <br /><br />These questions and more will be answered through this book as the secrets of the Ottoman Empire are revealed. This book contains a description of the origins and basics about the population of citizens within the empire along with descriptions about each of the 36 emperors' personal rises and falls in their quest to better the empire. Additionally, the contributions the Ottomans made to their empire and beyond to other countries will be described along with the daily life of those within the palace and those without. Is there anything left today that came from the Ottoman Empire? Or did the Ottoman Empire simply disappear without a trace left to indicate it existed?"},
#   {'wrapperType': 'audiobook',
#    'artistId': 1036384314,
#    'collectionId': 1088429617,
#    'artistName': 'Jack Johnson',
#    'collectionName': "Abraham Lincoln - 'Honest Abe': The Life and Times of the Man Who Led America Through Its Greatest Moral, Political, and Constitutional Crisis (Unabridged)",
#    'collectionCensoredName': "Abraham Lincoln - 'Honest Abe': The Life and Times of the Man Who Led America Through Its Greatest Moral, Political, and Constitutional Crisis (Unabridged)",
#    'artistViewUrl': 'https://books.apple.com/us/author/jack-johnson/id1036384314?uo=4',
#    'collectionViewUrl': 'https://books.apple.com/us/audiobook/abraham-lincoln-honest-abe-life-times-man-who-led-america/id1088429617?uo=4',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music49/v4/ab/e3/ef/abe3efd7-977a-a5c6-d74f-1b049741f1cc/rm_image.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music49/v4/ab/e3/ef/abe3efd7-977a-a5c6-d74f-1b049741f1cc/rm_image.jpg/100x100bb.jpg',
#    'collectionPrice': 5.99,
#    'collectionExplicitness': 'notExplicit',
#    'trackCount': 1,
#    'copyright': '© 2016 WE CANT BE BEAT LLC',
#    'country': 'USA',
#    'currency': 'USD',
#    'releaseDate': '2016-02-26T08:00:00Z',
#    'primaryGenreName': 'Nonfiction',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview113/v4/48/45/16/48451665-2dec-fc36-2b56-ba7b539e158f/mzaf_4691711533170477284.std.aac.p.m4a',
#    'description': "<i>Honest Abe</i> was written to act as your easy reference point that contains everything you need to know about the life and times of Abraham Lincoln. Throughout the book, I have sought to paint the picture of the scenes I describe, so that this is more than an academic treatise. This book is meant to be more of a movie; a movie that plays out in your head as you hear its vivid details, so that you can feel that you were there as it was happening. <br /><br />This is certainly a quick listen, but it is densely packed with information that so many historians tend to overlook. Lincoln's story is a gripping tale, from beginning to end. Given the massive nature of his accomplishments and the nearly six decades he lived, you might wonder how these words can adequately cover so much ground. This book will give you an excellent grasp of the man - as a son, as a younger brother, as a father, as a thinker, as a politician, and, of course, as our 16th president."},
#   {'wrapperType': 'audiobook',
#    'artistId': 1036384314,
#    'collectionId': 1127481158,
#    'artistName': 'Jack Johnson',
#    'collectionName': "Ambition Without Boundaries: How Julius Caesar's Thirst for Conquest Shaped the Ancient World, and Impacted the Modern One (Unabridged)",
#    'collectionCensoredName': "Ambition Without Boundaries: How Julius Caesar's Thirst for Conquest Shaped the Ancient World, and Impacted the Modern One (Unabridged)",
#    'artistViewUrl': 'https://books.apple.com/us/author/jack-johnson/id1036384314?uo=4',
#    'collectionViewUrl': 'https://books.apple.com/us/audiobook/ambition-without-boundaries-how-julius-caesars-thirst/id1127481158?uo=4',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music60/v4/eb/22/c4/eb22c4b4-c94e-5a47-1b69-caddf84337bb/rm_image.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music60/v4/eb/22/c4/eb22c4b4-c94e-5a47-1b69-caddf84337bb/rm_image.jpg/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'collectionExplicitness': 'notExplicit',
#    'trackCount': 1,
#    'copyright': '© 2016 WE CANT BE BEAT LLC',
#    'country': 'USA',
#    'currency': 'USD',
#    'releaseDate': '2016-06-23T07:00:00Z',
#    'primaryGenreName': 'History',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/53/45/6e/53456ed7-1033-83bc-b01a-5a3fa1186665/mzaf_1185154278098523116.std.aac.p.m4a',
#    'description': "This biography on one of history's most storied figures takes listeners on an exciting journey through the detailed history of Julius Caesar. Julius Caesar was a man who influenced the world in unparalleled ways, and his story is one loaded with an extravagant cast of politicians, generals, and royalty. It makes for a riveting tale of intrigue and melodrama. <br /><br />The audiobook begins with Caesar's early life, and the humble background from which he came. His accounts of great triumphs and great defeats are all included, as his exciting and eventful life is traced through the minutes of the book. Caesar was part of a time where record keeping was incredibly proficient, and the pieces we have to put together the life of this man and those around him are plentiful. Caesar's story is important down to the last detail, and this book encapsulates the details that matter, and help paint a picture of this legendary figure and the tumultuous time in which he lived. <br /><br />The greatest forms of entertainment can be found in the truth, rather than fiction, and Caesar's life is proof of this. It is history that tells us the most extravagant and unbelievable stories. No matter what amount of speculation or conjecture you throw into this story, the impact of Caesar's life is undeniable. His legacy is one that must be heard, and all that you could want to know about the man lies within this audiobook."},
#   {'wrapperType': 'audiobook',
#    'artistId': 1427820018,
#    'collectionId': 1441509207,
#    'artistName': 'Jack Johnson & Jack Gilinsky',
#    'collectionName': "Jack & Jack: You Don't Know Jacks",
#    'collectionCensoredName': "Jack & Jack: You Don't Know Jacks",
#    'artistViewUrl': 'https://books.apple.com/us/author/jack-johnson/id1427820018?uo=4',
#    'collectionViewUrl': 'https://books.apple.com/us/audiobook/jack-jack-you-dont-know-jacks/id1441509207?uo=4',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music118/v4/13/d0/d5/13d0d5a5-347d-0cb4-a170-4846e46065d0/9780062570154.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music118/v4/13/d0/d5/13d0d5a5-347d-0cb4-a170-4846e46065d0/9780062570154.jpg/100x100bb.jpg',
#    'collectionPrice': 6.99,
#    'collectionExplicitness': 'notExplicit',
#    'trackCount': 1,
#    'country': 'USA',
#    'currency': 'USD',
#    'releaseDate': '2016-09-06T07:00:00Z',
#    'primaryGenreName': 'Kids & Young Adults',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview113/v4/0a/fd/2e/0afd2e4e-82f8-7d83-96e6-93b4ca99a533/mzaf_7585685808789146885.std.aac.p.m4a',
#   {'wrapperType': 'audiobook',
#    'artistId': 1036384314,
#    'collectionId': 1051433445,
#    'artistName': 'Jack Johnson',
#    'collectionName': 'Anger Management: Anger Management Cure: Control Anger, Depression & Become Free (Unabridged)',
#    'collectionCensoredName': 'Anger Management: Anger Management Cure: Control Anger, Depression & Become Free (Unabridged)',
#    'artistViewUrl': 'https://books.apple.com/us/author/jack-johnson/id1036384314?uo=4',
#    'collectionViewUrl': 'https://books.apple.com/us/audiobook/anger-management-anger-management-cure-control-anger/id1051433445?uo=4',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music6/v4/26/cd/0d/26cd0d40-4bc7-fcf9-9206-bcdfc5a9e98a/rm_image.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music6/v4/26/cd/0d/26cd0d40-4bc7-fcf9-9206-bcdfc5a9e98a/rm_image.jpg/100x100bb.jpg',
#    'collectionPrice': 3.99,
#    'collectionExplicitness': 'notExplicit',
#    'trackCount': 1,
#    'copyright': '© 2015 Zac',
#    'country': 'USA',
#    'currency': 'USD',
#    'releaseDate': '2015-10-21T07:00:00Z',
#    'primaryGenreName': 'Self-Development',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview113/v4/a9/92/d1/a992d1c3-1afa-234b-b0e4-f9d6a93317f0/mzaf_3322965638975966706.std.aac.p.m4a',
#    'description': "I want to take you on a journey of what anger is and how to conquer it or use it for good. Everyone has their own beliefs about what anger is and if it's good or bad. For 20 years of my life, I lived in fear, and that caused me to feel angry about my life. I was hanging around angry people, and I felt like I had no control. I worked out that most people who are depressed have repressed anger inside, and that's why they feel that way. <br /><br />This audiobook will give you back the power and control. I teach you how to release your anger so you can start living more free and healthily. If you sometimes get angry, it doesn't mean there's something wrong with you; it simply means you have something in your past that keeps getting triggered. It can all change in a heartbeat, and I will show you how to make the change in this book. <br /><br />We need to understand that every emotion we experience from day to day is useful in some context. People look at depression and anger like they are bad to experience. If you find the higher purpose to why it's happening, your life will transform. Take my hand on this journey, and your anger will soon be resolved. <br /><br />Take action today."}]}

# %%
params = {
    'term': 'шнуров',
    'limit': 200,
#     'offset': 2
}

# %%
# pd.set_option('display.max_columns', 100)
res = requests.get(URL, params)
# res.json()

pd.DataFrame(res.json()['results'])
# Out:
#     wrapperType  kind  artistId  collectionId     trackId artistName  \
# 0         track  song  83741585    1506185978  1506185980  Leningrad
# 1         track  song  83741585    1506602653  1506602660  Leningrad
# 2         track  song  83741585    1506602653  1506602663  Leningrad
# 3         track  song  83741585    1506602653  1506602775  Leningrad
# 4         track  song  83741585    1506602653  1506602776  Leningrad
# ..          ...   ...       ...           ...         ...        ...
# 195       track  song  83741585    1506181639  1506181640  Leningrad
# 196       track  song  83741585    1506173424  1506173425  Leningrad
# 197       track  song  83741585    1506204838  1506204839  Leningrad
# 198       track  song  83741585    1505795682  1505795927  Leningrad
# 199       track  song  83741585    1506011055  1506011061  Leningrad
#
#                  collectionName          trackName  \
# 0             Экспонат - Single           Экспонат
# 1            Ленинград: Лучшее!             Москва
# 2            Ленинград: Лучшее!               Рыба
# 3            Ленинград: Лучшее!                WWW
# 4            Ленинград: Лучшее!      Мне бы в небо
# ..                          ...                ...
# 195           Кандидат - Single           Кандидат
# 196              Сумка - Single              Сумка
# 197  Красная смородина - Single  Красная смородина
# 198                  Бабье лето           Пару баб
# 199                      Всякое             Амплуа
#
#          collectionCensoredName  trackCensoredName  ... discNumber trackCount  \
# 0             Экспонат - Single           Экспонат  ...          1          1
# 1            Ленинград: Лучшее!             Москва  ...          1         21
# 2            Ленинград: Лучшее!               Рыба  ...          1         21
# 3            Ленинград: Лучшее!                WWW  ...          1         21
# 4            Ленинград: Лучшее!      Мне бы в небо  ...          1         21
# ..                          ...                ...  ...        ...        ...
# 195           Кандидат - Single           Кандидат  ...          1          1
# 196              Сумка - Single              Сумка  ...          1          1
# 197  Красная смородина - Single  Красная смородина  ...          1          1
# 198                  Бабье лето           Пару баб  ...          1         16
# 199                      Всякое             Амплуа  ...          1          8
#
#     trackNumber trackTimeMillis country currency primaryGenreName  \
# 0             1          230139     USA      USD             Rock
# 1             1          194273     USA      USD             Rock
# 2             3          163370     USA      USD             Rock
# 3            15          167200     USA      USD             Rock
# 4            16          216320     USA      USD             Rock
# ..          ...             ...     ...      ...              ...
# 195           1          157232     USA      USD             Rock
# 196           1          202240     USA      USD             Rock
# 197           1          147984     USA      USD             Rock
# 198          12          176041     USA      USD             Rock
# 199           5          144511     USA      USD             Rock
#
#      contentAdvisoryRating  isStreamable collectionArtistName
# 0                 Explicit          True                  NaN
# 1                 Explicit          True                  NaN
# 2                      NaN          True                  NaN
# 3                 Explicit          True                  NaN
# 4                      NaN          True                  NaN
# ..                     ...           ...                  ...
# 195               Explicit          True                  NaN
# 196                    NaN          True                  NaN
# 197                    NaN          True                  NaN
# 198                    NaN          True                  NaN
# 199               Explicit          True                  NaN
#
# [200 rows x 33 columns]

# %%
params = {
    'term': 'лазарев',
    'limit': 60,
    'attribute': 'allArtistTerm',
    'country': 'ru'
}

# %%
res = requests.get(URL, params)
res.json()

pd.DataFrame(res.json()['results'])
# Out:
#    wrapperType           kind     trackId                       artistName  \
# 0        track  feature-movie  1454644341                     Игорь Зайцев
# 1        track  feature-movie  1499932701                   Андрей Кравчук
# 2        track  feature-movie  1454730275                   Андрей Кравчук
# 3        track           song  1089863288                   Сергей Лазарев
# 4        track           song  1246353561      Сергей Лазарев & Дима Билан
# 5        track           song  1266229819                   Сергей Лазарев
# 6        track           song   978132385                   Сергей Лазарев
# 7        track           song  1017290110                   Сергей Лазарев
# 8        track           song  1470935172                   Сергей Лазарев
# 9        track           song  1276317737                   Сергей Лазарев
# 10       track           song  1292269887                   Сергей Лазарев
# 11       track           song  1477109432                   Сергей Лазарев
# 12       track           song   978132729                   Сергей Лазарев
# 13       track           song  1137973911                   Сергей Лазарев
# 14       track           song   966049279                   Сергей Лазарев
# 35                                           Остров
# 36                                       Доигрались
# 37                                          Пополам
# 38                                        Тактильно
# 39                                    Идеальный мир
# 40                                Нереальная любовь
# 41                                   Лаки Стрэнджер
# 42                                    Биение сердца
# 43                              Даже если ты уйдёшь
# 44                          Пусть весь мир подождёт
# 45                                       Найди меня
# 46                                        Вдребезги
# 47                                    Биение сердца
# 48                                           7 Цифр
# 49                                    Биение Сердца
# 50                                        7 Wonders
# 51                                         Отпускаю
# 52                                      Так красиво
# 53  Moscow to California (feat. Тимати & DJ M.E.G.)
# 54                                        Новый год
# 55                                In My Lonely Life
# 56                                     Hard to Love
# 57                  Cure the Thunder (feat. T-Pain)
# 58                                  Холодный ноябрь
# 59                                      Это всё она
#
#                                   trackCensoredName  \
# 0                                             Тобол
# 1                                     Союз спасения
# 2                                          Адмиралъ
# 3                              You Are the Only One
# 4                                       Прости меня
# 5                                       Так красиво
# 6                                    В самое сердце
# 7                                       Это всё она
# 8                                              Лови
# 9                                          Сдавайся
# 10                                          Шёпотом
# 11                                       Я не боюсь
# 12                              Даже если ты уйдёшь
# 13                          Пусть весь мир подождёт
# 14                                            Весна
# 15                                      Так красиво
# 16                                           Scream
# 17                                    грустные люди
# 18                                    Снег в океане
# 19                                        Вспоминай
# 20                                           7 Цифр
# 21                                         LazerBoy
# 22                                    Идеальный мир
# 23                                            Весна
# 24        Слёзы в моём сердце (ChinKong Production)
# 25                                      В Эпицентре
# 26                                         Сдавайся
# 27                                Нереальная любовь
# 28                                          Шёпотом
# 29                                   Лаки Стрэнджер
# 30                                    Биение сердца
# 31                                Давай расстанемся
# 32                                       Найди меня
# 33                                        Новый год
# 34             Слёзы в моём сердце (Ballad Version)
# 35                                           Остров
# 36                                       Доигрались
# 37                                          Пополам
# 38                                        Тактильно
# 39                                    Идеальный мир
# 40                                Нереальная любовь
# 41                                   Лаки Стрэнджер
# 42                Биение сердца (Unorthodoxx Remix)
# 43              Даже если ты уйдёшь (HarDrum Remix)
# 44                          Пусть весь мир подождёт
# 45                    Найди меня (Alex Menco Remix)
# 46                                        Вдребезги
# 47                 Биение сердца (Sec0ndSkin Remix)
# 48                        7 Цифр (Sec0ndSkin Remix)
# 49                                    Биение Сердца
# 50                                        7 Wonders
# 51                                         Отпускаю
# 52                Так красиво (Rock and Rave Remix)
# 53  Moscow to California (feat. Тимати & DJ M.E.G.)
# 54                        Новый год (HarDrum Remix)
# 55                                In My Lonely Life
# 56                                     Hard to Love
# 57                  Cure the Thunder (feat. T-Pain)
# 58                                  Холодный ноябрь
# 59                                      Это всё она
#
#                                          trackViewUrl  \
# 0   https://itunes.apple.com/ru/movie/%D1%82%D0%BE...
# 1   https://itunes.apple.com/ru/movie/%D1%81%D0%BE...
# 2   https://itunes.apple.com/ru/movie/%D0%B0%D0%B4...
# 3   https://music.apple.com/ru/album/you-are-the-o...
# 4   https://music.apple.com/ru/album/%D0%BF%D1%80%...
# 5   https://music.apple.com/ru/album/%D1%82%D0%B0%...
# 6   https://music.apple.com/ru/album/%D0%B2-%D1%81...
# 46  https://audio-ssl.itunes.apple.com/itunes-asse...
# 47  https://audio-ssl.itunes.apple.com/itunes-asse...
# 48  https://audio-ssl.itunes.apple.com/itunes-asse...
# 49  https://audio-ssl.itunes.apple.com/itunes-asse...
# 50  https://audio-ssl.itunes.apple.com/itunes-asse...
# 51  https://audio-ssl.itunes.apple.com/itunes-asse...
# 52  https://audio-ssl.itunes.apple.com/itunes-asse...
# 53  https://audio-ssl.itunes.apple.com/itunes-asse...
# 54  https://audio-ssl.itunes.apple.com/itunes-asse...
# 55  https://audio-ssl.itunes.apple.com/itunes-asse...
# 56  https://audio-ssl.itunes.apple.com/itunes-asse...
# 57  https://audio-ssl.itunes.apple.com/itunes-asse...
# 58  https://audio-ssl.itunes.apple.com/itunes-asse...
# 59  https://audio-ssl.itunes.apple.com/itunes-asse...
#
#                                          artworkUrl30  \
# 0   https://is1-ssl.mzstatic.com/image/thumb/Video...
# 1   https://is5-ssl.mzstatic.com/image/thumb/Video...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Video...
# 3   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 4   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 5   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 6   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 7   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 8   https://is5-ssl.mzstatic.com/image/thumb/Music...
# 9   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 10  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 11  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 12  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 13  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 14  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 15  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 16  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 17  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 18  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 19  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 20  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 21  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 22  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 23  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 24  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 25  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 26  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 27  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 28  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 29  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 30  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 31  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 32  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 33  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 34  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 35  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 36  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 37  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 38  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 39  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 40  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 41  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 42  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 43  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 44  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 45  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 46  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 47  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 48  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 49  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 50  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 51  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 52  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 53  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 54  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 55  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 56  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 57  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 58  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 59  https://is3-ssl.mzstatic.com/image/thumb/Music...
#
#                                          artworkUrl60  ...  \
# 0   https://is1-ssl.mzstatic.com/image/thumb/Video...  ...
# 1   https://is5-ssl.mzstatic.com/image/thumb/Video...  ...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Video...  ...
# 3   https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 4   https://is4-ssl.mzstatic.com/image/thumb/Music...  ...
# 5   https://is1-ssl.mzstatic.com/image/thumb/Music...  ...
# 6   https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 7   https://is5-ssl.mzstatic.com/image/thumb/Music...  ...
# 8   https://is5-ssl.mzstatic.com/image/thumb/Music...  ...
# 9   https://is1-ssl.mzstatic.com/image/thumb/Music...  ...
# 10  https://is4-ssl.mzstatic.com/image/thumb/Music...  ...
# 11  https://is5-ssl.mzstatic.com/image/thumb/Music...  ...
# 12  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 13  https://is4-ssl.mzstatic.com/image/thumb/Music...  ...
# 14  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 15  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 16  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 17  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 18  https://is4-ssl.mzstatic.com/image/thumb/Music...  ...
# 19  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 20  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 21  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 22  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 23  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 24  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 25  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 26  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 27  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 28  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 29  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 30  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 31  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 32  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 33  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 34  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 35  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 36  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 37  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 38  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 39  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 40  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 41  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 42  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 43  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 44  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 45  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 46  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 47  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 48  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 49  https://is4-ssl.mzstatic.com/image/thumb/Music...  ...
# 50  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 51  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 52  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 53  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 54  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 55  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 56  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 57  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
# 58  https://is5-ssl.mzstatic.com/image/thumb/Music...  ...
# 59  https://is3-ssl.mzstatic.com/image/thumb/Music...  ...
#
#                       collectionCensoredName  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3              You Are the Only One - Single
# 4                       Прости меня - Single
# 5                       Так красиво - Single
# 6                 The Best (Russian Edition)
# 7                       Это всё она - Single
# 8                              Лови - Single
# 9                          Сдавайся - Single
# 10                          Шёпотом - Single
# 11                                Я не боюсь
# 12                The Best (Russian Edition)
# 13          Пусть весь мир подождёт - Single
# 14                            Весна - Single
# 15                               В Эпицентре
# 16                           SCREAM - Single
# 17                    грустные люди - Single
# 18                                     Это я
# 19                The Best (Russian Edition)
# 20                The Best (Russian Edition)
# 21                The Best (Russian Edition)
# 22                    Идеальный мир - Single
# 23                The Best (Russian Edition)
# 24                 ЛАЗАРЕВ. (Deluxe Version)
# 25                               В Эпицентре
# 26                               В Эпицентре
# 27                The Best (Russian Edition)
# 28                               В Эпицентре
# 29                   Lucky Stranger - Single
# 30                The Best (Russian Edition)
# 31                               В Эпицентре
# 32                The Best (Russian Edition)
# 33                               В Эпицентре
# 34                The Best (Russian Edition)
# 35                               В Эпицентре
# 36                               В Эпицентре
# 37                               В Эпицентре
# 38                               В Эпицентре
# 39                               В Эпицентре
# 40                 ЛАЗАРЕВ. (Deluxe Version)
# 41                               В Эпицентре
# 42                The Best (Russian Edition)
# 43                The Best (Russian Edition)
# 44                               В Эпицентре
# 45                The Best (Russian Edition)
# 46                               В Эпицентре
# 47                The Best (Russian Edition)
# 48                The Best (Russian Edition)
# 49                    Биение Сердца - Single
# 50                 ЛАЗАРЕВ. (Deluxe Version)
# 51                The Best (Russian Edition)
# 52                               В Эпицентре
# 53                 ЛАЗАРЕВ. (Deluxe Version)
# 54                        Новый год - Single
# 55                The Best (English Edition)
# 56                The Best (English Edition)
# 57  Cure the Thunder (feat. T-Pain) - Single
# 58                  Холодный ноябрь - Single
# 59                           RUSSKOE для неё
#
#                                         artistViewUrl  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 4   https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 5   https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 6   https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 7   https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 8   https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 9   https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 10  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 11  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 12  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 13  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 14  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 15  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 16  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 17  https://music.apple.com/ru/artist/%D0%B4%D0%B8...
# 18  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 19  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 20  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 21  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 22  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 23  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 24  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 25  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 26  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 27  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 28  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 29  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 30  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 31  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 32  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 33  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 34  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 35  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 36  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 37  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 38  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 39  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 40  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 41  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 42  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 43  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 44  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 45  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 46  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 47  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 48  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 49  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 50  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 51  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 52  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 53  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 54  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 55  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 56  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 57  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 58  https://music.apple.com/ru/artist/%D1%81%D0%B5...
# 59  https://music.apple.com/ru/artist/%D1%81%D0%B5...
#
#                                     collectionViewUrl  discCount  discNumber  \
# 0                                                 NaN        NaN         NaN
# 1                                                 NaN        NaN         NaN
# 2                                                 NaN        NaN         NaN
# 3   https://music.apple.com/ru/album/you-are-the-o...        1.0         1.0
# 4   https://music.apple.com/ru/album/%D0%BF%D1%80%...        1.0         1.0
# 5   https://music.apple.com/ru/album/%D1%82%D0%B0%...        1.0         1.0
# 44  https://music.apple.com/ru/album/%D0%BF%D1%83%...        1.0         1.0
# 45  https://music.apple.com/ru/album/%D0%BD%D0%B0%...        1.0         1.0
# 46  https://music.apple.com/ru/album/%D0%B2%D0%B4%...        1.0         1.0
# 47  https://music.apple.com/ru/album/%D0%B1%D0%B8%...        1.0         1.0
# 48  https://music.apple.com/ru/album/7-%D1%86%D0%B...        1.0         1.0
# 49  https://music.apple.com/ru/album/%D0%B1%D0%B8%...        1.0         1.0
# 50  https://music.apple.com/ru/album/7-wonders/605...        1.0         1.0
# 51  https://music.apple.com/ru/album/%D0%BE%D1%82%...        1.0         1.0
# 52  https://music.apple.com/ru/album/%D1%82%D0%B0%...        1.0         1.0
# 53  https://music.apple.com/ru/album/moscow-to-cal...        1.0         1.0
# 54  https://music.apple.com/ru/album/%D0%BD%D0%BE%...        1.0         1.0
# 55  https://music.apple.com/ru/album/in-my-lonely-...        1.0         1.0
# 56  https://music.apple.com/ru/album/hard-to-love/...        1.0         1.0
# 57  https://music.apple.com/ru/album/cure-the-thun...        1.0         1.0
# 58  https://music.apple.com/ru/album/%D1%85%D0%BE%...        1.0         1.0
# 59  https://music.apple.com/ru/album/%D1%8D%D1%82%...        1.0         1.0
#
#     trackCount  trackNumber isStreamable collectionArtistId  \
# 0          NaN          NaN          NaN                NaN
# 1          NaN          NaN          NaN                NaN
# 2          NaN          NaN          NaN                NaN
# 3          1.0          1.0         True                NaN
# 4          1.0          1.0         True                NaN
# 5          1.0          1.0         True                NaN
# 6         16.0          3.0         True                NaN
# 7          1.0          1.0         True                NaN
# 8          1.0          1.0         True                NaN
# 9          1.0          1.0         True                NaN
# 10         1.0          1.0         True                NaN
# 11         8.0          2.0         True                NaN
# 12        16.0          8.0         True                NaN
# 13         1.0          1.0         True                NaN
# 14         1.0          1.0         True                NaN
# 15        15.0          1.0         True                NaN
# 16         1.0          1.0         True                NaN
# 17         1.0          1.0         True                NaN
# 18        11.0          5.0         True                NaN
# 19        16.0          9.0         True                NaN
# 20        16.0          2.0         True                NaN
# 21        16.0          5.0         True                NaN
# 22         1.0          1.0         True                NaN
# 23        16.0          1.0         True                NaN
# 24        16.0         12.0         True                NaN
# 25        15.0          4.0         True                NaN
# 26        15.0          5.0         True                NaN
# 27        16.0          4.0         True                NaN
# 28        15.0          3.0         True                NaN
# 29         2.0          1.0         True                NaN
# 30        16.0         10.0         True                NaN
# 31        15.0         12.0         True                NaN
# 32        16.0          6.0         True                NaN
# 33        15.0         14.0         True                NaN
# 34        16.0          7.0         True                NaN
# 35        15.0         13.0         True                NaN
# 36        15.0          7.0         True                NaN
# 37        15.0         11.0         True                NaN
# 38        15.0          2.0         True                NaN
# 39        15.0         10.0         True                NaN
# 40        16.0          5.0         True                NaN
# 41        15.0          8.0         True                NaN
# 42        16.0         14.0         True                NaN
# 43        16.0         13.0         True                NaN
# 44        15.0          9.0         True                NaN
# 45        16.0         12.0         True                NaN
# 46        15.0          6.0         True                NaN
# 47        16.0         16.0         True                NaN
# 48        16.0         15.0         True                NaN
# 49         1.0          1.0         True                NaN
# 50        16.0          8.0         True                NaN
# 51        16.0         11.0         True                NaN
# 52        15.0         15.0         True                NaN
# 53        16.0          7.0         True                NaN
# 54         2.0          2.0         True                NaN
# 55        29.0          2.0         True                NaN
# 56        29.0          6.0         True                NaN
# 57         1.0          1.0         True                NaN
# 58         1.0          1.0         True                NaN
# 59        35.0         10.0         True         80204262.0
#
#    collectionArtistName
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48                  NaN
# 49                  NaN
# 50                  NaN
# 51                  NaN
# 52                  NaN
# 53                  NaN
# 54                  NaN
# 55                  NaN
# 56                  NaN
# 57                  NaN
# 58                  NaN
# 59       Разные артисты
#
# [60 rows x 40 columns]

# %% [markdown]
# ## Практика 4. Соберем сообщения из новостной ленты ВК по нужному запросу

# %%
# https://vk.com/dev/manuals
# https://vk.com/dev/newsfeed.search
NEWSFEED_REQUEST = 'https://api.vk.com/method/newsfeed.search?'
TOKEN = '9df7991c9df7991c9df7991c329d86910d99df79df7991cc363a27748dcf7ad91284ef6'
VERSION = '5.103'
SLEEP = 0.33

# %%
# обращаем внимание, что максимальное количество постов, 
# которые можно вытащить за раз, ограничено
params = {
    'access_token': TOKEN,
    'v': VERSION,
    'q': 'короновирус',
    'count': 200
}

# %%
res = requests.get(NEWSFEED_REQUEST, params)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"error":{"error_code":38,"error_msg":"Unknown application: could not get application","request_params":[{"key":"v","value":"5.103"},{"key":"q","value":"короновирус"},{"key":"count","value":"200"},{"key":"method","value":"newsfeed.search"},{"key":"oauth","value":"1"}]}}'

# %%
res.json()
# Out:
# {'error': {'error_code': 38,
#   'error_msg': 'Unknown application: could not get application',
#   'request_params': [{'key': 'v', 'value': '5.103'},
#    {'key': 'q', 'value': 'короновирус'},
#    {'key': 'count', 'value': '200'},
#    {'key': 'method', 'value': 'newsfeed.search'},
#    {'key': 'oauth', 'value': '1'}]}}

# %%
res.json()['error']['request_params']
# Out:
# [{'key': 'v', 'value': '5.103'},
#  {'key': 'q', 'value': 'короновирус'},
#  {'key': 'count', 'value': '200'},
#  {'key': 'method', 'value': 'newsfeed.search'},
#  {'key': 'oauth', 'value': '1'}]

# %%
pd.DataFrame(res.json()['response']['items'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-80d05442f06c> in <module>
# ----> 1 pd.DataFrame(res.json()['response']['items'])
#
# KeyError: 'response'

# %%
# соберем все доступные сообщения по запросу
newsfeed_df = pd.DataFrame()
while True:
    result = requests.get(NEWSFEED_REQUEST, params)
    time.sleep(0.33)
    newsfeed_df = pd.concat([newsfeed_df, pd.DataFrame(result.json()['response']['items'])])
    if 'next_from' in result.json()['response'].keys():
        params['start_from'] = result.json()['response']['next_from']
    else:
        break
newsfeed_df
